# %% [markdown]
# <a href="https://colab.research.google.com/github/cartersmotherman/nba-predictions/blob/main/NBA_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nba_api
# Out:
# Collecting nba_api
#   Downloading nba_api-1.4.1-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.7/261.7 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: certifi<2024.0.0,>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from nba_api) (2023.11.17)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from nba_api) (1.23.5)
# Requirement already satisfied: requests<3.0,>=2.31 in /usr/local/lib/python3.10/dist-packages (from nba_api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->nba_api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->nba_api) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->nba_api) (2.0.7)
# Installing collected packages: nba_api
# Successfully installed nba_api-1.4.1

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the webpage
url = "https://hashtagbasketball.com/nba-defense-vs-position"

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")

# Find all tables on the webpage
tables = soup.find_all("table")

# Read the table data into the DataFrame
DefenseVsPosition = pd.read_html(str(tables[2]))[0]

# Remove "Sort: " from column names
DefenseVsPosition.columns = DefenseVsPosition.columns.str.replace('Sort: ', '')

# Columns to convert to float (excluding 'Position' and 'Team')
columns_to_convert = DefenseVsPosition.columns.difference(['Position', 'Team'])

# Loop through specified columns, remove ranks, and convert to floats
for col in columns_to_convert:
    DefenseVsPosition[col] = DefenseVsPosition[col].apply(lambda x: float(x.split()[0]))

# Clean 'Team' column to remove ranks
DefenseVsPosition['Team'] = DefenseVsPosition['Team'].apply(lambda x: x.split()[0])

replacement_map = {'SA': 'SAS', 'PHO': 'PHX', 'NY': 'NYK', 'NO': 'NOP', 'GS': 'GSW'}

# Replace values in 'Team' column using the replacement_map
DefenseVsPosition['Team'].replace(replacement_map, inplace=True)

# %%
DefenseVsPosition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  150 non-null    object
#  1   Team      150 non-null    object
#  2   PTS       150 non-null    float64
#  3   FG%       150 non-null    float64
#  4   FT%       150 non-null    float64
#  5   3PM       150 non-null    float64
#  6   REB       150 non-null    float64
#  7   AST       150 non-null    float64
#  8   STL       150 non-null    float64
#  9   BLK       150 non-null    float64
#  10  TO        150 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 13.0+ KB

# %%
from nba_api.stats.endpoints import leaguedashteamstats

# Fetch team opponent stats
from nba_api.stats.endpoints import leaguedashteamstats

# Fetch per game opponent stats
team_opponent_stats = leaguedashteamstats.LeagueDashTeamStats(per_mode_detailed='PerGame', measure_type_detailed_defense='Opponent',last_n_games=15)

# Convert the obtained data to a pandas DataFrame
team_opponent_stats_df = team_opponent_stats.get_data_frames()[0]


# Display the DataFrame containing team opponent stats
team_opponent_stats_df['TEAM_NAME'].unique()

team_abbreviations = {
    'Atlanta Hawks': 'ATL', 'Boston Celtics': 'BOS', 'Brooklyn Nets': 'BKN', 'Charlotte Hornets': 'CHA',
    'Chicago Bulls': 'CHI', 'Cleveland Cavaliers': 'CLE', 'Dallas Mavericks': 'DAL', 'Denver Nuggets': 'DEN',
    'Detroit Pistons': 'DET', 'Golden State Warriors': 'GSW', 'Houston Rockets': 'HOU', 'Indiana Pacers': 'IND',
    'LA Clippers': 'LAC', 'Los Angeles Lakers': 'LAL', 'Memphis Grizzlies': 'MEM', 'Miami Heat': 'MIA',
    'Milwaukee Bucks': 'MIL', 'Minnesota Timberwolves': 'MIN', 'New Orleans Pelicans': 'NOP',
    'New York Knicks': 'NYK', 'Oklahoma City Thunder': 'OKC', 'Orlando Magic': 'ORL', 'Philadelphia 76ers': 'PHI',
    'Phoenix Suns': 'PHX', 'Portland Trail Blazers': 'POR', 'Sacramento Kings': 'SAC',
    'San Antonio Spurs': 'SAS', 'Toronto Raptors': 'TOR', 'Utah Jazz': 'UTA', 'Washington Wizards': 'WAS'
}

# Replace the team names with abbreviations using the mapping
team_opponent_stats_df['TEAM'] = team_opponent_stats_df['TEAM_NAME'].map(team_abbreviations)

# Your DataFrame containing the columns
columns = [
    'TEAM', 'OPP_FGM', 'OPP_FGA', 'OPP_FG_PCT', 'OPP_FG3M', 'OPP_FG3A', 'OPP_FG3_PCT',
    'OPP_FTM', 'OPP_FTA', 'OPP_FT_PCT', 'OPP_OREB', 'OPP_DREB', 'OPP_REB', 'OPP_AST',
    'OPP_TOV', 'OPP_STL', 'OPP_BLK', 'OPP_BLKA', 'OPP_PF', 'OPP_PFD', 'OPP_PTS'
]

# Sample DataFrame (replace this with your actual DataFrame)
TeamOpponent = team_opponent_stats_df[columns]

# Define the desired column order
desired_order = [
    'TEAM', 'OPP_FGM', 'OPP_FGA', 'OPP_FG_PCT', 'OPP_FG3M', 'OPP_FG3A', 'OPP_FG3_PCT',
    'OPP_FTM', 'OPP_FTA', 'OPP_FT_PCT', 'OPP_OREB', 'OPP_DREB', 'OPP_REB', 'OPP_AST',
    'OPP_TOV', 'OPP_STL', 'OPP_BLK', 'OPP_BLKA', 'OPP_PF', 'OPP_PFD', 'OPP_PTS'
]

# Reorder columns
TeamOpponent = TeamOpponent.reindex(columns=desired_order)

# Display the updated DataFra

# %%
import pandas as pd
from nba_api.stats.endpoints import playergamelog
from nba_api.stats.static import players

# Read the CSV file containing player names
file_path = '/content/drive/MyDrive/PlayerList.csv'
df = pd.read_csv(file_path)

# List of player names from the CSV file
player_names = df['Player'].tolist()  # Assuming 'Player Name' is the column header in the CSV

# Get player IDs for the given player names
nba_players = players.get_players()
player_logs = []  # List to store player game logs

for player_name in player_names:
    player_info = [player for player in nba_players if player['full_name'] == player_name]

    if player_info:
        player_id = player_info[0]['id']
        # Get player's game log for a specific season
        season = '2023-24'  # Replace with the season you want to retrieve
        player_log = playergamelog.PlayerGameLog(player_id=player_id, season=season)
        player_data = player_log.get_data_frames()[0]  # Get player's game log DataFrame
        # Add a 'Player' column with the player's name
        player_data['Player'] = player_name

        # Modify 'MATCHUP' column to create 'OPP' column with the last 3 characters
        player_data['OPP'] = player_data['MATCHUP'].str[-3:]

        player_logs.append(player_data)  # Append DataFrame to the list
    else:
        print(f"Player '{player_name}' not found.")

# Concatenate all player game logs into a single DataFrame
master_df = pd.concat(player_logs, ignore_index=True)

# %%
selected_columns = ['Player', 'GAME_DATE','OPP', 'MIN', 'PTS', 'REB', 'AST', 'STL', 'BLK', 'TOV']
master_df = master_df[selected_columns]
playerlogs = master_df[master_df['MIN'] > 23]
playerlogs
# Out:
#                Player     GAME_DATE  OPP  MIN  PTS  REB  AST  STL  BLK  TOV
# 0         Joel Embiid  JAN 05, 2024  NYK   36   30   10    3    1    3    6
# 1         Joel Embiid  JAN 02, 2024  CHI   31   31   15   10    1    2    4
# 2         Joel Embiid  DEC 22, 2023  TOR   35   31   10    9    2    4    6
# 3         Joel Embiid  DEC 20, 2023  MIN   36   51   12    3    2    1    2
# 4         Joel Embiid  DEC 18, 2023  CHI   37   40   14    6    0    2    4
# ...               ...           ...  ...  ...  ...  ...  ...  ...  ...  ...
# 6119  Bismack Biyombo  NOV 08, 2023  MIA   30    9   10    0    1    0    1
# 6120  Bismack Biyombo  NOV 05, 2023  POR   26    8   11    4    0    3    2
# 6123     Gabe Vincent  OCT 30, 2023  ORL   25    9    0    2    1    0    0
# 6124     Gabe Vincent  OCT 29, 2023  SAC   32    2    0    2    1    0    0
# 6125     Gabe Vincent  OCT 26, 2023  PHX   35    7    3    6    3    0    0
#
# [5073 rows x 10 columns]

# %%
# Read the CSV file containing player names
file_path = '/content/drive/MyDrive/PlayerPositions.csv'
player_positions = pd.read_csv(file_path)

merged_df = pd.merge(master_df, player_positions, on='Player', how='left')

# Display the updated merged DataFrame
selected_columns = ['Player','Pos','GAME_DATE', 'OPP', 'MIN', 'PTS', 'REB', 'AST', 'STL', 'BLK', 'TOV']
playerlogs = merged_df[selected_columns]

playerlogs['Pos'].unique()
playerlogs
# Out:
#             Player Pos     GAME_DATE  OPP  MIN  PTS  REB  AST  STL  BLK  TOV
# 0      Joel Embiid   C  JAN 05, 2024  NYK   36   30   10    3    1    3    6
# 1      Joel Embiid   C  JAN 02, 2024  CHI   31   31   15   10    1    2    4
# 2      Joel Embiid   C  DEC 22, 2023  TOR   35   31   10    9    2    4    6
# 3      Joel Embiid   C  DEC 20, 2023  MIN   36   51   12    3    2    1    2
# 4      Joel Embiid   C  DEC 18, 2023  CHI   37   40   14    6    0    2    4
# ...            ...  ..           ...  ...  ...  ...  ...  ...  ...  ...  ...
# 6122  Gabe Vincent   G  DEC 20, 2023  CHI   14    3    1    3    0    0    0
# 6123  Gabe Vincent   G  OCT 30, 2023  ORL   25    9    0    2    1    0    0
# 6124  Gabe Vincent   G  OCT 29, 2023  SAC   32    2    0    2    1    0    0
# 6125  Gabe Vincent   G  OCT 26, 2023  PHX   35    7    3    6    3    0    0
# 6126  Gabe Vincent   G  OCT 24, 2023  DEN   22    6    1    2    1    0    2
#
# [6127 rows x 11 columns]

# %%
# Assuming 'playerlogs' is the DataFrame containing player logs

# Map positions accordingly
position_mapping = {'F': 'SF', 'G': 'PG', 'GF': 'SF', 'FC': 'C'}

# Replace positions with the updated ones
playerlogs['Pos'] = playerlogs['Pos'].replace(position_mapping)

# Filter positions to keep only 'PG', 'SG', 'SF', 'PF', 'C'
playerlogs = playerlogs[playerlogs['Pos'].isin(['PG', 'SG', 'SF', 'PF', 'C'])]

# Display unique positions after transformation
playerlogs.columns
playerlogs
# Out:
#             Player Pos     GAME_DATE  OPP  MIN  PTS  REB  AST  STL  BLK  TOV
# 0      Joel Embiid   C  JAN 05, 2024  NYK   36   30   10    3    1    3    6
# 1      Joel Embiid   C  JAN 02, 2024  CHI   31   31   15   10    1    2    4
# 2      Joel Embiid   C  DEC 22, 2023  TOR   35   31   10    9    2    4    6
# 3      Joel Embiid   C  DEC 20, 2023  MIN   36   51   12    3    2    1    2
# 4      Joel Embiid   C  DEC 18, 2023  CHI   37   40   14    6    0    2    4
# ...            ...  ..           ...  ...  ...  ...  ...  ...  ...  ...  ...
# 6122  Gabe Vincent  PG  DEC 20, 2023  CHI   14    3    1    3    0    0    0
# 6123  Gabe Vincent  PG  OCT 30, 2023  ORL   25    9    0    2    1    0    0
# 6124  Gabe Vincent  PG  OCT 29, 2023  SAC   32    2    0    2    1    0    0
# 6125  Gabe Vincent  PG  OCT 26, 2023  PHX   35    7    3    6    3    0    0
# 6126  Gabe Vincent  PG  OCT 24, 2023  DEN   22    6    1    2    1    0    2
#
# [6127 rows x 11 columns]

# %%
DefenseVsPosition.columns
# Out:
# Index(['Position', 'Team', 'PTS', 'FG%', 'FT%', '3PM', 'REB', 'AST', 'STL',
#        'BLK', 'TO'],
#       dtype='object')

# %%
merged_data = playerlogs.merge(DefenseVsPosition, left_on=['OPP', 'Pos'], right_on=['Team', 'Position'], how='left')

merged_data
# Out:
#             Player Pos     GAME_DATE  OPP  MIN  PTS_x  REB_x  AST_x  STL_x  \
# 0      Joel Embiid   C  JAN 05, 2024  NYK   36     30     10      3      1
# 1      Joel Embiid   C  JAN 02, 2024  CHI   31     31     15     10      1
# 2      Joel Embiid   C  DEC 22, 2023  TOR   35     31     10      9      2
# 3      Joel Embiid   C  DEC 20, 2023  MIN   36     51     12      3      2
# 4      Joel Embiid   C  DEC 18, 2023  CHI   37     40     14      6      0
# ...            ...  ..           ...  ...  ...    ...    ...    ...    ...
# 6122  Gabe Vincent  PG  DEC 20, 2023  CHI   14      3      1      3      0
# 6123  Gabe Vincent  PG  OCT 30, 2023  ORL   25      9      0      2      1
# 6124  Gabe Vincent  PG  OCT 29, 2023  SAC   32      2      0      2      1
# 6125  Gabe Vincent  PG  OCT 26, 2023  PHX   35      7      3      6      3
# 6126  Gabe Vincent  PG  OCT 24, 2023  DEN   22      6      1      2      1
#
#       BLK_x  ...  Team PTS_y   FG%   FT%  3PM  REB_y  AST_y  STL_y  BLK_y   TO
# 0         3  ...   NYK  20.8  54.5  73.3  1.3   13.5    2.4    1.2    2.3  2.4
# 1         2  ...   CHI  23.1  56.7  70.9  1.2   15.4    4.5    1.2    2.2  2.4
# 2         4  ...   TOR  22.6  58.2  78.0  0.9   14.8    4.5    1.0    2.4  2.4
# 3         1  ...   MIN  21.2  51.4  75.9  0.8   12.7    4.6    1.4    1.7  2.2
# 4         2  ...   CHI  23.1  56.7  70.9  1.2   15.4    4.5    1.2    2.2  2.4
# ...     ...  ...   ...   ...   ...   ...  ...    ...    ...    ...    ...  ...
# 6122      0  ...   CHI  21.6  42.6  86.0  2.8    5.3    9.0    1.2    0.6  3.4
# 6123      0  ...   ORL  26.3  46.1  81.8  3.1    5.6    8.1    1.6    0.5  3.2
# 6124      0  ...   SAC  24.7  46.2  84.5  3.1    6.1    7.9    1.6    0.6  3.0
# 6125      0  ...   PHX  26.2  46.9  84.7  3.1    6.4    8.7    2.0    0.6  2.6
# 6126      0  ...   DEN  23.3  45.8  85.0  2.7    6.1    7.4    1.5    0.7  2.9
#
# [6127 rows x 22 columns]

# %%
playerlogs_columns = {
    'PTS_x': 'PTS',
    'REB_x': 'REB',
    'AST_x': 'AST',
    'STL_x': 'STL',
    'BLK_x': 'BLK',
}

# Rename the columns from DefenseVsPosition with 'OPP_' prefix
opp_columns = {
    'PTS_y': 'OPP_PTSvsPos',
    'REB_y': 'OPP_REBvsPos',
    'AST_y': 'OPP_ASTvsPos',
    'STL_y': 'OPP_STLvsPos',
    'BLK_y': 'OPP_BLKvsPos',
    'TO': 'OPP_TOVvsPos'
}

# Rename columns in the DataFrame
final_data = merged_data.rename(columns={**playerlogs_columns, **opp_columns})

# Select only the desired columns
selected_columns = ['Player', 'Pos','GAME_DATE', 'OPP', 'MIN','PTS', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'OPP_PTSvsPos', 'OPP_REBvsPos', 'OPP_ASTvsPos', 'OPP_STLvsPos', 'OPP_BLKvsPos', 'OPP_TOVvsPos']
final_data = final_data[selected_columns]


# Display the final DataFrame
print(final_data.head())
# Out:
#         Player Pos     GAME_DATE  OPP  MIN  PTS  REB  AST  STL  BLK  TOV  \
# 0  Joel Embiid   C  JAN 05, 2024  NYK   36   30   10    3    1    3    6
# 1  Joel Embiid   C  JAN 02, 2024  CHI   31   31   15   10    1    2    4
# 2  Joel Embiid   C  DEC 22, 2023  TOR   35   31   10    9    2    4    6
# 3  Joel Embiid   C  DEC 20, 2023  MIN   36   51   12    3    2    1    2
# 4  Joel Embiid   C  DEC 18, 2023  CHI   37   40   14    6    0    2    4
#
#    OPP_PTSvsPos  OPP_REBvsPos  OPP_ASTvsPos  OPP_STLvsPos  OPP_BLKvsPos  \
# 0          20.8          13.5           2.4           1.2           2.3
# 1          23.1          15.4           4.5           1.2           2.2
# 2          22.6          14.8           4.5           1.0           2.4
# 3          21.2          12.7           4.6           1.4           1.7
# 4          23.1          15.4           4.5           1.2           2.2
#
#    OPP_TOVvsPos
# 0           2.4
# 1           2.4
# 2           2.4
# 3           2.2
# 4           2.4

# %%
final_data = pd.merge(final_data, TeamOpponent, left_on='OPP', right_on='TEAM')
final_data.columns
# Out:
# Index(['Player', 'Pos', 'GAME_DATE', 'OPP', 'MIN', 'PTS', 'REB', 'AST', 'STL',
#        'BLK', 'TOV', 'OPP_PTSvsPos', 'OPP_REBvsPos', 'OPP_ASTvsPos',
#        'OPP_STLvsPos', 'OPP_BLKvsPos', 'OPP_TOVvsPos', 'TEAM', 'OPP_FGM',
#        'OPP_FGA', 'OPP_FG_PCT', 'OPP_FG3M', 'OPP_FG3A', 'OPP_FG3_PCT',
#        'OPP_FTM', 'OPP_FTA', 'OPP_FT_PCT', 'OPP_OREB', 'OPP_DREB', 'OPP_REB',
#        'OPP_AST', 'OPP_TOV', 'OPP_STL', 'OPP_BLK', 'OPP_BLKA', 'OPP_PF',
#        'OPP_PFD', 'OPP_PTS'],
#       dtype='object')

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6127 entries, 0 to 6126
# Data columns (total 38 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Player        6127 non-null   object
#  1   Pos           6127 non-null   object
#  2   GAME_DATE     6127 non-null   object
#  3   OPP           6127 non-null   object
#  4   MIN           6127 non-null   int64
#  5   PTS           6127 non-null   int64
#  6   REB           6127 non-null   int64
#  7   AST           6127 non-null   int64
#  8   STL           6127 non-null   int64
#  9   BLK           6127 non-null   int64
#  10  TOV           6127 non-null   int64
#  11  OPP_PTSvsPos  6127 non-null   float64
#  12  OPP_REBvsPos  6127 non-null   float64
#  13  OPP_ASTvsPos  6127 non-null   float64
#  14  OPP_STLvsPos  6127 non-null   float64
#  15  OPP_BLKvsPos  6127 non-null   float64
#  16  OPP_TOVvsPos  6127 non-null   float64
#  17  TEAM          6127 non-null   object
#  18  OPP_FGM       6127 non-null   float64
#  19  OPP_FGA       6127 non-null   float64
#  20  OPP_FG_PCT    6127 non-null   float64
#  21  OPP_FG3M      6127 non-null   float64
#  22  OPP_FG3A      6127 non-null   float64
#  23  OPP_FG3_PCT   6127 non-null   float64
#  24  OPP_FTM       6127 non-null   float64
#  25  OPP_FTA       6127 non-null   float64
#  26  OPP_FT_PCT    6127 non-null   float64
#  27  OPP_OREB      6127 non-null   float64
#  28  OPP_DREB      6127 non-null   float64
#  29  OPP_REB       6127 non-null   float64
#  30  OPP_AST       6127 non-null   float64
#  31  OPP_TOV       6127 non-null   float64
#  32  OPP_STL       6127 non-null   float64
#  33  OPP_BLK       6127 non-null   float64
#  34  OPP_BLKA      6127 non-null   float64
#  35  OPP_PF        6127 non-null   float64
#  36  OPP_PFD       6127 non-null   float64
#  37  OPP_PTS       6127 non-null   float64
# dtypes: float64(26), int64(7), object(5)
# memory usage: 1.8+ MB

# %%
# Sort the dataframe by 'Player' and 'Game' columns
final_data = final_data.sort_values(by=['Player', 'GAME_DATE']).reset_index(drop=True)

# Calculate rolling averages for points, rebounds, and assists for the previous 5 games
final_data['Avg_Points_Prev_5'] = final_data.groupby('Player')['PTS'].rolling(window=5, min_periods=1).mean().reset_index(drop=True)
final_data['Avg_Rebounds_Prev_5'] = final_data.groupby('Player')['REB'].rolling(window=5, min_periods=1).mean().reset_index(drop=True)
final_data['Avg_Assists_Prev_5'] = final_data.groupby('Player')['AST'].rolling(window=5, min_periods=1).mean().reset_index(drop=True)

# Shift the rolling averages by one row to represent the previous 5 games excluding the current game
final_data['Avg_Points_Prev_5'] = final_data.groupby('Player')['Avg_Points_Prev_5'].shift(fill_value=0)
final_data['Avg_Rebounds_Prev_5'] = final_data.groupby('Player')['Avg_Rebounds_Prev_5'].shift(fill_value=0)
final_data['Avg_Assists_Prev_5'] = final_data.groupby('Player')['Avg_Assists_Prev_5'].shift(fill_value=0)
final_data.dropna(inplace=True)
# Display the updated DataFrame
final_data.head()
# Out:
#          Player Pos     GAME_DATE  OPP  MIN  PTS  REB  AST  STL  BLK  ...  \
# 0  Aaron Gordon  SF  DEC 02, 2023  SAC   33   17    7    3    0    1  ...
# 1  Aaron Gordon  SF  DEC 06, 2023  LAC   31    8    6    2    2    0  ...
# 2  Aaron Gordon  SF  DEC 08, 2023  HOU   22    3    6    3    0    0  ...
# 3  Aaron Gordon  SF  DEC 11, 2023  ATL   29   18   12    1    0    0  ...
# 4  Aaron Gordon  SF  DEC 12, 2023  CHI   32   14    7    6    0    0  ...
#
#    OPP_TOV  OPP_STL  OPP_BLK  OPP_BLKA  OPP_PF  OPP_PFD  OPP_PTS  \
# 0     13.7      6.6      5.7       4.3    18.2     19.7    117.7
# 1     12.6      7.5      4.0       5.1    19.0     19.1    114.6
# 2     14.3      7.0      5.4       3.9    20.7     21.6    117.6
# 3     12.7      7.6      4.9       4.9    21.2     19.8    126.1
# 4     13.7      6.6      5.0       5.5    18.5     18.5    109.1
#
#   Avg_Points_Prev_5  Avg_Rebounds_Prev_5  Avg_Assists_Prev_5
# 0          0.000000             0.000000            0.000000
# 1         17.000000             7.000000            3.000000
# 2         12.500000             6.500000            2.500000
# 3          9.333333             6.333333            2.666667
# 4         11.500000             7.750000            2.250000
#
# [5 rows x 41 columns]

# %%
pt_pwr = pd.read_csv('/content/drive/MyDrive/PointPower.csv')
data = pd.merge(final_data,pt_pwr,on=['OPP'])
print(pt_pwr)
# Out:
#     OPP  PT_PWR
# 0   BOS  329.52
# 1   DEN  329.01
# 2   MIL  338.76
# 3   MIN  321.09
# 4   OKC  332.52
# 5   PHI  329.97
# 6   LAC  329.94
# 7   DAL  334.35
# 8   NOP  326.93
# 9   NYK  330.34
# 10  SAC  332.27
# 11  CLE  325.13
# 12  IND  345.81
# 13  MIA  326.26
# 14  ORL  324.53
# 15  PHX  329.60
# 16  HOU  323.00
# 17  GSW  331.74
# 18  LAL  326.07
# 19  UTA  330.02
# 20  BKN  331.41
# 21  CHI  322.51
# 22  ATL  342.21
# 23  TOR  329.54
# 24  MEM  319.96
# 25  POR  323.15
# 26  CHA  329.96
# 27  WAS  336.47
# 28  SAS  329.11
# 29  DET  330.54

# %%
data = data.sort_values(by=['Player', 'GAME_DATE']).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
import pandas as pd
import xgboost as xgb

# Your data (I'll assume it's in a DataFrame named 'data')
# ...

# Unique players in the dataset
unique_players = data['Player'].unique()

# Dictionary to store the best model for each player's target variable ('PTS', 'REB', 'AST')
player_best_models = {player: {} for player in unique_players}

# ... (previous code remains unchanged)

# Iterate over unique players
for player in unique_players:
    # Filter data for the current player
    player_data = data[data['Player'] == player]

    # Check if the player has at least 20 rows
    if len(player_data) < 20:
        continue

    # Target variables
    target_variables = ['PTS', 'REB', 'AST']

    for target_variable in target_variables:
        # Features: All numeric columns except the target variable and excluded columns
        excluded_columns = ['PTS', 'REB', 'AST', 'STL', 'BLK', 'TOV']
        features = player_data.select_dtypes(include='number').drop(columns=[target_variable] + excluded_columns).columns.tolist()

        # Conditionally drop columns based on the target variable
        if target_variable == 'PTS':
            features = [feature for feature in features if feature not in ['Avg_Assists_Prev_5', 'Avg_Rebounds_Prev_5']]
        elif target_variable in ['REB', 'AST']:
            features = [feature for feature in features if feature not in ['Avg_Assists_Prev_5', 'Avg_Points_Prev_5']]

        # Rest of the code remains unchanged...
        # ... (Continuation from the original code)

        average_value = player_data[target_variable].mean()
        relative_threshold_percentage = 10  # Adjust this percentage based on your preference

        # Convert the percentage to an absolute value
        range_threshold = average_value * (relative_threshold_percentage / 100)

        # Features and target variable
        X = player_data[features]
        y = player_data[target_variable]

        # Normalize features
        scaler = StandardScaler()
        X_normalized = scaler.fit_transform(X)

        # Split data into train and test sets (80% train, 20% test)
        X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

        # Creating different models
        models = [
            LinearRegression(),
            Lasso(),
            Ridge(),
            DecisionTreeRegressor(),
            RandomForestRegressor(),
            xgb.XGBRegressor()  # Adding XGBoost Regressor
        ]

        # Train and evaluate each model
        best_model = None
        best_accuracy = 0  # Initialize with 0, as higher accuracy is better
        for model in models:
            model.fit(X_train, y_train)
            predictions = model.predict(X_test)

            # Calculate accuracy based on the specified range (-2 to 2)
            correct_predictions = ((predictions >= y_test - range_threshold) & (predictions <= y_test + range_threshold)).sum()
            total_predictions = len(predictions)
            accuracy = correct_predictions / total_predictions

            if accuracy > best_accuracy:
                best_accuracy = accuracy
                print(player, target_variable, best_accuracy, range_threshold)
                best_model = model

        # Check if the best model is not None before proceeding
        if best_model is not None:
            # Get the top 10 coefficients from the best model
            if hasattr(best_model, 'coef_'):
                coef_abs = abs(best_model.coef_)
            elif hasattr(best_model, 'feature_importances_'):
                coef_abs = abs(best_model.feature_importances_)
            else:
                coef_abs = best_model.feature_importances_

            top_10_indices = coef_abs.argsort()[-15:][::-1]  # Indexes of top 10 coefficients
            top_10_features = [features[i] for i in top_10_indices]

            # Refit the best model with the top 10 features
            X_top_10 = X[top_10_features]
            scaler.fit(X_top_10)  # Refit scaler with the top 10 features
            X_top_10_normalized = scaler.transform(X_top_10)

            best_model.fit(X_top_10_normalized, y)  # Refit the best model with the top 10 features

            # Calculate accuracy for the best model using the top 10 features
            predictions_top_10 = best_model.predict(X_test[:, top_10_indices])
            correct_predictions_top_10 = (
                (predictions_top_10 >= y_test - range_threshold) & (predictions_top_10 <= y_test + range_threshold)).sum()
            total_predictions_top_10 = len(predictions_top_10)
            accuracy_top_10 = correct_predictions_top_10 / total_predictions_top_10

            # Store the best model, top 10 features, and accuracy for the player and target variable
            player_best_models[player][target_variable] = {'model': best_model,
                                                            'top_10_features': top_10_features,
                                                            'score': accuracy_top_10}
# Out:
# Aaron Gordon PTS 0.14285714285714285 1.3818181818181818
# Aaron Gordon PTS 0.2857142857142857 1.3818181818181818
# Aaron Gordon REB 0.14285714285714285 0.6575757575757577
# Aaron Gordon AST 0.2857142857142857 0.3212121212121212
# Aaron Nesmith PTS 0.42857142857142855 1.1714285714285715
# Aaron Nesmith REB 0.14285714285714285 0.32571428571428573
# Aaron Nesmith REB 0.2857142857142857 0.32571428571428573
# Aaron Nesmith AST 0.14285714285714285 0.11142857142857143
# Aaron Nesmith AST 0.2857142857142857 0.11142857142857143
# Al Horford PTS 0.14285714285714285 0.7741935483870969
# Al Horford PTS 0.2857142857142857 0.7741935483870969
# Al Horford REB 0.14285714285714285 0.6870967741935484
# Al Horford REB 0.2857142857142857 0.6870967741935484
# Al Horford AST 0.2857142857142857 0.3032258064516129
# Alex Caruso PTS 0.14285714285714285 0.9906250000000001
# Alex Caruso REB 0.14285714285714285 0.353125
# Alex Caruso AST 0.2857142857142857 0.25
# Alperen Sengun PTS 0.125 2.155555555555556
# Alperen Sengun PTS 0.25 2.155555555555556
# Alperen Sengun PTS 0.375 2.155555555555556
# Alperen Sengun REB 0.375 0.9
# Alperen Sengun AST 0.375 0.49722222222222223
# Andrew Wiggins PTS 0.42857142857142855 1.1727272727272726
# Andrew Wiggins PTS 0.5714285714285714 1.1727272727272726
# Andrew Wiggins REB 0.14285714285714285 0.4121212121212121
# Andrew Wiggins REB 0.2857142857142857 0.4121212121212121
# Andrew Wiggins AST 0.14285714285714285 0.1303030303030303
# Anthony Davis PTS 0.25 2.566666666666667
# Anthony Davis PTS 0.375 2.566666666666667
# Anthony Davis REB 0.25 1.2194444444444446
# Anthony Davis AST 0.125 0.3388888888888889
# Anthony Edwards PTS 0.2857142857142857 2.6294117647058823
# Anthony Edwards REB 0.14285714285714285 0.5352941176470588
# Anthony Edwards REB 0.2857142857142857 0.5352941176470588
# Anthony Edwards AST 0.2857142857142857 0.4882352941176471
# Keegan Murray PTS 0.2857142857142857 1.6181818181818184
# Keegan Murray REB 0.14285714285714285 0.5545454545454546
# Keegan Murray REB 0.2857142857142857 0.5545454545454546
# Keegan Murray AST 0.2857142857142857 0.1606060606060606
# Keldon Johnson PTS 0.2857142857142857 1.7529411764705884
# Keldon Johnson REB 0.14285714285714285 0.6147058823529412
# Keldon Johnson AST 0.14285714285714285 0.3764705882352941
# Keldon Johnson AST 0.2857142857142857 0.3764705882352941
# Kelly Oubre Jr. REB 0.2 0.41600000000000004
# Kelly Oubre Jr. REB 0.4 0.41600000000000004
# Kelly Oubre Jr. AST 0.2 0.10800000000000001
# Kelly Oubre Jr. AST 0.4 0.10800000000000001
# Kelly Oubre Jr. AST 0.6 0.10800000000000001
# Kentavious Caldwell-Pope PTS 0.125 1.010810810810811
# Kentavious Caldwell-Pope PTS 0.375 1.010810810810811
# Kentavious Caldwell-Pope REB 0.125 0.2189189189189189
# Kentavious Caldwell-Pope REB 0.25 0.2189189189189189
# Kentavious Caldwell-Pope AST 0.125 0.25675675675675674
# Kevin Durant PTS 0.5 2.9633333333333334
# Kevin Durant REB 0.16666666666666666 0.6400000000000001
# Kevin Huerter PTS 0.125 0.9500000000000001
# Kevin Huerter REB 0.25 0.35555555555555557
# Kevin Huerter AST 0.125 0.25
# Keyonte George PTS 0.14285714285714285 1.087878787878788
# Keyonte George PTS 0.2857142857142857 1.087878787878788
# Keyonte George REB 0.14285714285714285 0.30000000000000004
# Keyonte George REB 0.2857142857142857 0.30000000000000004
# Keyonte George AST 0.2857142857142857 0.44545454545454544
# Khris Middleton PTS 0.14285714285714285 1.46875
# Khris Middleton PTS 0.2857142857142857 1.46875
# Khris Middleton REB 0.14285714285714285 0.44062500000000004
# Khris Middleton REB 0.2857142857142857 0.44062500000000004
# Khris Middleton REB 0.42857142857142855 0.44062500000000004
# Khris Middleton AST 0.2857142857142857 0.49375
# Killian Hayes PTS 0.42857142857142855 0.7575757575757577
# Killian Hayes REB 0.14285714285714285 0.29090909090909095
# Killian Hayes AST 0.14285714285714285 0.4636363636363637
# Killian Hayes AST 0.2857142857142857 0.4636363636363637
# Klay Thompson PTS 0.375 1.7055555555555557
# Klay Thompson PTS 0.5 1.7055555555555557
# Klay Thompson REB 0.125 0.35555555555555557
# Klay Thompson REB 0.375 0.35555555555555557
# Klay Thompson AST 0.125 0.22222222222222224
# Klay Thompson AST 0.25 0.22222222222222224
# Kristaps Porzingis PTS 0.16666666666666666 1.9777777777777779
# Kristaps Porzingis PTS 0.5 1.9777777777777779
# Kristaps Porzingis REB 0.16666666666666666 0.7000000000000001
# Kristaps Porzingis REB 0.3333333333333333 0.7000000000000001
# Kristaps Porzingis AST 0.3333333333333333 0.1851851851851852
# Kyle Kuzma PTS 0.25 2.2243243243243245
# Kyle Kuzma PTS 0.375 2.2243243243243245
# Kyle Kuzma REB 0.25 0.6216216216216216
# Kyle Kuzma AST 0.25 0.41891891891891897
# Kyle Lowry PTS 0.2857142857142857 0.915625
# Kyle Lowry REB 0.14285714285714285 0.35625
# Trae Young PTS 0.42857142857142855 2.782352941176471
# Trae Young REB 0.14285714285714285 0.30000000000000004
# Trae Young REB 0.2857142857142857 0.30000000000000004
# Trae Young REB 0.42857142857142855 0.30000000000000004
# Trae Young AST 0.5714285714285714 1.1029411764705883
# Tre Jones PTS 0.14285714285714285 0.86875
# Tre Jones REB 0.14285714285714285 0.28750000000000003
# Tre Jones REB 0.42857142857142855 0.28750000000000003
# Tre Jones AST 0.14285714285714285 0.49062500000000003
# Tyrese Haliburton PTS 0.2857142857142857 2.3636363636363638
# Tyrese Haliburton REB 0.14285714285714285 0.4212121212121212
# Tyrese Haliburton REB 0.42857142857142855 0.4212121212121212
# Tyrese Haliburton AST 0.2857142857142857 1.2454545454545456
# Tyrese Maxey PTS 0.14285714285714285 2.62
# Tyrese Maxey PTS 0.2857142857142857 2.62
# Tyrese Maxey PTS 0.42857142857142855 2.62
# Tyrese Maxey REB 0.14285714285714285 0.37428571428571433
# Tyus Jones PTS 0.125 1.264864864864865
# Tyus Jones PTS 0.375 1.264864864864865
# Tyus Jones REB 0.25 0.2810810810810811
# Tyus Jones AST 0.125 0.5513513513513514
# Victor Wembanyama PTS 0.14285714285714285 1.921875
# Victor Wembanyama REB 0.14285714285714285 1.01875
# Victor Wembanyama REB 0.2857142857142857 1.01875
# Victor Wembanyama AST 0.2857142857142857 0.30625
# Victor Wembanyama AST 0.42857142857142855 0.30625
# Victor Wembanyama AST 0.5714285714285714 0.30625
# Walker Kessler PTS 0.14285714285714285 0.8806451612903227
# Walker Kessler PTS 0.42857142857142855 0.8806451612903227
# Walker Kessler REB 0.14285714285714285 0.7741935483870969
# Walker Kessler AST 0.14285714285714285 0.07419354838709678
# Walker Kessler AST 0.42857142857142855 0.07419354838709678
# Zach Collins PTS 0.14285714285714285 1.2935483870967743
# Zach Collins PTS 0.2857142857142857 1.2935483870967743
# Zach Collins REB 0.14285714285714285 0.5967741935483871
# Zach Collins REB 0.2857142857142857 0.5967741935483871
# Zach Collins AST 0.14285714285714285 0.3290322580645162
# Zach LaVine PTS 0.2 2.033333333333333
# Zach LaVine PTS 0.6 2.033333333333333
# Zach LaVine REB 0.4 0.5190476190476191
# Zach LaVine AST 0.2 0.3666666666666667
# Zach LaVine AST 0.6 0.3666666666666667
# Zion Williamson PTS 0.14285714285714285 2.1709677419354843
# Zion Williamson PTS 0.5714285714285714 2.1709677419354843
# Zion Williamson REB 0.14285714285714285 0.5935483870967743
# Zion Williamson REB 0.2857142857142857 0.5935483870967743
# Zion Williamson AST 0.14285714285714285 0.46129032258064523

# %%
t = {k: v for k, v in player_best_models.items() if v}
my_dict = {k: t[k] for k in set(t)}


# Remove duplicates using dictionary comprehension
player_best_models = {k: v for k, v in my_dict.items() if list(my_dict.keys()).count(k) == 1}

# Filter out entries with None values for 'PTS', 'REB', or 'AST'
player_best_models = {
    player: stats
    for player, stats in player_best_models.items()
    if all(stats.get(key) is not None for key in ['PTS', 'REB', 'AST'])
}

# %%
import pandas as pd

# Create empty lists to store player scores for each category
pts_scores = []
reb_scores = []
ast_scores = []

# Iterate through each player in the player_best_models dictionary
for player, stats in player_best_models.items():
    if 'PTS' in stats and stats['PTS'] is not None and 'score' in stats['PTS']:
        pts_score = stats['PTS']['score']  # Get the PTS score for each player
        pts_scores.append({'Player': player, 'PTS_Score': pts_score})

    if 'REB' in stats and stats['REB'] is not None and 'score' in stats['REB']:
        reb_score = stats['REB']['score']  # Get the REB score for each player
        reb_scores.append({'Player': player, 'REB_Score': reb_score})

    if 'AST' in stats and stats['AST'] is not None and 'score' in stats['AST']:
        ast_score = stats['AST']['score']  # Get the AST score for each player
        ast_scores.append({'Player': player, 'AST_Score': ast_score})

# Create DataFrames from the player scores for each category
pts_scores_df = pd.DataFrame(pts_scores)
reb_scores_df = pd.DataFrame(reb_scores)
ast_scores_df = pd.DataFrame(ast_scores)

# Find top 5 players based on PTS score
if not pts_scores_df.empty:
    top_5_pts_players = pts_scores_df.nlargest(5, 'PTS_Score')
    print("Top 5 Players based on PTS Score:")
    print(top_5_pts_players)
else:
    print("No available PTS scores for any player.")

# Find top 5 players based on REB score
if not reb_scores_df.empty:
    top_5_reb_players = reb_scores_df.nlargest(5, 'REB_Score')
    print("\nTop 5 Players based on REB Score:")
    print(top_5_reb_players)
else:
    print("\nNo available REB scores for any player.")

# Find top 5 players based on AST score
if not ast_scores_df.empty:
    top_5_ast_players = ast_scores_df.nlargest(5, 'AST_Score')
    print("\nTop 5 Players based on AST Score:")
    print(top_5_ast_players)
else:
    print("\nNo available AST scores for any player.")
# Out:
# Top 5 Players based on PTS Score:
#              Player  PTS_Score
# 7       Jalen Green        1.0
# 11    Stephen Curry        1.0
# 12     LeBron James        1.0
# 13  Dejounte Murray        1.0
# 14        Max Strus        1.0
#
# Top 5 Players based on REB Score:
#                       Player  REB_Score
# 13           Dejounte Murray        1.0
# 14                 Max Strus        1.0
# 15           Zion Williamson        1.0
# 23             Aaron Nesmith        1.0
# 24  Kentavious Caldwell-Pope        1.0
#
# Top 5 Players based on AST Score:
#             Player  AST_Score
# 2    Devin Vassell        1.0
# 5      Ivica Zubac        1.0
# 9   Daniel Gafford        1.0
# 11   Stephen Curry        1.0
# 19   Kevin Huerter        1.0

# %%
import re

team_mapping = {
    'Atlanta': 'ATL', 'Boston': 'BOS', 'Brooklyn': 'BKN', 'Charlotte': 'CHA',
    'Chicago': 'CHI', 'Cleveland': 'CLE', 'Dallas': 'DAL', 'Denver': 'DEN',
    'Detroit': 'DET', 'Golden State': 'GSW', 'Houston': 'HOU', 'Indiana': 'IND',
    'LA': 'LAC', 'Los Angeles': 'LAL', 'Memphis': 'MEM', 'Miami': 'MIA',
    'Milwaukee': 'MIL', 'Minnesota': 'MIN', 'New Orleans': 'NOP', 'New York': 'NYK',
    'Oklahoma City': 'OKC', 'Orlando': 'ORL', 'Philadelphia': 'PHI', 'Phoenix': 'PHX',
    'Portland': 'POR', 'Sacramento': 'SAC', 'San Antonio': 'SAS', 'Toronto': 'TOR',
    'Utah': 'UTA', 'Washington': 'WAS'
}

text = """
MATCHUP
TIME
TV
TICKETS

Brooklyn
  @

Cleveland
2:00 PM
NBA TV
Tickets as low as $105

Boston
  @

Milwaukee
7:30 PM
TNT
Tickets as low as $28

Portland
  @

Oklahoma City
8:00 PM		Tickets as low as $8

New York
  @

Dallas
8:30 PM		Tickets as low as $18

Phoenix
  @

Los Angeles
10:00 PM
TNT
Tickets as low as $67
"""

lines = text.split('\n')

# Remove empty lines and header rows
relevant_lines = [line.strip() for line in lines if line.strip() and line.strip() != 'MATCHUP' and line.strip() != 'TIME' and line.strip() != 'TV' and line.strip() != 'TICKETS']

team_abbreviations = [team_mapping[line] for line in relevant_lines if line in team_mapping]
team_opponent_pairs = [(team_abbreviations[i], team_abbreviations[i + 1]) for i in range(0, len(team_abbreviations), 2)]

# Display team-opponent pairs
for pair in team_opponent_pairs:
    print(pair)
# Out:
# ('BKN', 'CLE')
# ('BOS', 'MIL')
# ('POR', 'OKC')
# ('NYK', 'DAL')
# ('PHX', 'LAL')

# %%
player_teams = pd.read_csv('/content/drive/MyDrive/PlayerTeam.csv')

predict_data_temp = []
for team, opponent in team_opponent_pairs:
    # Filter players by the team
    team_players = player_teams[player_teams['Team'] == team]['Player']
    # Create rows for each player with their respective opponent
    for player in team_players:
        predict_data_temp.append({'Player': player, 'OPP': opponent})

    # Similarly, now get the players from the opponent team
    opponent_players = player_teams[player_teams['Team'] == opponent]['Player']
    # Create rows for each player with their respective opponent (opponent team)
    for player in opponent_players:
        predict_data_temp.append({'Player': player, 'OPP': team})

# Create DataFrame
predict_data = pd.DataFrame(predict_data_temp)
predict_data
# Out:
#                Player  OPP
# 0          Cam Thomas  CLE
# 1       Mikal Bridges  CLE
# 2     Cameron Johnson  CLE
# 3   Spencer Dinwiddie  CLE
# 4         Nic Claxton  CLE
# ..                ...  ...
# 63   D'Angelo Russell  PHX
# 64      Rui Hachimura  PHX
# 65     Taurean Prince  PHX
# 66        Cam Reddish  PHX
# 67       Gabe Vincent  PHX
#
# [68 rows x 2 columns]

# %%
predict_data = pd.merge(predict_data, player_positions, on='Player', how='left')
predict_data['Pos'] = predict_data['Pos'].replace(position_mapping)

# Filter positions to keep only 'PG', 'SG', 'SF', 'PF', 'C'
predict_data = predict_data[predict_data['Pos'].isin(['PG', 'SG', 'SF', 'PF', 'C'])]
predict_data
# Out:
#                Player  OPP Pos
# 0          Cam Thomas  CLE  PG
# 1       Mikal Bridges  CLE  SG
# 2     Cameron Johnson  CLE  PG
# 3   Spencer Dinwiddie  CLE  PG
# 4         Nic Claxton  CLE   C
# ..                ...  ...  ..
# 63   D'Angelo Russell  PHX  SG
# 64      Rui Hachimura  PHX  SF
# 65     Taurean Prince  PHX  SF
# 66        Cam Reddish  PHX  PG
# 67       Gabe Vincent  PHX  PG
#
# [68 rows x 3 columns]

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

def preprocess_player_name(player_name):
    # Add your custom logic to handle variations in player names
    name_parts = player_name.split()
    if len(name_parts) == 2 and all(len(part) == 2 for part in name_parts):
        return f"{name_parts[0][0]}.{name_parts[1][0]}. {name_parts[1]}"
    else:
        return player_name

url = "https://www.numberfire.com/nba/daily-fantasy/daily-basketball-projections"
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all rows in the table
    rows = soup.find_all('tr', class_='')

    # Create lists to store player names and projected minutes
    player_names = []
    projected_minutes = []

    # Loop through each row and extract player name and projected minutes
    for row in rows:
        # Extract player name
        player_name_elem = row.find('a', class_='full')
        player_name = player_name_elem.contents[0].strip() if player_name_elem else None

        # Preprocess player name
        if player_name:
          player_name = preprocess_player_name(player_name)

        # Extract projected minutes
        minutes_elem = row.find('td', class_='min')
        minutes = minutes_elem.get_text(strip=True) if minutes_elem else None

        # Append data to lists
        player_names.append(player_name)
        projected_minutes.append(minutes)

    # Create a DataFrame named PlayerMinutes
    PlayerMinutes = pd.DataFrame({'Player': player_names, 'MIN': projected_minutes})

    # Display the DataFrame
    print(PlayerMinutes)
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
#                       Player    MIN
# 0                       None   None
# 1                       None   None
# 2      Giannis Antetokounmpo  36.04
# 3              Anthony Davis  38.61
# 4    Shai Gilgeous-Alexander  35.77
# ..                       ...    ...
# 123              Luka Doncic   0.00
# 124              Maxi Kleber   0.00
# 125         Ryan Arcidiacono   0.10
# 126               Dante Exum   0.00
# 127              Robin Lopez   0.09
#
# [128 rows x 2 columns]

# %%
PlayerMinutes.dropna(inplace=True)
PlayerMinutes.reset_index(drop=True,inplace=True)
predict_data = pd.merge(predict_data, PlayerMinutes, on='Player', how='left')
PlayerMinutes.head(25)
# Out:
#                      Player    MIN
# 0     Giannis Antetokounmpo  36.04
# 1             Anthony Davis  38.61
# 2   Shai Gilgeous-Alexander  35.77
# 3              LeBron James  37.62
# 4              Kyrie Irving  36.87
# 5             Julius Randle  36.58
# 6              Jayson Tatum  38.17
# 7              Kevin Durant  35.41
# 8             Jalen Brunson  36.56
# 9            Damian Lillard  35.50
# 10             Devin Booker  35.25
# 11            Chet Holmgren  32.00
# 12             Jaylen Brown  38.17
# 13       Kristaps Porzingis  31.18
# 14             Jusuf Nurkic  30.21
# 15             Jrue Holiday  33.28
# 16             Bradley Beal  35.24
# 17          Khris Middleton  32.42
# 18          Anfernee Simons  32.85
# 19              Brook Lopez  32.42
# 20           Jalen Williams  33.31
# 21       Isaiah Hartenstein  35.60
# 22              Josh Giddey  25.93
# 23            Derrick White  32.21
# 24             Jerami Grant  32.85

# %%
temp_df = predict_data.merge(DefenseVsPosition, left_on=['OPP', 'Pos'], right_on=['Team', 'Position'], how='left')

print(temp_df.shape)
opp_columns = {
    'PTS': 'OPP_PTSvsPos',
    'REB': 'OPP_REBvsPos',
    'AST': 'OPP_ASTvsPos',
    'STL': 'OPP_STLvsPos',
    'BLK': 'OPP_BLKvsPos',
    'TO': 'OPP_TOVvsPos'
}
# Rename columns in the DataFrame
today_data = temp_df.rename(columns={**opp_columns})
print(today_data.shape)
selected_columns = ['Player', 'Pos', 'OPP','MIN','OPP_PTSvsPos', 'OPP_REBvsPos', 'OPP_ASTvsPos', 'OPP_STLvsPos', 'OPP_BLKvsPos', 'OPP_TOVvsPos']
today_data = today_data[selected_columns]
today_data = pd.merge(today_data, TeamOpponent, left_on='OPP', right_on='TEAM')
print(today_data.head())
today_data = pd.merge(today_data,pt_pwr,on=['OPP']).dropna()
print(today_data.shape)
# Out:
# (68, 15)
# (68, 15)
#               Player Pos  OPP  MIN  OPP_PTSvsPos  OPP_REBvsPos  OPP_ASTvsPos  \
# 0         Cam Thomas  PG  CLE  NaN          24.5           5.9           7.2
# 1      Mikal Bridges  SG  CLE  NaN          19.6           6.2           4.4
# 2    Cameron Johnson  PG  CLE  NaN          24.5           5.9           7.2
# 3  Spencer Dinwiddie  PG  CLE  NaN          24.5           5.9           7.2
# 4        Nic Claxton   C  CLE  NaN          22.6          14.2           3.9
#
#    OPP_STLvsPos  OPP_BLKvsPos  OPP_TOVvsPos  ... OPP_DREB  OPP_REB  OPP_AST  \
# 0           2.0           0.6           3.1  ...     31.0     39.9     24.0
# 1           1.5           0.7           2.6  ...     31.0     39.9     24.0
# 2           2.0           0.6           3.1  ...     31.0     39.9     24.0
# 3           2.0           0.6           3.1  ...     31.0     39.9     24.0
# 4           1.3           2.5           2.8  ...     31.0     39.9     24.0
#
#    OPP_TOV  OPP_STL  OPP_BLK  OPP_BLKA  OPP_PF  OPP_PFD  OPP_PTS
# 0     13.1      7.5      6.0       3.7    19.6     19.5    112.1
# 1     13.1      7.5      6.0       3.7    19.6     19.5    112.1
# 2     13.1      7.5      6.0       3.7    19.6     19.5    112.1
# 3     13.1      7.5      6.0       3.7    19.6     19.5    112.1
# 4     13.1      7.5      6.0       3.7    19.6     19.5    112.1
#
# [5 rows x 31 columns]
# (49, 32)

# %%
today_data.dropna(inplace=True)

# %%
from nba_api.stats.static import players
from nba_api.stats.endpoints import playergamelog
import pandas as pd

# Get the list of NBA players
nba_players = players.get_players()

# Create a dictionary mapping player names to player IDs
player_name_to_id = {player['full_name']: player['id'] for player in nba_players}

# Function to fetch last 5 games' stats for a player
def get_last_5_games_stats(player_id, season):
    gamelog = playergamelog.PlayerGameLog(player_id=player_id, season=season)
    gamelog_data = gamelog.get_data_frames()[0]
    last_5_games = gamelog_data.head(6)  # Considering the data is already sorted by the latest games
    return last_5_games

# Create an empty DataFrame to store the results
all_players_last_5_stats = pd.DataFrame(columns=['Player', 'PTS', 'REB', 'AST', 'MIN'])

# Loop through each player in the DataFrame and fetch their last 5 games' stats
for player_name in today_data['Player']:
    if player_name in player_name_to_id:
        player_id = player_name_to_id[player_name]
        player_stats = get_last_5_games_stats(player_id, '2023-24')  # Replace '2023-24' with the desired season
        player_stats['Player'] = player_name  # Add a 'Player' column with player's name
        all_players_last_5_stats = pd.concat([all_players_last_5_stats, player_stats])


# Select only the desired columns
all_players_last_5_stats = all_players_last_5_stats[['Player', 'PTS', 'REB', 'AST']]

# Rename columns for clarity
all_players_last_5_stats.rename(columns={
    'Player': 'Player',
    'PTS': 'Avg_Points_Prev_5',
    'REB': 'Avg_Rebounds_Prev_5',
    'AST': 'Avg_Assists_Prev_5'
}, inplace=True)

# Calculate the average per-minute stats for each player
average_stats_per_minute = all_players_last_5_stats.groupby('Player').mean().reset_index()

print("\nAverage per-minute statistics for each player:")
print(average_stats_per_minute)
# Out:
# Average per-minute statistics for each player:
#                      Player  Avg_Points_Prev_5  Avg_Rebounds_Prev_5  \
# 0                Al Horford           8.666667             5.833333
# 1           Anfernee Simons          20.833333             4.000000
# 2             Anthony Davis          29.333333            11.833333
# 3             Austin Reaves          15.166667             3.166667
# 4              Bobby Portis           7.500000             4.833333
# 5              Bradley Beal          19.833333             4.500000
# 6               Brook Lopez          12.500000             5.833333
# 7               Cam Reddish           6.166667             1.666667
# 8             Chet Holmgren          19.166667             5.833333
# 9          D'Angelo Russell          11.333333             1.166667
# 10           Damian Lillard          20.333333             3.333333
# 11            Deandre Ayton          13.500000            10.666667
# 12        Derrick Jones Jr.           8.833333             4.166667
# 13            Derrick White          12.500000             5.000000
# 14             Devin Booker          21.666667             3.166667
# 15              Eric Gordon          14.666667             2.000000
# 16    Giannis Antetokounmpo          34.500000            14.333333
# 17           Grant Williams           5.500000             2.166667
# 18            Grayson Allen          14.500000             2.833333
# 19       Isaiah Hartenstein           8.166667            12.833333
# 20            Jalen Brunson          24.833333             2.833333
# 21           Jalen Williams          19.000000             4.666667
# 22             Jaylen Brown          26.333333             5.833333
# 23             Jayson Tatum          33.166667             8.666667
# 24             Jerami Grant          19.666667             2.166667
# 25              Josh Giddey          13.833333             6.333333
# 26               Josh Green           7.333333             3.166667
# 27                Josh Hart           7.000000             8.666667
# 28             Jrue Holiday          12.833333             5.000000
# 29            Julius Randle          28.166667             8.000000
# 30             Jusuf Nurkic          13.000000             9.500000
# 31             Kevin Durant          24.666667             7.333333
# 32          Khris Middleton          16.333333             3.500000
# 33       Kristaps Porzingis          20.500000             6.666667
# 34             Kyrie Irving          24.333333             7.500000
# 35             LeBron James          25.166667             5.333333
# 36            Luguentz Dort          12.333333             4.166667
# 37              Luka Doncic          33.833333             6.500000
# 38          Malcolm Brogdon          11.000000             2.000000
# 39            Malik Beasley          10.833333             2.833333
# 40         Matisse Thybulle           4.333333             2.000000
# 41               OG Anunoby          13.833333             4.500000
# 42            Rui Hachimura          12.833333             3.166667
# 43          Scoot Henderson          13.500000             4.000000
# 44           Shaedon Sharpe          11.166667             2.666667
# 45  Shai Gilgeous-Alexander          31.166667             6.666667
# 46           Taurean Prince           9.666667             2.500000
# 47         Tim Hardaway Jr.          12.666667             3.333333
# 48           Toumani Camara           7.333333             7.000000
#
#     Avg_Assists_Prev_5
# 0             3.833333
# 1             4.333333
# 2             4.666667
# 3             6.333333
# 4             0.333333
# 5             3.833333
# 6             1.333333
# 7             1.000000
# 8             3.500000
# 9             5.333333
# 10            6.000000
# 11            1.666667
# 12            0.833333
# 13            4.666667
# 14            6.666667
# 15            1.000000
# 16            7.333333
# 17            1.000000
# 18            3.333333
# 19            3.333333
# 20            8.333333
# 21            6.500000
# 22            2.833333
# 23            5.500000
# 24            2.166667
# 25            5.166667
# 26            1.666667
# 27            2.833333
# 28            4.333333
# 29            4.333333
# 30            3.000000
# 31            7.666667
# 32            7.000000
# 33            2.333333
# 34            4.166667
# 35            8.166667
# 36            1.833333
# 37            8.166667
# 38            3.166667
# 39            0.500000
# 40            0.333333
# 41            1.166667
# 42            0.666667
# 43            7.000000
# 44            1.333333
# 45            6.666667
# 46            1.833333
# 47            2.000000
# 48            1.000000

# %%
average_stats = average_stats_per_minute.copy()
today_data = pd.merge(today_data,average_stats,on = 'Player')

# %%
t = {k: v for k, v in player_best_models.items() if v}
my_dict = {k: t[k] for k in set(t)}


# Remove duplicates using dictionary comprehension
player_best_models = {k: v for k, v in my_dict.items() if list(my_dict.keys()).count(k) == 1}

# Filter out entries with None values for 'PTS', 'REB', or 'AST'
player_best_models = {
    player: stats
    for player, stats in player_best_models.items()
    if all(stats.get(key) is not None for key in ['PTS', 'REB', 'AST'])
}

player_best_models
# Out:
# {'Shai Gilgeous-Alexander': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'Avg_Points_Prev_5',
#     'OPP_BLKA',
#     'OPP_FT_PCT',
#     'OPP_STL',
#     'OPP_STLvsPos',
#     'OPP_BLK',
#     'OPP_ASTvsPos',
#     'OPP_FG3A',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_REBvsPos',
#     'OPP_PTSvsPos'],
#    'score': 0.7142857142857143},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.14285714285714285},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['OPP_PTSvsPos',
#     'OPP_FTM',
#     'PT_PWR',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.5714285714285714}},
#  'Patrick Williams': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['OPP_TOV',
#     'OPP_REBvsPos',
#     'OPP_PF',
#     'OPP_BLKvsPos',
#     'OPP_STL',
#     'OPP_AST',
#     'MIN',
#     'OPP_DREB',
#     'OPP_FG3A',
#     'OPP_REB',
#     'OPP_BLK',
#     'OPP_FGA',
#     'OPP_TOVvsPos',
#     'OPP_FTA',
#     'OPP_FTM'],
#    'score': 0.375},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.125},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_FTA',
#     'OPP_BLKvsPos',
#     'OPP_REBvsPos',
#     'OPP_PFD',
#     'OPP_PTSvsPos',
#     'OPP_FG3_PCT',
#     'OPP_BLKA',
#     'OPP_OREB',
#     'OPP_FG_PCT',
#     'OPP_FT_PCT',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'OPP_TOV',
#     'OPP_FGA',
#     'OPP_FG3M'],
#    'score': 0.0}},
#  'Devin Vassell': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_AST',
#     'OPP_FG3_PCT',
#     'OPP_PF',
#     'OPP_DREB',
#     'OPP_PTSvsPos',
#     'OPP_REB',
#     'OPP_FG3M',
#     'OPP_REBvsPos',
#     'MIN',
#     'OPP_BLKA',
#     'OPP_PFD',
#     'OPP_TOVvsPos',
#     'PT_PWR'],
#    'score': 0.14285714285714285},
#   'REB': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_FG_PCT',
#     'Avg_Rebounds_Prev_5',
#     'OPP_OREB',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_FGM',
#     'OPP_FG3M',
#     'OPP_FTA',
#     'OPP_ASTvsPos',
#     'OPP_PTS',
#     'OPP_FG3A',
#     'OPP_REBvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos'],
#    'score': 0.7142857142857143},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_STLvsPos',
#     'Avg_Rebounds_Prev_5',
#     'MIN',
#     'OPP_AST',
#     'OPP_PFD',
#     'OPP_PTSvsPos',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT'],
#    'score': 1.0}},
#  'Dennis Schroder': {'PTS': {'model': Lasso(),
#    'top_10_features': ['OPP_AST',
#     'OPP_PTSvsPos',
#     'OPP_STL',
#     'OPP_PFD',
#     'MIN',
#     'OPP_BLKvsPos',
#     'OPP_REB',
#     'OPP_FG3A',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT'],
#    'score': 0.375},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_REB',
#     'OPP_FTA',
#     'OPP_DREB',
#     'OPP_FG_PCT',
#     'OPP_FTM',
#     'OPP_FGA',
#     'OPP_PTS',
#     'OPP_FGM',
#     'OPP_OREB',
#     'OPP_FT_PCT',
#     'OPP_FG3_PCT',
#     'OPP_FG3A',
#     'OPP_FG3M',
#     'OPP_PTSvsPos',
#     'OPP_BLK'],
#    'score': 0.125},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_REB',
#     'OPP_FGA',
#     'OPP_OREB',
#     'OPP_FG3M',
#     'OPP_FTA',
#     'OPP_FGM',
#     'OPP_PTS',
#     'OPP_DREB',
#     'OPP_FG_PCT',
#     'OPP_FG3_PCT',
#     'OPP_FTM',
#     'OPP_FG3A',
#     'OPP_AST',
#     'OPP_PFD',
#     'OPP_PTSvsPos'],
#    'score': 0.5}},
#  'Miles Bridges': {'PTS': {'model': Lasso(),
#    'top_10_features': ['OPP_AST',
#     'MIN',
#     'OPP_PF',
#     'OPP_STL',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M'],
#    'score': 0.6},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['MIN',
#     'OPP_PTSvsPos',
#     'OPP_PFD',
#     'OPP_BLK',
#     'OPP_OREB',
#     'OPP_FG3A',
#     'OPP_FG3M',
#     'OPP_BLKvsPos',
#     'OPP_FG3_PCT',
#     'OPP_TOV',
#     'OPP_REB',
#     'OPP_FT_PCT',
#     'OPP_PF',
#     'OPP_ASTvsPos',
#     'PT_PWR'],
#    'score': 0.8},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.2}},
#  'Ivica Zubac': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_PF',
#     'OPP_FG3M',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3A',
#     'OPP_FG3_PCT'],
#    'score': 0.25},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_FG3A',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3_PCT',
#     'PT_PWR'],
#    'score': 0.375},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_FT_PCT',
#     'Avg_Rebounds_Prev_5',
#     'OPP_REBvsPos',
#     'OPP_FGA',
#     'OPP_FG3_PCT',
#     'OPP_FG_PCT',
#     'MIN',
#     'OPP_TOVvsPos',
#     'OPP_BLK',
#     'OPP_PTSvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_FGM',
#     'OPP_FG3M'],
#    'score': 1.0}},
#  'Cole Anthony': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_BLKA',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT'],
#    'score': 0.25},
#   'REB': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_BLK',
#     'OPP_FTM',
#     'OPP_BLKvsPos',
#     'OPP_PF',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FG3A',
#     'OPP_PFD',
#     'OPP_STLvsPos',
#     'OPP_STL',
#     'OPP_TOV',
#     'OPP_FG3M',
#     'PT_PWR',
#     'OPP_PTSvsPos',
#     'OPP_ASTvsPos'],
#    'score': 0.375},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_ASTvsPos',
#     'OPP_STL',
#     'OPP_FG_PCT',
#     'OPP_TOVvsPos',
#     'OPP_FG3_PCT',
#     'OPP_FGA',
#     'OPP_BLKvsPos',
#     'OPP_DREB',
#     'OPP_REB',
#     'PT_PWR',
#     'OPP_TOV',
#     'OPP_FG3M',
#     'MIN',
#     'OPP_AST',
#     'OPP_FTM'],
#    'score': 0.125}},
#  'Jalen Green': {'PTS': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=None, ...),
#    'top_10_features': ['OPP_TOV',
#     'OPP_FGM',
#     'OPP_BLK',
#     'OPP_OREB',
#     'OPP_AST',
#     'Avg_Points_Prev_5',
#     'OPP_REBvsPos',
#     'OPP_FT_PCT',
#     'OPP_FTM',
#     'OPP_ASTvsPos',
#     'PT_PWR',
#     'MIN',
#     'OPP_BLKA',
#     'OPP_FGA',
#     'OPP_PF'],
#    'score': 1.0},
#   'REB': {'model': Ridge(),
#    'top_10_features': ['OPP_REBvsPos',
#     'OPP_FTA',
#     'OPP_TOVvsPos',
#     'OPP_FTM',
#     'OPP_BLK',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'Avg_Rebounds_Prev_5',
#     'OPP_TOV',
#     'OPP_FG3M',
#     'PT_PWR',
#     'OPP_PF',
#     'OPP_AST',
#     'OPP_STL',
#     'OPP_FGM'],
#    'score': 0.5},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.125}},
#  'Kyrie Irving': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'PT_PWR',
#     'OPP_BLK',
#     'OPP_ASTvsPos',
#     'OPP_PTS',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M'],
#    'score': 0.0},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['OPP_STL',
#     'PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT'],
#    'score': 0.2},
#   'AST': {'model': RandomForestRegressor(),
#    'top_10_features': ['OPP_DREB',
#     'OPP_TOV',
#     'Avg_Rebounds_Prev_5',
#     'OPP_PF',
#     'OPP_BLKA',
#     'PT_PWR',
#     'MIN',
#     'OPP_FT_PCT',
#     'OPP_BLK',
#     'OPP_FG3A',
#     'OPP_PFD',
#     'OPP_OREB',
#     'OPP_FG3M',
#     'OPP_REB',
#     'OPP_FG3_PCT'],
#    'score': 0.8}},
#  'Pascal Siakam': {'PTS': {'model': RandomForestRegressor(),
#    'top_10_features': ['OPP_ASTvsPos',
#     'MIN',
#     'OPP_PTSvsPos',
#     'OPP_PFD',
#     'Avg_Points_Prev_5',
#     'OPP_REBvsPos',
#     'OPP_FTA',
#     'OPP_OREB',
#     'OPP_REB',
#     'OPP_TOVvsPos',
#     'OPP_BLKA',
#     'OPP_PF',
#     'OPP_FGA',
#     'OPP_AST',
#     'OPP_FG3A'],
#    'score': 0.375},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.5},
#   'AST': {'model': Ridge(),
#    'top_10_features': ['OPP_PFD',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_ASTvsPos',
#     'PT_PWR',
#     'OPP_STL',
#     'OPP_PF',
#     'OPP_REBvsPos',
#     'OPP_PTSvsPos',
#     'OPP_BLKvsPos',
#     'OPP_BLK',
#     'OPP_TOVvsPos',
#     'OPP_BLKA',
#     'OPP_FG3_PCT',
#     'OPP_FG3M'],
#    'score': 0.375}},
#  'Daniel Gafford': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_TOVvsPos',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'PT_PWR'],
#    'score': 0.2857142857142857},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_STLvsPos',
#     'MIN',
#     'OPP_REBvsPos',
#     'OPP_FG3A',
#     'OPP_PFD',
#     'Avg_Rebounds_Prev_5',
#     'OPP_AST',
#     'OPP_FT_PCT',
#     'OPP_PF',
#     'OPP_FGA',
#     'OPP_FTA',
#     'OPP_PTSvsPos',
#     'OPP_FG_PCT',
#     'OPP_FG3_PCT',
#     'OPP_STL'],
#    'score': 0.0},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_PFD',
#     'MIN',
#     'Avg_Rebounds_Prev_5',
#     'OPP_STLvsPos',
#     'OPP_FT_PCT',
#     'OPP_FTM',
#     'OPP_BLKA',
#     'OPP_FGM',
#     'OPP_FG_PCT',
#     'OPP_FGA',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FG3A',
#     'OPP_ASTvsPos',
#     'OPP_REBvsPos'],
#    'score': 1.0}},
#  'Stephen Curry': {'PTS': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_FGM',
#     'OPP_FTA',
#     'Avg_Points_Prev_5',
#     'OPP_PTSvsPos',
#     'OPP_FG3A',
#     'OPP_STL',
#     'OPP_TOV',
#     'OPP_PF',
#     'PT_PWR',
#     'OPP_FG3M',
#     'OPP_PTS',
#     'OPP_STLvsPos',
#     'OPP_FG_PCT',
#     'OPP_REBvsPos'],
#    'score': 1.0},
#   'REB': {'model': Ridge(),
#    'top_10_features': ['MIN',
#     'OPP_DREB',
#     'OPP_FT_PCT',
#     'OPP_FTA',
#     'OPP_AST',
#     'OPP_BLKA',
#     'OPP_REB',
#     'Avg_Rebounds_Prev_5',
#     'OPP_PF',
#     'OPP_BLKvsPos',
#     'OPP_ASTvsPos',
#     'OPP_FTM',
#     'OPP_TOVvsPos',
#     'OPP_REBvsPos',
#     'OPP_BLK'],
#    'score': 0.14285714285714285},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['Avg_Rebounds_Prev_5',
#     'OPP_PFD',
#     'MIN',
#     'OPP_STLvsPos',
#     'PT_PWR',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_ASTvsPos',
#     'OPP_FT_PCT',
#     'OPP_TOV',
#     'OPP_REB',
#     'OPP_AST',
#     'OPP_BLKA',
#     'OPP_FG_PCT',
#     'OPP_PTSvsPos'],
#    'score': 1.0}},
#  'LeBron James': {'PTS': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=None, ...),
#    'top_10_features': ['OPP_PFD',
#     'OPP_FG3A',
#     'OPP_FT_PCT',
#     'OPP_TOVvsPos',
#     'OPP_PF',
#     'Avg_Points_Prev_5',
#     'OPP_BLKvsPos',
#     'OPP_FGM',
#     'OPP_ASTvsPos',
#     'OPP_BLK',
#     'OPP_STLvsPos',
#     'OPP_OREB',
#     'OPP_FTA',
#     'MIN',
#     'OPP_AST'],
#    'score': 1.0},
#   'REB': {'model': RandomForestRegressor(),
#    'top_10_features': ['OPP_FGA',
#     'PT_PWR',
#     'Avg_Rebounds_Prev_5',
#     'MIN',
#     'OPP_FG3_PCT',
#     'OPP_AST',
#     'OPP_FG3M',
#     'OPP_STL',
#     'OPP_TOV',
#     'OPP_FG3A',
#     'OPP_FTA',
#     'OPP_DREB',
#     'OPP_PFD',
#     'OPP_PF',
#     'OPP_FT_PCT'],
#    'score': 0.5714285714285714},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_FG3_PCT',
#     'OPP_REBvsPos',
#     'OPP_PF',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FT_PCT',
#     'OPP_STLvsPos',
#     'OPP_PFD',
#     'OPP_PTSvsPos',
#     'OPP_BLKA',
#     'OPP_FTM',
#     'OPP_STL',
#     'OPP_ASTvsPos',
#     'OPP_FTA',
#     'OPP_FG3A',
#     'OPP_REB'],
#    'score': 0.2857142857142857}},
#  'Dejounte Murray': {'PTS': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_PFD',
#     'OPP_STL',
#     'Avg_Points_Prev_5',
#     'PT_PWR',
#     'OPP_TOVvsPos',
#     'OPP_FGA',
#     'OPP_FGM',
#     'OPP_BLKA',
#     'OPP_PTS',
#     'OPP_PF',
#     'OPP_FT_PCT',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_FG3M'],
#    'score': 1.0},
#   'REB': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_FTM',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FT_PCT',
#     'OPP_FGA',
#     'MIN',
#     'OPP_BLKA',
#     'OPP_ASTvsPos',
#     'OPP_TOVvsPos',
#     'PT_PWR',
#     'OPP_AST',
#     'OPP_PF',
#     'OPP_TOV',
#     'OPP_REB',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos'],
#    'score': 1.0},
#   'AST': {'model': RandomForestRegressor(),
#    'top_10_features': ['OPP_FG3_PCT',
#     'MIN',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FG_PCT',
#     'OPP_AST',
#     'OPP_FG3M',
#     'OPP_DREB',
#     'OPP_REBvsPos',
#     'OPP_FGM',
#     'OPP_FT_PCT',
#     'OPP_PF',
#     'OPP_STLvsPos',
#     'OPP_STL',
#     'OPP_FGA',
#     'OPP_OREB'],
#    'score': 0.375}},
#  'Max Strus': {'PTS': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=None, ...),
#    'top_10_features': ['OPP_TOV',
#     'Avg_Points_Prev_5',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'MIN',
#     'OPP_PTSvsPos',
#     'OPP_STLvsPos',
#     'OPP_REBvsPos',
#     'OPP_TOVvsPos',
#     'OPP_ASTvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FTM',
#     'OPP_FT_PCT',
#     'OPP_PTS'],
#    'score': 1.0},
#   'REB': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=None, ...),
#    'top_10_features': ['OPP_STL',
#     'OPP_TOV',
#     'OPP_AST',
#     'OPP_FTM',
#     'OPP_PF',
#     'OPP_STLvsPos',
#     'MIN',
#     'OPP_FT_PCT',
#     'PT_PWR',
#     'Avg_Rebounds_Prev_5',
#     'OPP_PTSvsPos',
#     'OPP_BLK',
#     'OPP_TOVvsPos',
#     'OPP_FGA',
#     'OPP_PFD'],
#    'score': 1.0},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.25}},
#  'Zion Williamson': {'PTS': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_REB',
#     'OPP_TOVvsPos',
#     'Avg_Points_Prev_5',
#     'OPP_FTA',
#     'OPP_PFD',
#     'OPP_FT_PCT',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_FG3A',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos'],
#    'score': 1.0},
#   'REB': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_FT_PCT',
#     'Avg_Rebounds_Prev_5',
#     'MIN',
#     'OPP_FG_PCT',
#     'OPP_TOV',
#     'OPP_REB',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_DREB',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_STL',
#     'OPP_BLKvsPos',
#     'OPP_FG3M',
#     'OPP_TOVvsPos'],
#    'score': 1.0},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['OPP_TOVvsPos',
#     'PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.14285714285714285}},
#  'Jalen Duren': {'PTS': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_FTA',
#     'OPP_TOV',
#     'OPP_REBvsPos',
#     'OPP_BLK',
#     'OPP_FG3_PCT',
#     'Avg_Points_Prev_5',
#     'OPP_PF',
#     'OPP_FG3A',
#     'OPP_TOVvsPos',
#     'OPP_FG_PCT',
#     'OPP_PTSvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_FGM'],
#    'score': 1.0},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['OPP_FG_PCT',
#     'MIN',
#     'OPP_TOV',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT'],
#    'score': 0.6},
#   'AST': {'model': Ridge(),
#    'top_10_features': ['OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'PT_PWR',
#     'OPP_OREB',
#     'Avg_Rebounds_Prev_5',
#     'OPP_STL',
#     'OPP_FGA',
#     'OPP_FT_PCT',
#     'OPP_BLK',
#     'OPP_TOV',
#     'OPP_PFD',
#     'OPP_REB',
#     'OPP_FG3A'],
#    'score': 0.4}},
#  'Al Horford': {'PTS': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=None, ...),
#    'top_10_features': ['OPP_FGM',
#     'OPP_TOVvsPos',
#     'OPP_OREB',
#     'OPP_ASTvsPos',
#     'Avg_Points_Prev_5',
#     'OPP_BLK',
#     'OPP_STLvsPos',
#     'OPP_REBvsPos',
#     'OPP_FG3M',
#     'MIN',
#     'OPP_BLKA',
#     'OPP_PTSvsPos',
#     'OPP_FG3_PCT',
#     'OPP_FG3A',
#     'OPP_DREB'],
#    'score': 1.0},
#   'REB': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_BLKA',
#     'OPP_PTS',
#     'OPP_FG_PCT',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FGM',
#     'OPP_STLvsPos',
#     'OPP_STL',
#     'OPP_TOV',
#     'OPP_BLKvsPos',
#     'OPP_AST',
#     'OPP_FG3A',
#     'OPP_FG3M',
#     'OPP_REB',
#     'OPP_REBvsPos'],
#    'score': 0.7142857142857143},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['MIN',
#     'OPP_ASTvsPos',
#     'OPP_FG3_PCT',
#     'OPP_FG3A',
#     'Avg_Rebounds_Prev_5',
#     'OPP_TOVvsPos',
#     'OPP_BLKvsPos',
#     'OPP_AST',
#     'OPP_PF',
#     'OPP_STL',
#     'OPP_STLvsPos',
#     'OPP_BLK',
#     'OPP_FG3M',
#     'OPP_REBvsPos',
#     'OPP_FGA'],
#    'score': 0.5714285714285714}},
#  'Tobias Harris': {'PTS': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'Avg_Points_Prev_5',
#     'OPP_PFD',
#     'OPP_FT_PCT',
#     'OPP_PF',
#     'OPP_FG3_PCT',
#     'OPP_TOVvsPos',
#     'OPP_BLK',
#     'OPP_FG3M',
#     'OPP_AST',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_FTA',
#     'OPP_PTS',
#     'OPP_DREB'],
#    'score': 0.7142857142857143},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_OREB',
#     'OPP_FT_PCT',
#     'OPP_FGA',
#     'OPP_BLKA',
#     'OPP_PFD',
#     'OPP_AST',
#     'OPP_TOV',
#     'OPP_ASTvsPos',
#     'OPP_FTA',
#     'OPP_FTM',
#     'MIN',
#     'OPP_BLKvsPos',
#     'OPP_REBvsPos',
#     'OPP_DREB',
#     'OPP_BLK'],
#    'score': 0.42857142857142855},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['Avg_Rebounds_Prev_5',
#     'OPP_TOV',
#     'OPP_PTSvsPos',
#     'PT_PWR',
#     'OPP_BLK',
#     'OPP_FG3_PCT',
#     'OPP_REBvsPos',
#     'OPP_FG3A',
#     'OPP_DREB',
#     'OPP_FT_PCT',
#     'OPP_BLKvsPos',
#     'OPP_FG3M',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_STLvsPos'],
#    'score': 0.8571428571428571}},
#  'Kevin Huerter': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['MIN',
#     'Avg_Points_Prev_5',
#     'OPP_BLKA',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_AST',
#     'OPP_REBvsPos',
#     'OPP_FG3M',
#     'OPP_OREB',
#     'OPP_FG3A',
#     'OPP_REB',
#     'OPP_FGM',
#     'OPP_DREB',
#     'OPP_FG_PCT',
#     'OPP_FTA'],
#    'score': 0.125},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['PT_PWR',
#     'MIN',
#     'OPP_BLKvsPos',
#     'OPP_STL',
#     'OPP_PFD',
#     'OPP_PF',
#     'OPP_REBvsPos',
#     'OPP_STLvsPos',
#     'OPP_ASTvsPos',
#     'OPP_FTA',
#     'OPP_FTM',
#     'OPP_FG_PCT',
#     'OPP_PTSvsPos',
#     'OPP_FGA',
#     'OPP_TOV'],
#    'score': 0.0},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_TOVvsPos',
#     'OPP_FTA',
#     'Avg_Rebounds_Prev_5',
#     'OPP_PF',
#     'OPP_ASTvsPos',
#     'OPP_OREB',
#     'OPP_BLK',
#     'OPP_STL',
#     'OPP_PTS',
#     'OPP_PFD',
#     'OPP_FG_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_STLvsPos'],
#    'score': 1.0}},
#  'Bam Adebayo': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_FG_PCT',
#     'OPP_FG3_PCT',
#     'OPP_BLKvsPos',
#     'OPP_BLKA',
#     'OPP_FGA',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FG3M',
#     'OPP_FG3A'],
#    'score': 0.8333333333333334},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_STL',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT'],
#    'score': 0.16666666666666666},
#   'AST': {'model': Ridge(),
#    'top_10_features': ['OPP_STLvsPos',
#     'OPP_STL',
#     'OPP_TOVvsPos',
#     'OPP_FG3A',
#     'OPP_REBvsPos',
#     'OPP_FG3_PCT',
#     'Avg_Rebounds_Prev_5',
#     'OPP_PTSvsPos',
#     'OPP_TOV',
#     'PT_PWR',
#     'OPP_ASTvsPos',
#     'OPP_FG_PCT',
#     'OPP_OREB',
#     'OPP_PFD',
#     'OPP_AST'],
#    'score': 0.0}},
#  'Nikola Jokic': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['MIN',
#     'OPP_TOVvsPos',
#     'OPP_REBvsPos',
#     'OPP_FG3M',
#     'OPP_BLKA',
#     'OPP_PF',
#     'OPP_OREB',
#     'OPP_FTA',
#     'OPP_PFD',
#     'OPP_TOV',
#     'Avg_Points_Prev_5',
#     'OPP_STLvsPos',
#     'OPP_FG3A',
#     'OPP_PTS',
#     'OPP_FG3_PCT'],
#    'score': 0.25},
#   'REB': {'model': Ridge(),
#    'top_10_features': ['PT_PWR',
#     'OPP_BLKA',
#     'OPP_STL',
#     'OPP_AST',
#     'MIN',
#     'OPP_STLvsPos',
#     'OPP_PFD',
#     'OPP_OREB',
#     'OPP_FG3M',
#     'OPP_DREB',
#     'OPP_FTA',
#     'OPP_FG3A',
#     'OPP_REBvsPos',
#     'OPP_PF',
#     'OPP_TOV'],
#    'score': 0.25},
#   'AST': {'model': RandomForestRegressor(),
#    'top_10_features': ['Avg_Rebounds_Prev_5',
#     'MIN',
#     'OPP_FG3A',
#     'OPP_FG3M',
#     'OPP_FTM',
#     'OPP_PFD',
#     'OPP_FTA',
#     'OPP_STL',
#     'OPP_STLvsPos',
#     'OPP_FG3_PCT',
#     'OPP_REBvsPos',
#     'OPP_PF',
#     'OPP_FG_PCT',
#     'OPP_BLK',
#     'OPP_TOVvsPos'],
#    'score': 0.5}},
#  'Isaiah Stewart': {'PTS': {'model': Ridge(),
#    'top_10_features': ['MIN',
#     'OPP_FGA',
#     'OPP_PF',
#     'OPP_BLKvsPos',
#     'OPP_PFD',
#     'OPP_TOVvsPos',
#     'OPP_REB',
#     'OPP_BLKA',
#     'OPP_DREB',
#     'OPP_REBvsPos',
#     'PT_PWR',
#     'OPP_BLK',
#     'OPP_ASTvsPos',
#     'OPP_OREB',
#     'OPP_FTM'],
#    'score': 0.3333333333333333},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_PTS',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT'],
#    'score': 0.16666666666666666},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_FG3_PCT',
#     'Avg_Rebounds_Prev_5',
#     'OPP_AST',
#     'MIN',
#     'OPP_OREB',
#     'OPP_FG3M',
#     'OPP_FT_PCT',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FG3A',
#     'OPP_REBvsPos',
#     'OPP_FGA',
#     'OPP_FG_PCT'],
#    'score': 1.0}},
#  'Aaron Nesmith': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['OPP_PFD',
#     'OPP_FGA',
#     'OPP_FT_PCT',
#     'OPP_BLKvsPos',
#     'OPP_BLKA',
#     'OPP_STLvsPos',
#     'OPP_STL',
#     'OPP_TOVvsPos',
#     'OPP_FG_PCT',
#     'PT_PWR',
#     'OPP_FG3M',
#     'OPP_AST',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_PTS'],
#    'score': 0.5714285714285714},
#   'REB': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_FGM',
#     'OPP_FT_PCT',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FTA',
#     'OPP_REB',
#     'MIN',
#     'OPP_PTSvsPos',
#     'OPP_PTS',
#     'OPP_ASTvsPos',
#     'OPP_BLK',
#     'OPP_FG3M',
#     'OPP_REBvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos'],
#    'score': 1.0},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.0}},
#  'Kentavious Caldwell-Pope': {'PTS': {'model': Lasso(),
#    'top_10_features': ['OPP_STLvsPos',
#     'OPP_PTS',
#     'OPP_STL',
#     'PT_PWR',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A'],
#    'score': 0.125},
#   'REB': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_FGM',
#     'PT_PWR',
#     'OPP_BLKvsPos',
#     'MIN',
#     'OPP_STL',
#     'OPP_FGA',
#     'Avg_Rebounds_Prev_5',
#     'OPP_DREB',
#     'OPP_FG3M',
#     'OPP_STLvsPos',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_PTS'],
#    'score': 1.0},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['PT_PWR',
#     'OPP_PTSvsPos',
#     'MIN',
#     'OPP_STLvsPos',
#     'Avg_Rebounds_Prev_5',
#     'OPP_DREB',
#     'OPP_AST',
#     'OPP_TOVvsPos',
#     'OPP_FTM',
#     'OPP_TOV',
#     'OPP_PFD',
#     'OPP_FG_PCT',
#     'OPP_PTS',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos'],
#    'score': 1.0}},
#  'Deni Avdija': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_FT_PCT',
#     'OPP_FG3_PCT',
#     'OPP_FG3M',
#     'Avg_Points_Prev_5',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3A'],
#    'score': 0.25},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'PT_PWR'],
#    'score': 0.25},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.25}},
#  'Grayson Allen': {'PTS': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FT_PCT',
#     'OPP_FTM',
#     'OPP_PF',
#     'Avg_Points_Prev_5',
#     'OPP_OREB',
#     'OPP_PTS',
#     'OPP_BLK',
#     'OPP_FGA',
#     'OPP_BLKvsPos',
#     'OPP_FG3M',
#     'OPP_ASTvsPos'],
#    'score': 1.0},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['Avg_Rebounds_Prev_5',
#     'OPP_PF',
#     'PT_PWR',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A'],
#    'score': 0.5714285714285714},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.5714285714285714}},
#  'Jaden McDaniels': {'PTS': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_REBvsPos',
#     'OPP_BLKA',
#     'Avg_Points_Prev_5',
#     'OPP_BLKvsPos',
#     'OPP_FTA',
#     'OPP_STL',
#     'PT_PWR',
#     'OPP_PTS',
#     'OPP_FG3M',
#     'OPP_PTSvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_PFD',
#     'OPP_TOVvsPos'],
#    'score': 1.0},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_REBvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_STL',
#     'OPP_PFD',
#     'OPP_FTA',
#     'OPP_FTM',
#     'OPP_DREB',
#     'OPP_FG3_PCT',
#     'OPP_REB',
#     'OPP_FT_PCT',
#     'OPP_FG3M',
#     'OPP_BLKA',
#     'Avg_Rebounds_Prev_5',
#     'OPP_TOV'],
#    'score': 0.0},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.0}},
#  'Isaiah Hartenstein': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_REBvsPos',
#     'OPP_FG3_PCT',
#     'OPP_STL',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A'],
#    'score': 0.125},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_PFD',
#     'OPP_ASTvsPos',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT'],
#    'score': 0.125},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.0}},
#  'Jarrett Allen': {'PTS': {'model': RandomForestRegressor(),
#    'top_10_features': ['OPP_PTSvsPos',
#     'MIN',
#     'OPP_PF',
#     'PT_PWR',
#     'OPP_REB',
#     'OPP_FGA',
#     'OPP_ASTvsPos',
#     'OPP_DREB',
#     'OPP_FGM',
#     'OPP_BLKvsPos',
#     'OPP_PTS',
#     'OPP_OREB',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'Avg_Points_Prev_5'],
#    'score': 0.42857142857142855},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_BLKvsPos',
#     'OPP_FG_PCT',
#     'PT_PWR',
#     'OPP_DREB',
#     'OPP_BLKA',
#     'OPP_TOV',
#     'OPP_FGM',
#     'OPP_PTS',
#     'OPP_OREB',
#     'OPP_TOVvsPos',
#     'Avg_Rebounds_Prev_5',
#     'OPP_REB',
#     'OPP_ASTvsPos',
#     'OPP_AST',
#     'OPP_REBvsPos'],
#    'score': 0.42857142857142855},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.5714285714285714}},
#  'Taurean Prince': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_PF',
#     'OPP_FG_PCT',
#     'OPP_OREB',
#     'OPP_BLKA',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG3M'],
#    'score': 0.25},
#   'REB': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_STLvsPos',
#     'Avg_Rebounds_Prev_5',
#     'OPP_BLK',
#     'MIN',
#     'OPP_PFD',
#     'OPP_BLKvsPos',
#     'OPP_FG3A',
#     'OPP_STL',
#     'OPP_OREB',
#     'OPP_FTA',
#     'OPP_REB',
#     'OPP_FGA',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos'],
#    'score': 1.0},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_ASTvsPos',
#     'Avg_Rebounds_Prev_5',
#     'PT_PWR',
#     'OPP_FG3_PCT',
#     'MIN',
#     'OPP_FGM',
#     'OPP_AST',
#     'OPP_PTS',
#     'OPP_FTM',
#     'OPP_OREB',
#     'OPP_PF',
#     'OPP_BLKA',
#     'OPP_FG_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos'],
#    'score': 1.0}},
#  'Zach Collins': {'PTS': {'model': Lasso(),
#    'top_10_features': ['OPP_FT_PCT',
#     'MIN',
#     'OPP_DREB',
#     'OPP_PTSvsPos',
#     'OPP_OREB',
#     'OPP_FG3_PCT',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M'],
#    'score': 0.2857142857142857},
#   'REB': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'Avg_Rebounds_Prev_5',
#     'OPP_ASTvsPos',
#     'OPP_FT_PCT',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FTM',
#     'OPP_AST',
#     'OPP_FG3_PCT',
#     'OPP_FGA',
#     'OPP_BLK',
#     'OPP_DREB',
#     'OPP_REBvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOV'],
#    'score': 0.7142857142857143},
#   'AST': {'model': Ridge(),
#    'top_10_features': ['MIN',
#     'OPP_BLKvsPos',
#     'OPP_AST',
#     'OPP_FT_PCT',
#     'OPP_BLK',
#     'OPP_STL',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_OREB',
#     'OPP_FG3_PCT',
#     'OPP_ASTvsPos',
#     'OPP_PFD',
#     'OPP_STLvsPos',
#     'OPP_FTA',
#     'OPP_BLKA'],
#    'score': 0.0}},
#  'Myles Turner': {'PTS': {'model': Ridge(),
#    'top_10_features': ['OPP_BLK',
#     'MIN',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_PTSvsPos',
#     'OPP_FT_PCT',
#     'PT_PWR',
#     'Avg_Points_Prev_5',
#     'OPP_TOVvsPos',
#     'OPP_REB',
#     'OPP_PF',
#     'OPP_BLKvsPos',
#     'OPP_DREB',
#     'OPP_OREB',
#     'OPP_BLKA'],
#    'score': 0.375},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.375},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['Avg_Rebounds_Prev_5',
#     'OPP_FGA',
#     'MIN',
#     'OPP_PF',
#     'OPP_TOVvsPos',
#     'OPP_REBvsPos',
#     'OPP_FG3A',
#     'OPP_AST',
#     'OPP_FGM',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_FG_PCT'],
#    'score': 1.0}},
#  'Reggie Jackson': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['MIN',
#     'OPP_REBvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_FG3_PCT',
#     'OPP_BLK',
#     'OPP_FGA',
#     'OPP_FG3A',
#     'OPP_FG_PCT',
#     'OPP_TOV',
#     'PT_PWR',
#     'OPP_BLKA',
#     'OPP_PTSvsPos',
#     'OPP_STL',
#     'OPP_TOVvsPos'],
#    'score': 0.25},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.375},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_PF',
#     'OPP_AST',
#     'OPP_PFD',
#     'OPP_ASTvsPos',
#     'OPP_BLK',
#     'OPP_FG3_PCT',
#     'OPP_BLKA',
#     'OPP_REBvsPos',
#     'OPP_TOV',
#     'PT_PWR',
#     'OPP_BLKvsPos',
#     'OPP_FG3M',
#     'MIN',
#     'OPP_STL',
#     'OPP_FT_PCT'],
#    'score': 0.125}},
#  'Grant Williams': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['OPP_AST',
#     'OPP_PF',
#     'OPP_FGA',
#     'OPP_TOVvsPos',
#     'OPP_FTA',
#     'OPP_TOV',
#     'OPP_FG3A',
#     'OPP_BLKvsPos',
#     'OPP_FG3_PCT',
#     'OPP_FT_PCT',
#     'OPP_ASTvsPos',
#     'OPP_REBvsPos',
#     'MIN',
#     'OPP_PTS',
#     'OPP_FGM'],
#    'score': 0.42857142857142855},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['Avg_Rebounds_Prev_5',
#     'OPP_TOV',
#     'MIN',
#     'OPP_FGA',
#     'OPP_STL',
#     'OPP_PF',
#     'OPP_BLKvsPos',
#     'PT_PWR',
#     'OPP_AST',
#     'OPP_ASTvsPos',
#     'OPP_FT_PCT',
#     'OPP_PTS',
#     'OPP_BLKA',
#     'OPP_FTM',
#     'OPP_FGM'],
#    'score': 0.0},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_REB',
#     'Avg_Rebounds_Prev_5',
#     'MIN',
#     'PT_PWR',
#     'OPP_BLKvsPos',
#     'OPP_STL',
#     'OPP_PTS',
#     'OPP_TOV',
#     'OPP_FTM',
#     'OPP_PF',
#     'OPP_FG_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos'],
#    'score': 1.0}},
#  'Josh Hart': {'PTS': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_FTA',
#     'Avg_Points_Prev_5',
#     'OPP_TOVvsPos',
#     'OPP_PFD',
#     'OPP_FT_PCT',
#     'OPP_FTM',
#     'OPP_AST',
#     'OPP_TOV',
#     'OPP_STL',
#     'OPP_ASTvsPos',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_PF',
#     'OPP_FG3A'],
#    'score': 0.5},
#   'REB': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=None, ...),
#    'top_10_features': ['OPP_FG_PCT',
#     'OPP_STL',
#     'OPP_FT_PCT',
#     'OPP_PF',
#     'OPP_TOVvsPos',
#     'OPP_BLKvsPos',
#     'MIN',
#     'OPP_FG3M',
#     'OPP_ASTvsPos',
#     'OPP_FGM',
#     'OPP_STLvsPos',
#     'OPP_PTSvsPos',
#     'OPP_FGA',
#     'OPP_AST',
#     'OPP_FTM'],
#    'score': 1.0},
#   'AST': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FTA',
#     'OPP_STL',
#     'OPP_TOV',
#     'OPP_PF',
#     'OPP_BLKA',
#     'OPP_BLK',
#     'OPP_OREB',
#     'OPP_STLvsPos',
#     'OPP_FT_PCT',
#     'OPP_TOVvsPos',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'PT_PWR'],
#    'score': 0.25}},
#  'Mike Conley': {'PTS': {'model': Lasso(),
#    'top_10_features': ['OPP_PTSvsPos',
#     'OPP_PFD',
#     'PT_PWR',
#     'OPP_FTM',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT'],
#    'score': 0.125},
#   'REB': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['Avg_Rebounds_Prev_5',
#     'MIN',
#     'OPP_BLK',
#     'OPP_PF',
#     'OPP_FG_PCT',
#     'OPP_BLKvsPos',
#     'OPP_FG3M',
#     'OPP_AST',
#     'OPP_OREB',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_FG3A',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA'],
#    'score': 1.0},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_BLK',
#     'OPP_TOV',
#     'OPP_FG3A',
#     'PT_PWR',
#     'OPP_STL',
#     'OPP_PFD',
#     'OPP_FG3M',
#     'OPP_STLvsPos',
#     'Avg_Rebounds_Prev_5',
#     'OPP_DREB',
#     'OPP_REB',
#     'OPP_FG3_PCT',
#     'OPP_FTM',
#     'OPP_PTS',
#     'OPP_FT_PCT'],
#    'score': 0.375}},
#  'Ausar Thompson': {'PTS': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_STL',
#     'Avg_Points_Prev_5',
#     'OPP_STLvsPos',
#     'OPP_DREB',
#     'OPP_PF',
#     'OPP_FTA',
#     'OPP_TOV',
#     'OPP_FG3A',
#     'OPP_OREB',
#     'OPP_PTSvsPos',
#     'PT_PWR',
#     'OPP_PFD',
#     'OPP_FGA',
#     'OPP_TOVvsPos'],
#    'score': 0.5},
#   'REB': {'model': Ridge(),
#    'top_10_features': ['OPP_PFD',
#     'PT_PWR',
#     'OPP_PTSvsPos',
#     'MIN',
#     'OPP_TOV',
#     'OPP_BLKvsPos',
#     'OPP_AST',
#     'OPP_FTM',
#     'OPP_ASTvsPos',
#     'OPP_TOVvsPos',
#     'OPP_OREB',
#     'OPP_REBvsPos',
#     'OPP_FTA',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FGA'],
#    'score': 0.75},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.25}},
#  'Chet Holmgren': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['OPP_STL',
#     'OPP_REBvsPos',
#     'OPP_FG3_PCT',
#     'OPP_AST',
#     'OPP_FGA',
#     'OPP_ASTvsPos',
#     'OPP_PTSvsPos',
#     'OPP_STLvsPos',
#     'OPP_OREB',
#     'PT_PWR',
#     'OPP_PF',
#     'OPP_FGM',
#     'OPP_DREB',
#     'OPP_FTA',
#     'OPP_PFD'],
#    'score': 0.375},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'PT_PWR'],
#    'score': 0.25},
#   'AST': {'model': RandomForestRegressor(),
#    'top_10_features': ['OPP_BLK',
#     'OPP_ASTvsPos',
#     'Avg_Rebounds_Prev_5',
#     'MIN',
#     'OPP_BLKvsPos',
#     'OPP_REB',
#     'OPP_DREB',
#     'OPP_STLvsPos',
#     'OPP_STL',
#     'OPP_REBvsPos',
#     'OPP_FTA',
#     'OPP_FT_PCT',
#     'OPP_FG3A',
#     'OPP_TOVvsPos',
#     'OPP_BLKA'],
#    'score': 0.375}},
#  'Jeremy Sochan': {'PTS': {'model': Lasso(),
#    'top_10_features': ['OPP_PF',
#     'OPP_STLvsPos',
#     'OPP_TOV',
#     'OPP_STL',
#     'PT_PWR',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M'],
#    'score': 0.25},
#   'REB': {'model': RandomForestRegressor(),
#    'top_10_features': ['OPP_BLKA',
#     'MIN',
#     'OPP_DREB',
#     'PT_PWR',
#     'Avg_Rebounds_Prev_5',
#     'OPP_REBvsPos',
#     'OPP_FG_PCT',
#     'OPP_FGM',
#     'OPP_PTSvsPos',
#     'OPP_TOVvsPos',
#     'OPP_AST',
#     'OPP_FG3M',
#     'OPP_FGA',
#     'OPP_ASTvsPos',
#     'OPP_PF'],
#    'score': 0.75},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.25}},
#  'Nikola Vucevic': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['MIN',
#     'OPP_PFD',
#     'OPP_REBvsPos',
#     'OPP_FGA',
#     'OPP_TOV',
#     'OPP_AST',
#     'OPP_TOVvsPos',
#     'OPP_PTSvsPos',
#     'OPP_FGM',
#     'OPP_BLK',
#     'OPP_FG3A',
#     'OPP_DREB',
#     'PT_PWR',
#     'OPP_FTA',
#     'OPP_OREB'],
#    'score': 0.42857142857142855},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_ASTvsPos',
#     'OPP_OREB',
#     'OPP_AST',
#     'MIN',
#     'OPP_TOVvsPos',
#     'OPP_BLKvsPos',
#     'OPP_REBvsPos',
#     'OPP_DREB',
#     'OPP_STLvsPos',
#     'OPP_PF',
#     'OPP_PFD',
#     'OPP_FG_PCT',
#     'OPP_FTM',
#     'PT_PWR',
#     'OPP_FT_PCT'],
#    'score': 0.14285714285714285},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_PF',
#     'OPP_STL',
#     'OPP_TOVvsPos',
#     'OPP_ASTvsPos',
#     'OPP_REBvsPos',
#     'OPP_TOV',
#     'OPP_BLKA',
#     'OPP_AST',
#     'PT_PWR',
#     'OPP_PTSvsPos',
#     'Avg_Rebounds_Prev_5',
#     'OPP_BLK',
#     'OPP_OREB',
#     'OPP_FGM',
#     'OPP_FGA'],
#    'score': 0.0}},
#  'Anthony Davis': {'PTS': {'model': Ridge(),
#    'top_10_features': ['OPP_REBvsPos',
#     'MIN',
#     'PT_PWR',
#     'OPP_PFD',
#     'OPP_OREB',
#     'OPP_BLKvsPos',
#     'OPP_ASTvsPos',
#     'Avg_Points_Prev_5',
#     'OPP_AST',
#     'OPP_FG_PCT',
#     'OPP_PF',
#     'OPP_REB',
#     'OPP_FTM',
#     'OPP_FTA',
#     'OPP_TOVvsPos'],
#    'score': 0.25},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_OREB',
#     'OPP_DREB',
#     'OPP_PTSvsPos',
#     'OPP_STL',
#     'OPP_PF',
#     'OPP_AST',
#     'OPP_TOVvsPos',
#     'OPP_BLK',
#     'OPP_BLKvsPos',
#     'OPP_REB',
#     'OPP_FTA',
#     'OPP_FT_PCT',
#     'OPP_FG_PCT',
#     'OPP_STLvsPos',
#     'OPP_FG3_PCT'],
#    'score': 0.375},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.0}},
#  'Jabari Smith Jr.': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['OPP_FGA',
#     'OPP_BLK',
#     'OPP_PF',
#     'OPP_AST',
#     'OPP_DREB',
#     'OPP_PFD',
#     'OPP_FG_PCT',
#     'OPP_TOV',
#     'OPP_PTSvsPos',
#     'OPP_FT_PCT',
#     'OPP_OREB',
#     'OPP_BLKA',
#     'OPP_REB',
#     'OPP_FTM',
#     'OPP_ASTvsPos'],
#    'score': 0.14285714285714285},
# ...
#     'OPP_BLKvsPos',
#     'OPP_PTSvsPos',
#     'OPP_FG3A',
#     'OPP_FT_PCT',
#     'OPP_FGA'],
#    'score': 1.0},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_BLK',
#     'OPP_REBvsPos',
#     'OPP_OREB',
#     'Avg_Rebounds_Prev_5',
#     'OPP_STL',
#     'MIN',
#     'OPP_BLKA',
#     'OPP_FG_PCT',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'OPP_BLKvsPos',
#     'OPP_FG3A',
#     'OPP_ASTvsPos'],
#    'score': 1.0}},
#  'Buddy Hield': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_FG3_PCT',
#     'OPP_FTA',
#     'OPP_BLKvsPos',
#     'OPP_FT_PCT',
#     'OPP_PF',
#     'OPP_OREB',
#     'OPP_PFD',
#     'OPP_FG3M',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM'],
#    'score': 0.25},
#   'REB': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_PF',
#     'MIN',
#     'OPP_FG_PCT',
#     'PT_PWR',
#     'OPP_DREB',
#     'OPP_STL',
#     'Avg_Rebounds_Prev_5',
#     'OPP_OREB',
#     'OPP_REBvsPos',
#     'OPP_BLKA',
#     'OPP_AST',
#     'OPP_PFD',
#     'OPP_FGA',
#     'OPP_PTSvsPos',
#     'OPP_ASTvsPos'],
#    'score': 1.0},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_PTSvsPos',
#     'Avg_Rebounds_Prev_5',
#     'OPP_ASTvsPos',
#     'OPP_PF',
#     'OPP_PTS',
#     'MIN',
#     'OPP_FG_PCT',
#     'OPP_OREB',
#     'OPP_BLK',
#     'OPP_PFD',
#     'OPP_REBvsPos',
#     'OPP_FG3M',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos'],
#    'score': 1.0}},
#  'Kyle Kuzma': {'PTS': {'model': RandomForestRegressor(),
#    'top_10_features': ['Avg_Points_Prev_5',
#     'MIN',
#     'OPP_PF',
#     'OPP_PFD',
#     'OPP_REB',
#     'OPP_DREB',
#     'OPP_STL',
#     'OPP_TOV',
#     'OPP_STLvsPos',
#     'OPP_FT_PCT',
#     'OPP_BLKA',
#     'OPP_FG_PCT',
#     'OPP_BLK',
#     'OPP_FG3A',
#     'PT_PWR'],
#    'score': 0.625},
#   'REB': {'model': Ridge(),
#    'top_10_features': ['OPP_TOV',
#     'OPP_PTSvsPos',
#     'OPP_FTM',
#     'OPP_PTS',
#     'OPP_BLK',
#     'MIN',
#     'OPP_OREB',
#     'OPP_FG3M',
#     'OPP_FTA',
#     'OPP_FG_PCT',
#     'OPP_FG3A',
#     'OPP_FT_PCT',
#     'OPP_FG3_PCT',
#     'OPP_PFD',
#     'OPP_DREB'],
#    'score': 0.375},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['OPP_FGA',
#     'PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.125}},
#  'Bennedict Mathurin': {'PTS': {'model': Ridge(),
#    'top_10_features': ['MIN',
#     'OPP_FT_PCT',
#     'OPP_STLvsPos',
#     'OPP_PTSvsPos',
#     'OPP_STL',
#     'OPP_PFD',
#     'OPP_BLKA',
#     'OPP_FG_PCT',
#     'OPP_BLK',
#     'OPP_FTA',
#     'OPP_TOVvsPos',
#     'OPP_FGA',
#     'OPP_AST',
#     'OPP_REBvsPos',
#     'OPP_FG3A'],
#    'score': 0.125},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_OREB',
#     'MIN',
#     'OPP_TOV',
#     'OPP_STL',
#     'OPP_BLKA',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'OPP_PTSvsPos',
#     'OPP_REB',
#     'OPP_BLK',
#     'OPP_PFD',
#     'OPP_FG3A',
#     'OPP_AST',
#     'OPP_ASTvsPos',
#     'OPP_FTM'],
#    'score': 0.125},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_TOV',
#     'OPP_STL',
#     'OPP_OREB',
#     'OPP_FG3_PCT',
#     'OPP_AST',
#     'OPP_PFD',
#     'OPP_PF',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_BLKA',
#     'OPP_FG3A',
#     'OPP_BLK',
#     'OPP_TOVvsPos',
#     'MIN',
#     'OPP_FG3M'],
#    'score': 0.375}},
#  'OG Anunoby': {'PTS': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=None, ...),
#    'top_10_features': ['OPP_DREB',
#     'OPP_FG3A',
#     'OPP_TOVvsPos',
#     'OPP_STL',
#     'OPP_FG3M',
#     'Avg_Points_Prev_5',
#     'MIN',
#     'OPP_FT_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_PF',
#     'OPP_FG_PCT',
#     'OPP_FTA',
#     'OPP_FGA',
#     'OPP_STLvsPos'],
#    'score': 1.0},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_PTSvsPos',
#     'OPP_BLK',
#     'OPP_OREB',
#     'PT_PWR',
#     'OPP_PF',
#     'OPP_FG_PCT',
#     'OPP_STL',
#     'OPP_TOVvsPos',
#     'OPP_BLKvsPos',
#     'OPP_PFD',
#     'OPP_FTA',
#     'OPP_FTM',
#     'OPP_FGA',
#     'OPP_TOV',
#     'OPP_REBvsPos'],
#    'score': 0.5714285714285714},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_ASTvsPos',
#     'OPP_OREB',
#     'OPP_BLKvsPos',
#     'OPP_PFD',
#     'OPP_REBvsPos',
#     'OPP_FTA',
#     'OPP_FTM',
#     'OPP_TOV',
#     'OPP_PF',
#     'OPP_STL',
#     'OPP_DREB',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'OPP_BLK',
#     'OPP_FT_PCT'],
#    'score': 0.2857142857142857}},
#  'Franz Wagner': {'PTS': {'model': Lasso(),
#    'top_10_features': ['OPP_FG3A',
#     'OPP_STLvsPos',
#     'OPP_AST',
#     'OPP_BLK',
#     'OPP_FTA',
#     'OPP_OREB',
#     'OPP_PTSvsPos',
#     'PT_PWR',
#     'OPP_TOV',
#     'OPP_FG_PCT',
#     'OPP_PTS',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_PFD',
#     'OPP_BLKvsPos'],
#    'score': 0.2857142857142857},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_REBvsPos',
#     'OPP_AST',
#     'OPP_FG_PCT',
#     'OPP_ASTvsPos',
#     'OPP_STL',
#     'OPP_FTM',
#     'OPP_FT_PCT',
#     'OPP_FGM',
#     'OPP_BLKvsPos',
#     'OPP_BLKA',
#     'OPP_FG3A',
#     'OPP_TOVvsPos',
#     'MIN',
#     'OPP_FG3M',
#     'OPP_FGA'],
#    'score': 0.2857142857142857},
#   'AST': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_BLK',
#     'Avg_Rebounds_Prev_5',
#     'OPP_ASTvsPos',
#     'OPP_FG3A',
#     'OPP_OREB',
#     'OPP_PFD',
#     'OPP_PF',
#     'OPP_STL',
#     'OPP_PTSvsPos',
#     'OPP_TOVvsPos',
#     'OPP_REBvsPos',
#     'OPP_DREB',
#     'OPP_BLKA',
#     'PT_PWR'],
#    'score': 0.42857142857142855}},
#  'John Collins': {'PTS': {'model': RandomForestRegressor(),
#    'top_10_features': ['OPP_FTA',
#     'MIN',
#     'Avg_Points_Prev_5',
#     'OPP_PF',
#     'OPP_FTM',
#     'OPP_FG3A',
#     'OPP_BLK',
#     'OPP_DREB',
#     'OPP_BLKA',
#     'OPP_PFD',
#     'OPP_REB',
#     'OPP_STLvsPos',
#     'PT_PWR',
#     'OPP_TOVvsPos',
#     'OPP_FG3_PCT'],
#    'score': 0.8571428571428571},
#   'REB': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_DREB',
#     'Avg_Rebounds_Prev_5',
#     'OPP_PTSvsPos',
#     'OPP_BLK',
#     'OPP_TOV',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FGA',
#     'OPP_FGM',
#     'OPP_REB',
#     'OPP_OREB',
#     'OPP_AST',
#     'OPP_FT_PCT',
#     'OPP_STLvsPos'],
#    'score': 0.7142857142857143},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_TOV',
#     'OPP_STLvsPos',
#     'OPP_STL',
#     'OPP_PFD',
#     'PT_PWR',
#     'OPP_ASTvsPos',
#     'OPP_FG3M',
#     'OPP_TOVvsPos',
#     'OPP_OREB',
#     'OPP_FGA',
#     'OPP_BLK',
#     'OPP_FTA',
#     'OPP_PTS',
#     'MIN',
#     'OPP_BLKvsPos'],
#    'score': 0.0}},
#  'Paolo Banchero': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_BLK',
#     'OPP_DREB',
#     'PT_PWR',
#     'OPP_STLvsPos',
#     'OPP_ASTvsPos',
#     'OPP_PF',
#     'OPP_FG3A',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT'],
#    'score': 0.5},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_REBvsPos',
#     'OPP_OREB',
#     'OPP_PFD',
#     'OPP_FT_PCT',
#     'OPP_FGA',
#     'OPP_FTM',
#     'OPP_TOV',
#     'OPP_AST',
#     'OPP_DREB',
#     'OPP_TOVvsPos',
#     'OPP_PTSvsPos',
#     'OPP_BLKvsPos',
#     'OPP_STLvsPos',
#     'PT_PWR',
#     'OPP_FG3_PCT'],
#    'score': 0.375},
#   'AST': {'model': Ridge(),
#    'top_10_features': ['OPP_PFD',
#     'OPP_FG_PCT',
#     'OPP_AST',
#     'OPP_FT_PCT',
#     'OPP_BLKvsPos',
#     'OPP_STLvsPos',
#     'OPP_PTSvsPos',
#     'MIN',
#     'OPP_FGA',
#     'OPP_FG3M',
#     'OPP_FTA',
#     'OPP_FG3_PCT',
#     'OPP_PF',
#     'PT_PWR',
#     'OPP_FGM'],
#    'score': 0.25}},
#  'Jamal Murray': {'PTS': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_FGM',
#     'OPP_PTS',
#     'OPP_STL',
#     'OPP_FG_PCT',
#     'MIN',
#     'OPP_PTSvsPos',
#     'OPP_OREB',
#     'Avg_Points_Prev_5',
#     'OPP_BLK',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGA',
#     'OPP_STLvsPos',
#     'OPP_FG3A',
#     'OPP_ASTvsPos'],
#    'score': 1.0},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_DREB',
#     'OPP_REB',
#     'OPP_PF',
#     'OPP_STLvsPos',
#     'OPP_FG_PCT',
#     'PT_PWR',
#     'OPP_FT_PCT',
#     'OPP_FGM',
#     'OPP_PFD',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_FGA',
#     'OPP_BLK',
#     'OPP_FG3M'],
#    'score': 0.2},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'PT_PWR'],
#    'score': 0.4}},
#  'Jaren Jackson Jr.': {'PTS': {'model': Ridge(),
#    'top_10_features': ['MIN',
#     'OPP_PF',
#     'OPP_ASTvsPos',
#     'OPP_TOV',
#     'OPP_BLKvsPos',
#     'OPP_FGA',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'OPP_FT_PCT',
#     'OPP_STL',
#     'OPP_PFD',
#     'OPP_AST',
#     'OPP_FG3A',
#     'OPP_FG3M',
#     'OPP_FGM'],
#    'score': 0.625},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['Avg_Rebounds_Prev_5',
#     'OPP_FGA',
#     'OPP_AST',
#     'MIN',
#     'OPP_BLKA',
#     'OPP_BLK',
#     'OPP_STLvsPos',
#     'OPP_FG3_PCT',
#     'OPP_REBvsPos',
#     'OPP_BLKvsPos',
#     'OPP_FT_PCT',
#     'OPP_FG_PCT',
#     'OPP_TOV',
#     'OPP_PF',
#     'OPP_STL'],
#    'score': 0.375},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_FGA',
#     'OPP_TOVvsPos',
#     'OPP_FG_PCT',
#     'OPP_FT_PCT',
#     'OPP_REB',
#     'OPP_DREB',
#     'OPP_FG3A',
#     'Avg_Rebounds_Prev_5',
#     'OPP_PTSvsPos',
#     'OPP_OREB',
#     'OPP_FG3_PCT',
#     'OPP_ASTvsPos',
#     'OPP_AST',
#     'OPP_BLKvsPos',
#     'OPP_BLK'],
#    'score': 0.25}},
#  'Spencer Dinwiddie': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['OPP_TOV',
#     'OPP_BLK',
#     'OPP_FGA',
#     'OPP_PFD',
#     'OPP_FGM',
#     'OPP_REB',
#     'OPP_FTA',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_PTS',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_TOVvsPos',
#     'OPP_DREB',
#     'OPP_STLvsPos'],
#    'score': 0.0},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_TOV',
#     'OPP_REB',
#     'OPP_OREB',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_PTS',
#     'OPP_ASTvsPos',
#     'OPP_BLK',
#     'OPP_PFD',
#     'OPP_FG3M',
#     'OPP_PF',
#     'OPP_AST',
#     'OPP_TOVvsPos',
#     'OPP_FG3A',
#     'OPP_FT_PCT'],
#    'score': 0.2857142857142857},
#   'AST': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'Avg_Rebounds_Prev_5',
#     'OPP_STLvsPos',
#     'OPP_FTA',
#     'OPP_PFD',
#     'OPP_FG3M',
#     'OPP_OREB',
#     'OPP_FG3A',
#     'OPP_STL',
#     'OPP_PF',
#     'OPP_ASTvsPos',
#     'OPP_AST',
#     'OPP_TOVvsPos',
#     'OPP_FG3_PCT',
#     'OPP_BLK'],
#    'score': 0.42857142857142855}},
#  'Jalen Johnson': {'PTS': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=None, ...),
#    'top_10_features': ['OPP_TOV',
#     'Avg_Points_Prev_5',
#     'OPP_ASTvsPos',
#     'OPP_PTSvsPos',
#     'MIN',
#     'OPP_FTA',
#     'OPP_FGA',
#     'OPP_DREB',
#     'OPP_BLKvsPos',
#     'OPP_REBvsPos',
#     'OPP_FG3M',
#     'OPP_FTM',
#     'OPP_BLK',
#     'OPP_FG_PCT',
#     'OPP_PTS'],
#    'score': 1.0},
#   'REB': {'model': Ridge(),
#    'top_10_features': ['MIN',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FGA',
#     'OPP_OREB',
#     'OPP_REBvsPos',
#     'OPP_BLK',
#     'OPP_FG3_PCT',
#     'OPP_FG3M',
#     'OPP_FG_PCT',
#     'OPP_PFD',
#     'OPP_PF',
#     'OPP_AST',
#     'OPP_TOVvsPos',
#     'OPP_TOV',
#     'OPP_REB'],
#    'score': 0.4},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['MIN',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FGA',
#     'OPP_DREB',
#     'OPP_BLKA',
#     'OPP_PFD',
#     'OPP_FG3A',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FG_PCT'],
#    'score': 1.0}},
#  'Khris Middleton': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_TOVvsPos',
#     'OPP_FTA',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'Avg_Points_Prev_5',
#     'OPP_FG3A',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_PTS',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT'],
#    'score': 0.2857142857142857},
#   'REB': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=None, ...),
#    'top_10_features': ['OPP_FG3A',
#     'OPP_TOVvsPos',
#     'OPP_DREB',
#     'OPP_FG3M',
#     'OPP_FGM',
#     'OPP_FTM',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'MIN',
#     'Avg_Rebounds_Prev_5',
#     'OPP_STL',
#     'OPP_PTSvsPos',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_REBvsPos'],
#    'score': 1.0},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.2857142857142857}},
#  'Kyle Lowry': {'PTS': {'model': Lasso(),
#    'top_10_features': ['OPP_FG3_PCT',
#     'MIN',
#     'OPP_ASTvsPos',
#     'OPP_BLKA',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A'],
#    'score': 0.2857142857142857},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.0},
#   'AST': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'Avg_Rebounds_Prev_5',
#     'OPP_TOV',
#     'OPP_FTA',
#     'OPP_FG_PCT',
#     'OPP_FG3_PCT',
#     'OPP_ASTvsPos',
#     'OPP_FG3A',
#     'OPP_PFD',
#     'PT_PWR',
#     'OPP_BLKA',
#     'OPP_REB',
#     'OPP_FTM',
#     'OPP_DREB',
#     'OPP_OREB'],
#    'score': 0.42857142857142855}}}

# %%
t = {k: v for k, v in player_best_models.items() if v}
my_dict = {k: t[k] for k in set(t)}


# Remove duplicates using dictionary comprehension
player_best_models = {k: v for k, v in my_dict.items() if list(my_dict.keys()).count(k) == 1}

# Filter out entries with None values for 'PTS', 'REB', or 'AST'
player_best_models = {
    player: stats
    for player, stats in player_best_models.items()
    if all(stats.get(key) is not None for key in ['PTS', 'REB', 'AST'])
}

player_best_models
# Out:
# {'Shai Gilgeous-Alexander': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'Avg_Points_Prev_5',
#     'OPP_BLKA',
#     'OPP_FT_PCT',
#     'OPP_STL',
#     'OPP_STLvsPos',
#     'OPP_BLK',
#     'OPP_ASTvsPos',
#     'OPP_FG3A',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_REBvsPos',
#     'OPP_PTSvsPos'],
#    'score': 0.7142857142857143},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.14285714285714285},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['OPP_PTSvsPos',
#     'OPP_FTM',
#     'PT_PWR',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.5714285714285714}},
#  'Patrick Williams': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['OPP_TOV',
#     'OPP_REBvsPos',
#     'OPP_PF',
#     'OPP_BLKvsPos',
#     'OPP_STL',
#     'OPP_AST',
#     'MIN',
#     'OPP_DREB',
#     'OPP_FG3A',
#     'OPP_REB',
#     'OPP_BLK',
#     'OPP_FGA',
#     'OPP_TOVvsPos',
#     'OPP_FTA',
#     'OPP_FTM'],
#    'score': 0.375},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.125},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_FTA',
#     'OPP_BLKvsPos',
#     'OPP_REBvsPos',
#     'OPP_PFD',
#     'OPP_PTSvsPos',
#     'OPP_FG3_PCT',
#     'OPP_BLKA',
#     'OPP_OREB',
#     'OPP_FG_PCT',
#     'OPP_FT_PCT',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'OPP_TOV',
#     'OPP_FGA',
#     'OPP_FG3M'],
#    'score': 0.0}},
#  'Devin Vassell': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_AST',
#     'OPP_FG3_PCT',
#     'OPP_PF',
#     'OPP_DREB',
#     'OPP_PTSvsPos',
#     'OPP_REB',
#     'OPP_FG3M',
#     'OPP_REBvsPos',
#     'MIN',
#     'OPP_BLKA',
#     'OPP_PFD',
#     'OPP_TOVvsPos',
#     'PT_PWR'],
#    'score': 0.14285714285714285},
#   'REB': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_FG_PCT',
#     'Avg_Rebounds_Prev_5',
#     'OPP_OREB',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_FGM',
#     'OPP_FG3M',
#     'OPP_FTA',
#     'OPP_ASTvsPos',
#     'OPP_PTS',
#     'OPP_FG3A',
#     'OPP_REBvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos'],
#    'score': 0.7142857142857143},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_STLvsPos',
#     'Avg_Rebounds_Prev_5',
#     'MIN',
#     'OPP_AST',
#     'OPP_PFD',
#     'OPP_PTSvsPos',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT'],
#    'score': 1.0}},
#  'Dennis Schroder': {'PTS': {'model': Lasso(),
#    'top_10_features': ['OPP_AST',
#     'OPP_PTSvsPos',
#     'OPP_STL',
#     'OPP_PFD',
#     'MIN',
#     'OPP_BLKvsPos',
#     'OPP_REB',
#     'OPP_FG3A',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT'],
#    'score': 0.375},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_REB',
#     'OPP_FTA',
#     'OPP_DREB',
#     'OPP_FG_PCT',
#     'OPP_FTM',
#     'OPP_FGA',
#     'OPP_PTS',
#     'OPP_FGM',
#     'OPP_OREB',
#     'OPP_FT_PCT',
#     'OPP_FG3_PCT',
#     'OPP_FG3A',
#     'OPP_FG3M',
#     'OPP_PTSvsPos',
#     'OPP_BLK'],
#    'score': 0.125},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_REB',
#     'OPP_FGA',
#     'OPP_OREB',
#     'OPP_FG3M',
#     'OPP_FTA',
#     'OPP_FGM',
#     'OPP_PTS',
#     'OPP_DREB',
#     'OPP_FG_PCT',
#     'OPP_FG3_PCT',
#     'OPP_FTM',
#     'OPP_FG3A',
#     'OPP_AST',
#     'OPP_PFD',
#     'OPP_PTSvsPos'],
#    'score': 0.5}},
#  'Miles Bridges': {'PTS': {'model': Lasso(),
#    'top_10_features': ['OPP_AST',
#     'MIN',
#     'OPP_PF',
#     'OPP_STL',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M'],
#    'score': 0.6},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['MIN',
#     'OPP_PTSvsPos',
#     'OPP_PFD',
#     'OPP_BLK',
#     'OPP_OREB',
#     'OPP_FG3A',
#     'OPP_FG3M',
#     'OPP_BLKvsPos',
#     'OPP_FG3_PCT',
#     'OPP_TOV',
#     'OPP_REB',
#     'OPP_FT_PCT',
#     'OPP_PF',
#     'OPP_ASTvsPos',
#     'PT_PWR'],
#    'score': 0.8},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.2}},
#  'Ivica Zubac': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_PF',
#     'OPP_FG3M',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3A',
#     'OPP_FG3_PCT'],
#    'score': 0.25},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_FG3A',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3_PCT',
#     'PT_PWR'],
#    'score': 0.375},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_FT_PCT',
#     'Avg_Rebounds_Prev_5',
#     'OPP_REBvsPos',
#     'OPP_FGA',
#     'OPP_FG3_PCT',
#     'OPP_FG_PCT',
#     'MIN',
#     'OPP_TOVvsPos',
#     'OPP_BLK',
#     'OPP_PTSvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_FGM',
#     'OPP_FG3M'],
#    'score': 1.0}},
#  'Cole Anthony': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_BLKA',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT'],
#    'score': 0.25},
#   'REB': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_BLK',
#     'OPP_FTM',
#     'OPP_BLKvsPos',
#     'OPP_PF',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FG3A',
#     'OPP_PFD',
#     'OPP_STLvsPos',
#     'OPP_STL',
#     'OPP_TOV',
#     'OPP_FG3M',
#     'PT_PWR',
#     'OPP_PTSvsPos',
#     'OPP_ASTvsPos'],
#    'score': 0.375},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_ASTvsPos',
#     'OPP_STL',
#     'OPP_FG_PCT',
#     'OPP_TOVvsPos',
#     'OPP_FG3_PCT',
#     'OPP_FGA',
#     'OPP_BLKvsPos',
#     'OPP_DREB',
#     'OPP_REB',
#     'PT_PWR',
#     'OPP_TOV',
#     'OPP_FG3M',
#     'MIN',
#     'OPP_AST',
#     'OPP_FTM'],
#    'score': 0.125}},
#  'Jalen Green': {'PTS': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=None, ...),
#    'top_10_features': ['OPP_TOV',
#     'OPP_FGM',
#     'OPP_BLK',
#     'OPP_OREB',
#     'OPP_AST',
#     'Avg_Points_Prev_5',
#     'OPP_REBvsPos',
#     'OPP_FT_PCT',
#     'OPP_FTM',
#     'OPP_ASTvsPos',
#     'PT_PWR',
#     'MIN',
#     'OPP_BLKA',
#     'OPP_FGA',
#     'OPP_PF'],
#    'score': 1.0},
#   'REB': {'model': Ridge(),
#    'top_10_features': ['OPP_REBvsPos',
#     'OPP_FTA',
#     'OPP_TOVvsPos',
#     'OPP_FTM',
#     'OPP_BLK',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'Avg_Rebounds_Prev_5',
#     'OPP_TOV',
#     'OPP_FG3M',
#     'PT_PWR',
#     'OPP_PF',
#     'OPP_AST',
#     'OPP_STL',
#     'OPP_FGM'],
#    'score': 0.5},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.125}},
#  'Kyrie Irving': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'PT_PWR',
#     'OPP_BLK',
#     'OPP_ASTvsPos',
#     'OPP_PTS',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M'],
#    'score': 0.0},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['OPP_STL',
#     'PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT'],
#    'score': 0.2},
#   'AST': {'model': RandomForestRegressor(),
#    'top_10_features': ['OPP_DREB',
#     'OPP_TOV',
#     'Avg_Rebounds_Prev_5',
#     'OPP_PF',
#     'OPP_BLKA',
#     'PT_PWR',
#     'MIN',
#     'OPP_FT_PCT',
#     'OPP_BLK',
#     'OPP_FG3A',
#     'OPP_PFD',
#     'OPP_OREB',
#     'OPP_FG3M',
#     'OPP_REB',
#     'OPP_FG3_PCT'],
#    'score': 0.8}},
#  'Pascal Siakam': {'PTS': {'model': RandomForestRegressor(),
#    'top_10_features': ['OPP_ASTvsPos',
#     'MIN',
#     'OPP_PTSvsPos',
#     'OPP_PFD',
#     'Avg_Points_Prev_5',
#     'OPP_REBvsPos',
#     'OPP_FTA',
#     'OPP_OREB',
#     'OPP_REB',
#     'OPP_TOVvsPos',
#     'OPP_BLKA',
#     'OPP_PF',
#     'OPP_FGA',
#     'OPP_AST',
#     'OPP_FG3A'],
#    'score': 0.375},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.5},
#   'AST': {'model': Ridge(),
#    'top_10_features': ['OPP_PFD',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_ASTvsPos',
#     'PT_PWR',
#     'OPP_STL',
#     'OPP_PF',
#     'OPP_REBvsPos',
#     'OPP_PTSvsPos',
#     'OPP_BLKvsPos',
#     'OPP_BLK',
#     'OPP_TOVvsPos',
#     'OPP_BLKA',
#     'OPP_FG3_PCT',
#     'OPP_FG3M'],
#    'score': 0.375}},
#  'Daniel Gafford': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_TOVvsPos',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'PT_PWR'],
#    'score': 0.2857142857142857},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_STLvsPos',
#     'MIN',
#     'OPP_REBvsPos',
#     'OPP_FG3A',
#     'OPP_PFD',
#     'Avg_Rebounds_Prev_5',
#     'OPP_AST',
#     'OPP_FT_PCT',
#     'OPP_PF',
#     'OPP_FGA',
#     'OPP_FTA',
#     'OPP_PTSvsPos',
#     'OPP_FG_PCT',
#     'OPP_FG3_PCT',
#     'OPP_STL'],
#    'score': 0.0},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_PFD',
#     'MIN',
#     'Avg_Rebounds_Prev_5',
#     'OPP_STLvsPos',
#     'OPP_FT_PCT',
#     'OPP_FTM',
#     'OPP_BLKA',
#     'OPP_FGM',
#     'OPP_FG_PCT',
#     'OPP_FGA',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FG3A',
#     'OPP_ASTvsPos',
#     'OPP_REBvsPos'],
#    'score': 1.0}},
#  'Stephen Curry': {'PTS': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_FGM',
#     'OPP_FTA',
#     'Avg_Points_Prev_5',
#     'OPP_PTSvsPos',
#     'OPP_FG3A',
#     'OPP_STL',
#     'OPP_TOV',
#     'OPP_PF',
#     'PT_PWR',
#     'OPP_FG3M',
#     'OPP_PTS',
#     'OPP_STLvsPos',
#     'OPP_FG_PCT',
#     'OPP_REBvsPos'],
#    'score': 1.0},
#   'REB': {'model': Ridge(),
#    'top_10_features': ['MIN',
#     'OPP_DREB',
#     'OPP_FT_PCT',
#     'OPP_FTA',
#     'OPP_AST',
#     'OPP_BLKA',
#     'OPP_REB',
#     'Avg_Rebounds_Prev_5',
#     'OPP_PF',
#     'OPP_BLKvsPos',
#     'OPP_ASTvsPos',
#     'OPP_FTM',
#     'OPP_TOVvsPos',
#     'OPP_REBvsPos',
#     'OPP_BLK'],
#    'score': 0.14285714285714285},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['Avg_Rebounds_Prev_5',
#     'OPP_PFD',
#     'MIN',
#     'OPP_STLvsPos',
#     'PT_PWR',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_ASTvsPos',
#     'OPP_FT_PCT',
#     'OPP_TOV',
#     'OPP_REB',
#     'OPP_AST',
#     'OPP_BLKA',
#     'OPP_FG_PCT',
#     'OPP_PTSvsPos'],
#    'score': 1.0}},
#  'LeBron James': {'PTS': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=None, ...),
#    'top_10_features': ['OPP_PFD',
#     'OPP_FG3A',
#     'OPP_FT_PCT',
#     'OPP_TOVvsPos',
#     'OPP_PF',
#     'Avg_Points_Prev_5',
#     'OPP_BLKvsPos',
#     'OPP_FGM',
#     'OPP_ASTvsPos',
#     'OPP_BLK',
#     'OPP_STLvsPos',
#     'OPP_OREB',
#     'OPP_FTA',
#     'MIN',
#     'OPP_AST'],
#    'score': 1.0},
#   'REB': {'model': RandomForestRegressor(),
#    'top_10_features': ['OPP_FGA',
#     'PT_PWR',
#     'Avg_Rebounds_Prev_5',
#     'MIN',
#     'OPP_FG3_PCT',
#     'OPP_AST',
#     'OPP_FG3M',
#     'OPP_STL',
#     'OPP_TOV',
#     'OPP_FG3A',
#     'OPP_FTA',
#     'OPP_DREB',
#     'OPP_PFD',
#     'OPP_PF',
#     'OPP_FT_PCT'],
#    'score': 0.5714285714285714},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_FG3_PCT',
#     'OPP_REBvsPos',
#     'OPP_PF',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FT_PCT',
#     'OPP_STLvsPos',
#     'OPP_PFD',
#     'OPP_PTSvsPos',
#     'OPP_BLKA',
#     'OPP_FTM',
#     'OPP_STL',
#     'OPP_ASTvsPos',
#     'OPP_FTA',
#     'OPP_FG3A',
#     'OPP_REB'],
#    'score': 0.2857142857142857}},
#  'Dejounte Murray': {'PTS': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_PFD',
#     'OPP_STL',
#     'Avg_Points_Prev_5',
#     'PT_PWR',
#     'OPP_TOVvsPos',
#     'OPP_FGA',
#     'OPP_FGM',
#     'OPP_BLKA',
#     'OPP_PTS',
#     'OPP_PF',
#     'OPP_FT_PCT',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_FG3M'],
#    'score': 1.0},
#   'REB': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_FTM',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FT_PCT',
#     'OPP_FGA',
#     'MIN',
#     'OPP_BLKA',
#     'OPP_ASTvsPos',
#     'OPP_TOVvsPos',
#     'PT_PWR',
#     'OPP_AST',
#     'OPP_PF',
#     'OPP_TOV',
#     'OPP_REB',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos'],
#    'score': 1.0},
#   'AST': {'model': RandomForestRegressor(),
#    'top_10_features': ['OPP_FG3_PCT',
#     'MIN',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FG_PCT',
#     'OPP_AST',
#     'OPP_FG3M',
#     'OPP_DREB',
#     'OPP_REBvsPos',
#     'OPP_FGM',
#     'OPP_FT_PCT',
#     'OPP_PF',
#     'OPP_STLvsPos',
#     'OPP_STL',
#     'OPP_FGA',
#     'OPP_OREB'],
#    'score': 0.375}},
#  'Max Strus': {'PTS': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=None, ...),
#    'top_10_features': ['OPP_TOV',
#     'Avg_Points_Prev_5',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'MIN',
#     'OPP_PTSvsPos',
#     'OPP_STLvsPos',
#     'OPP_REBvsPos',
#     'OPP_TOVvsPos',
#     'OPP_ASTvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FTM',
#     'OPP_FT_PCT',
#     'OPP_PTS'],
#    'score': 1.0},
#   'REB': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=None, ...),
#    'top_10_features': ['OPP_STL',
#     'OPP_TOV',
#     'OPP_AST',
#     'OPP_FTM',
#     'OPP_PF',
#     'OPP_STLvsPos',
#     'MIN',
#     'OPP_FT_PCT',
#     'PT_PWR',
#     'Avg_Rebounds_Prev_5',
#     'OPP_PTSvsPos',
#     'OPP_BLK',
#     'OPP_TOVvsPos',
#     'OPP_FGA',
#     'OPP_PFD'],
#    'score': 1.0},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.25}},
#  'Zion Williamson': {'PTS': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_REB',
#     'OPP_TOVvsPos',
#     'Avg_Points_Prev_5',
#     'OPP_FTA',
#     'OPP_PFD',
#     'OPP_FT_PCT',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_FG3A',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos'],
#    'score': 1.0},
#   'REB': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_FT_PCT',
#     'Avg_Rebounds_Prev_5',
#     'MIN',
#     'OPP_FG_PCT',
#     'OPP_TOV',
#     'OPP_REB',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_DREB',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_STL',
#     'OPP_BLKvsPos',
#     'OPP_FG3M',
#     'OPP_TOVvsPos'],
#    'score': 1.0},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['OPP_TOVvsPos',
#     'PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.14285714285714285}},
#  'Jalen Duren': {'PTS': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_FTA',
#     'OPP_TOV',
#     'OPP_REBvsPos',
#     'OPP_BLK',
#     'OPP_FG3_PCT',
#     'Avg_Points_Prev_5',
#     'OPP_PF',
#     'OPP_FG3A',
#     'OPP_TOVvsPos',
#     'OPP_FG_PCT',
#     'OPP_PTSvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_FGM'],
#    'score': 1.0},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['OPP_FG_PCT',
#     'MIN',
#     'OPP_TOV',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT'],
#    'score': 0.6},
#   'AST': {'model': Ridge(),
#    'top_10_features': ['OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'PT_PWR',
#     'OPP_OREB',
#     'Avg_Rebounds_Prev_5',
#     'OPP_STL',
#     'OPP_FGA',
#     'OPP_FT_PCT',
#     'OPP_BLK',
#     'OPP_TOV',
#     'OPP_PFD',
#     'OPP_REB',
#     'OPP_FG3A'],
#    'score': 0.4}},
#  'Al Horford': {'PTS': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=None, ...),
#    'top_10_features': ['OPP_FGM',
#     'OPP_TOVvsPos',
#     'OPP_OREB',
#     'OPP_ASTvsPos',
#     'Avg_Points_Prev_5',
#     'OPP_BLK',
#     'OPP_STLvsPos',
#     'OPP_REBvsPos',
#     'OPP_FG3M',
#     'MIN',
#     'OPP_BLKA',
#     'OPP_PTSvsPos',
#     'OPP_FG3_PCT',
#     'OPP_FG3A',
#     'OPP_DREB'],
#    'score': 1.0},
#   'REB': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_BLKA',
#     'OPP_PTS',
#     'OPP_FG_PCT',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FGM',
#     'OPP_STLvsPos',
#     'OPP_STL',
#     'OPP_TOV',
#     'OPP_BLKvsPos',
#     'OPP_AST',
#     'OPP_FG3A',
#     'OPP_FG3M',
#     'OPP_REB',
#     'OPP_REBvsPos'],
#    'score': 0.7142857142857143},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['MIN',
#     'OPP_ASTvsPos',
#     'OPP_FG3_PCT',
#     'OPP_FG3A',
#     'Avg_Rebounds_Prev_5',
#     'OPP_TOVvsPos',
#     'OPP_BLKvsPos',
#     'OPP_AST',
#     'OPP_PF',
#     'OPP_STL',
#     'OPP_STLvsPos',
#     'OPP_BLK',
#     'OPP_FG3M',
#     'OPP_REBvsPos',
#     'OPP_FGA'],
#    'score': 0.5714285714285714}},
#  'Tobias Harris': {'PTS': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'Avg_Points_Prev_5',
#     'OPP_PFD',
#     'OPP_FT_PCT',
#     'OPP_PF',
#     'OPP_FG3_PCT',
#     'OPP_TOVvsPos',
#     'OPP_BLK',
#     'OPP_FG3M',
#     'OPP_AST',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_FTA',
#     'OPP_PTS',
#     'OPP_DREB'],
#    'score': 0.7142857142857143},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_OREB',
#     'OPP_FT_PCT',
#     'OPP_FGA',
#     'OPP_BLKA',
#     'OPP_PFD',
#     'OPP_AST',
#     'OPP_TOV',
#     'OPP_ASTvsPos',
#     'OPP_FTA',
#     'OPP_FTM',
#     'MIN',
#     'OPP_BLKvsPos',
#     'OPP_REBvsPos',
#     'OPP_DREB',
#     'OPP_BLK'],
#    'score': 0.42857142857142855},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['Avg_Rebounds_Prev_5',
#     'OPP_TOV',
#     'OPP_PTSvsPos',
#     'PT_PWR',
#     'OPP_BLK',
#     'OPP_FG3_PCT',
#     'OPP_REBvsPos',
#     'OPP_FG3A',
#     'OPP_DREB',
#     'OPP_FT_PCT',
#     'OPP_BLKvsPos',
#     'OPP_FG3M',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_STLvsPos'],
#    'score': 0.8571428571428571}},
#  'Kevin Huerter': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['MIN',
#     'Avg_Points_Prev_5',
#     'OPP_BLKA',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_AST',
#     'OPP_REBvsPos',
#     'OPP_FG3M',
#     'OPP_OREB',
#     'OPP_FG3A',
#     'OPP_REB',
#     'OPP_FGM',
#     'OPP_DREB',
#     'OPP_FG_PCT',
#     'OPP_FTA'],
#    'score': 0.125},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['PT_PWR',
#     'MIN',
#     'OPP_BLKvsPos',
#     'OPP_STL',
#     'OPP_PFD',
#     'OPP_PF',
#     'OPP_REBvsPos',
#     'OPP_STLvsPos',
#     'OPP_ASTvsPos',
#     'OPP_FTA',
#     'OPP_FTM',
#     'OPP_FG_PCT',
#     'OPP_PTSvsPos',
#     'OPP_FGA',
#     'OPP_TOV'],
#    'score': 0.0},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_TOVvsPos',
#     'OPP_FTA',
#     'Avg_Rebounds_Prev_5',
#     'OPP_PF',
#     'OPP_ASTvsPos',
#     'OPP_OREB',
#     'OPP_BLK',
#     'OPP_STL',
#     'OPP_PTS',
#     'OPP_PFD',
#     'OPP_FG_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_STLvsPos'],
#    'score': 1.0}},
#  'Bam Adebayo': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_FG_PCT',
#     'OPP_FG3_PCT',
#     'OPP_BLKvsPos',
#     'OPP_BLKA',
#     'OPP_FGA',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FG3M',
#     'OPP_FG3A'],
#    'score': 0.8333333333333334},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_STL',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT'],
#    'score': 0.16666666666666666},
#   'AST': {'model': Ridge(),
#    'top_10_features': ['OPP_STLvsPos',
#     'OPP_STL',
#     'OPP_TOVvsPos',
#     'OPP_FG3A',
#     'OPP_REBvsPos',
#     'OPP_FG3_PCT',
#     'Avg_Rebounds_Prev_5',
#     'OPP_PTSvsPos',
#     'OPP_TOV',
#     'PT_PWR',
#     'OPP_ASTvsPos',
#     'OPP_FG_PCT',
#     'OPP_OREB',
#     'OPP_PFD',
#     'OPP_AST'],
#    'score': 0.0}},
#  'Nikola Jokic': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['MIN',
#     'OPP_TOVvsPos',
#     'OPP_REBvsPos',
#     'OPP_FG3M',
#     'OPP_BLKA',
#     'OPP_PF',
#     'OPP_OREB',
#     'OPP_FTA',
#     'OPP_PFD',
#     'OPP_TOV',
#     'Avg_Points_Prev_5',
#     'OPP_STLvsPos',
#     'OPP_FG3A',
#     'OPP_PTS',
#     'OPP_FG3_PCT'],
#    'score': 0.25},
#   'REB': {'model': Ridge(),
#    'top_10_features': ['PT_PWR',
#     'OPP_BLKA',
#     'OPP_STL',
#     'OPP_AST',
#     'MIN',
#     'OPP_STLvsPos',
#     'OPP_PFD',
#     'OPP_OREB',
#     'OPP_FG3M',
#     'OPP_DREB',
#     'OPP_FTA',
#     'OPP_FG3A',
#     'OPP_REBvsPos',
#     'OPP_PF',
#     'OPP_TOV'],
#    'score': 0.25},
#   'AST': {'model': RandomForestRegressor(),
#    'top_10_features': ['Avg_Rebounds_Prev_5',
#     'MIN',
#     'OPP_FG3A',
#     'OPP_FG3M',
#     'OPP_FTM',
#     'OPP_PFD',
#     'OPP_FTA',
#     'OPP_STL',
#     'OPP_STLvsPos',
#     'OPP_FG3_PCT',
#     'OPP_REBvsPos',
#     'OPP_PF',
#     'OPP_FG_PCT',
#     'OPP_BLK',
#     'OPP_TOVvsPos'],
#    'score': 0.5}},
#  'Isaiah Stewart': {'PTS': {'model': Ridge(),
#    'top_10_features': ['MIN',
#     'OPP_FGA',
#     'OPP_PF',
#     'OPP_BLKvsPos',
#     'OPP_PFD',
#     'OPP_TOVvsPos',
#     'OPP_REB',
#     'OPP_BLKA',
#     'OPP_DREB',
#     'OPP_REBvsPos',
#     'PT_PWR',
#     'OPP_BLK',
#     'OPP_ASTvsPos',
#     'OPP_OREB',
#     'OPP_FTM'],
#    'score': 0.3333333333333333},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_PTS',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT'],
#    'score': 0.16666666666666666},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_FG3_PCT',
#     'Avg_Rebounds_Prev_5',
#     'OPP_AST',
#     'MIN',
#     'OPP_OREB',
#     'OPP_FG3M',
#     'OPP_FT_PCT',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FG3A',
#     'OPP_REBvsPos',
#     'OPP_FGA',
#     'OPP_FG_PCT'],
#    'score': 1.0}},
#  'Aaron Nesmith': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['OPP_PFD',
#     'OPP_FGA',
#     'OPP_FT_PCT',
#     'OPP_BLKvsPos',
#     'OPP_BLKA',
#     'OPP_STLvsPos',
#     'OPP_STL',
#     'OPP_TOVvsPos',
#     'OPP_FG_PCT',
#     'PT_PWR',
#     'OPP_FG3M',
#     'OPP_AST',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_PTS'],
#    'score': 0.5714285714285714},
#   'REB': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_FGM',
#     'OPP_FT_PCT',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FTA',
#     'OPP_REB',
#     'MIN',
#     'OPP_PTSvsPos',
#     'OPP_PTS',
#     'OPP_ASTvsPos',
#     'OPP_BLK',
#     'OPP_FG3M',
#     'OPP_REBvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos'],
#    'score': 1.0},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.0}},
#  'Kentavious Caldwell-Pope': {'PTS': {'model': Lasso(),
#    'top_10_features': ['OPP_STLvsPos',
#     'OPP_PTS',
#     'OPP_STL',
#     'PT_PWR',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A'],
#    'score': 0.125},
#   'REB': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_FGM',
#     'PT_PWR',
#     'OPP_BLKvsPos',
#     'MIN',
#     'OPP_STL',
#     'OPP_FGA',
#     'Avg_Rebounds_Prev_5',
#     'OPP_DREB',
#     'OPP_FG3M',
#     'OPP_STLvsPos',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_PTS'],
#    'score': 1.0},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['PT_PWR',
#     'OPP_PTSvsPos',
#     'MIN',
#     'OPP_STLvsPos',
#     'Avg_Rebounds_Prev_5',
#     'OPP_DREB',
#     'OPP_AST',
#     'OPP_TOVvsPos',
#     'OPP_FTM',
#     'OPP_TOV',
#     'OPP_PFD',
#     'OPP_FG_PCT',
#     'OPP_PTS',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos'],
#    'score': 1.0}},
#  'Deni Avdija': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_FT_PCT',
#     'OPP_FG3_PCT',
#     'OPP_FG3M',
#     'Avg_Points_Prev_5',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3A'],
#    'score': 0.25},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'PT_PWR'],
#    'score': 0.25},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.25}},
#  'Grayson Allen': {'PTS': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FT_PCT',
#     'OPP_FTM',
#     'OPP_PF',
#     'Avg_Points_Prev_5',
#     'OPP_OREB',
#     'OPP_PTS',
#     'OPP_BLK',
#     'OPP_FGA',
#     'OPP_BLKvsPos',
#     'OPP_FG3M',
#     'OPP_ASTvsPos'],
#    'score': 1.0},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['Avg_Rebounds_Prev_5',
#     'OPP_PF',
#     'PT_PWR',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A'],
#    'score': 0.5714285714285714},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.5714285714285714}},
#  'Jaden McDaniels': {'PTS': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_REBvsPos',
#     'OPP_BLKA',
#     'Avg_Points_Prev_5',
#     'OPP_BLKvsPos',
#     'OPP_FTA',
#     'OPP_STL',
#     'PT_PWR',
#     'OPP_PTS',
#     'OPP_FG3M',
#     'OPP_PTSvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_PFD',
#     'OPP_TOVvsPos'],
#    'score': 1.0},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_REBvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_STL',
#     'OPP_PFD',
#     'OPP_FTA',
#     'OPP_FTM',
#     'OPP_DREB',
#     'OPP_FG3_PCT',
#     'OPP_REB',
#     'OPP_FT_PCT',
#     'OPP_FG3M',
#     'OPP_BLKA',
#     'Avg_Rebounds_Prev_5',
#     'OPP_TOV'],
#    'score': 0.0},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.0}},
#  'Isaiah Hartenstein': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_REBvsPos',
#     'OPP_FG3_PCT',
#     'OPP_STL',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A'],
#    'score': 0.125},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_PFD',
#     'OPP_ASTvsPos',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT'],
#    'score': 0.125},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.0}},
#  'Jarrett Allen': {'PTS': {'model': RandomForestRegressor(),
#    'top_10_features': ['OPP_PTSvsPos',
#     'MIN',
#     'OPP_PF',
#     'PT_PWR',
#     'OPP_REB',
#     'OPP_FGA',
#     'OPP_ASTvsPos',
#     'OPP_DREB',
#     'OPP_FGM',
#     'OPP_BLKvsPos',
#     'OPP_PTS',
#     'OPP_OREB',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'Avg_Points_Prev_5'],
#    'score': 0.42857142857142855},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_BLKvsPos',
#     'OPP_FG_PCT',
#     'PT_PWR',
#     'OPP_DREB',
#     'OPP_BLKA',
#     'OPP_TOV',
#     'OPP_FGM',
#     'OPP_PTS',
#     'OPP_OREB',
#     'OPP_TOVvsPos',
#     'Avg_Rebounds_Prev_5',
#     'OPP_REB',
#     'OPP_ASTvsPos',
#     'OPP_AST',
#     'OPP_REBvsPos'],
#    'score': 0.42857142857142855},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.5714285714285714}},
#  'Taurean Prince': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_PF',
#     'OPP_FG_PCT',
#     'OPP_OREB',
#     'OPP_BLKA',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG3M'],
#    'score': 0.25},
#   'REB': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_STLvsPos',
#     'Avg_Rebounds_Prev_5',
#     'OPP_BLK',
#     'MIN',
#     'OPP_PFD',
#     'OPP_BLKvsPos',
#     'OPP_FG3A',
#     'OPP_STL',
#     'OPP_OREB',
#     'OPP_FTA',
#     'OPP_REB',
#     'OPP_FGA',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos'],
#    'score': 1.0},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_ASTvsPos',
#     'Avg_Rebounds_Prev_5',
#     'PT_PWR',
#     'OPP_FG3_PCT',
#     'MIN',
#     'OPP_FGM',
#     'OPP_AST',
#     'OPP_PTS',
#     'OPP_FTM',
#     'OPP_OREB',
#     'OPP_PF',
#     'OPP_BLKA',
#     'OPP_FG_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos'],
#    'score': 1.0}},
#  'Zach Collins': {'PTS': {'model': Lasso(),
#    'top_10_features': ['OPP_FT_PCT',
#     'MIN',
#     'OPP_DREB',
#     'OPP_PTSvsPos',
#     'OPP_OREB',
#     'OPP_FG3_PCT',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M'],
#    'score': 0.2857142857142857},
#   'REB': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'Avg_Rebounds_Prev_5',
#     'OPP_ASTvsPos',
#     'OPP_FT_PCT',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FTM',
#     'OPP_AST',
#     'OPP_FG3_PCT',
#     'OPP_FGA',
#     'OPP_BLK',
#     'OPP_DREB',
#     'OPP_REBvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOV'],
#    'score': 0.7142857142857143},
#   'AST': {'model': Ridge(),
#    'top_10_features': ['MIN',
#     'OPP_BLKvsPos',
#     'OPP_AST',
#     'OPP_FT_PCT',
#     'OPP_BLK',
#     'OPP_STL',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_OREB',
#     'OPP_FG3_PCT',
#     'OPP_ASTvsPos',
#     'OPP_PFD',
#     'OPP_STLvsPos',
#     'OPP_FTA',
#     'OPP_BLKA'],
#    'score': 0.0}},
#  'Myles Turner': {'PTS': {'model': Ridge(),
#    'top_10_features': ['OPP_BLK',
#     'MIN',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_PTSvsPos',
#     'OPP_FT_PCT',
#     'PT_PWR',
#     'Avg_Points_Prev_5',
#     'OPP_TOVvsPos',
#     'OPP_REB',
#     'OPP_PF',
#     'OPP_BLKvsPos',
#     'OPP_DREB',
#     'OPP_OREB',
#     'OPP_BLKA'],
#    'score': 0.375},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.375},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['Avg_Rebounds_Prev_5',
#     'OPP_FGA',
#     'MIN',
#     'OPP_PF',
#     'OPP_TOVvsPos',
#     'OPP_REBvsPos',
#     'OPP_FG3A',
#     'OPP_AST',
#     'OPP_FGM',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_FG_PCT'],
#    'score': 1.0}},
#  'Reggie Jackson': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['MIN',
#     'OPP_REBvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_FG3_PCT',
#     'OPP_BLK',
#     'OPP_FGA',
#     'OPP_FG3A',
#     'OPP_FG_PCT',
#     'OPP_TOV',
#     'PT_PWR',
#     'OPP_BLKA',
#     'OPP_PTSvsPos',
#     'OPP_STL',
#     'OPP_TOVvsPos'],
#    'score': 0.25},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.375},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_PF',
#     'OPP_AST',
#     'OPP_PFD',
#     'OPP_ASTvsPos',
#     'OPP_BLK',
#     'OPP_FG3_PCT',
#     'OPP_BLKA',
#     'OPP_REBvsPos',
#     'OPP_TOV',
#     'PT_PWR',
#     'OPP_BLKvsPos',
#     'OPP_FG3M',
#     'MIN',
#     'OPP_STL',
#     'OPP_FT_PCT'],
#    'score': 0.125}},
#  'Grant Williams': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['OPP_AST',
#     'OPP_PF',
#     'OPP_FGA',
#     'OPP_TOVvsPos',
#     'OPP_FTA',
#     'OPP_TOV',
#     'OPP_FG3A',
#     'OPP_BLKvsPos',
#     'OPP_FG3_PCT',
#     'OPP_FT_PCT',
#     'OPP_ASTvsPos',
#     'OPP_REBvsPos',
#     'MIN',
#     'OPP_PTS',
#     'OPP_FGM'],
#    'score': 0.42857142857142855},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['Avg_Rebounds_Prev_5',
#     'OPP_TOV',
#     'MIN',
#     'OPP_FGA',
#     'OPP_STL',
#     'OPP_PF',
#     'OPP_BLKvsPos',
#     'PT_PWR',
#     'OPP_AST',
#     'OPP_ASTvsPos',
#     'OPP_FT_PCT',
#     'OPP_PTS',
#     'OPP_BLKA',
#     'OPP_FTM',
#     'OPP_FGM'],
#    'score': 0.0},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_REB',
#     'Avg_Rebounds_Prev_5',
#     'MIN',
#     'PT_PWR',
#     'OPP_BLKvsPos',
#     'OPP_STL',
#     'OPP_PTS',
#     'OPP_TOV',
#     'OPP_FTM',
#     'OPP_PF',
#     'OPP_FG_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos'],
#    'score': 1.0}},
#  'Josh Hart': {'PTS': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_FTA',
#     'Avg_Points_Prev_5',
#     'OPP_TOVvsPos',
#     'OPP_PFD',
#     'OPP_FT_PCT',
#     'OPP_FTM',
#     'OPP_AST',
#     'OPP_TOV',
#     'OPP_STL',
#     'OPP_ASTvsPos',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_PF',
#     'OPP_FG3A'],
#    'score': 0.5},
#   'REB': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=None, ...),
#    'top_10_features': ['OPP_FG_PCT',
#     'OPP_STL',
#     'OPP_FT_PCT',
#     'OPP_PF',
#     'OPP_TOVvsPos',
#     'OPP_BLKvsPos',
#     'MIN',
#     'OPP_FG3M',
#     'OPP_ASTvsPos',
#     'OPP_FGM',
#     'OPP_STLvsPos',
#     'OPP_PTSvsPos',
#     'OPP_FGA',
#     'OPP_AST',
#     'OPP_FTM'],
#    'score': 1.0},
#   'AST': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FTA',
#     'OPP_STL',
#     'OPP_TOV',
#     'OPP_PF',
#     'OPP_BLKA',
#     'OPP_BLK',
#     'OPP_OREB',
#     'OPP_STLvsPos',
#     'OPP_FT_PCT',
#     'OPP_TOVvsPos',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'PT_PWR'],
#    'score': 0.25}},
#  'Mike Conley': {'PTS': {'model': Lasso(),
#    'top_10_features': ['OPP_PTSvsPos',
#     'OPP_PFD',
#     'PT_PWR',
#     'OPP_FTM',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT'],
#    'score': 0.125},
#   'REB': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['Avg_Rebounds_Prev_5',
#     'MIN',
#     'OPP_BLK',
#     'OPP_PF',
#     'OPP_FG_PCT',
#     'OPP_BLKvsPos',
#     'OPP_FG3M',
#     'OPP_AST',
#     'OPP_OREB',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_FG3A',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA'],
#    'score': 1.0},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_BLK',
#     'OPP_TOV',
#     'OPP_FG3A',
#     'PT_PWR',
#     'OPP_STL',
#     'OPP_PFD',
#     'OPP_FG3M',
#     'OPP_STLvsPos',
#     'Avg_Rebounds_Prev_5',
#     'OPP_DREB',
#     'OPP_REB',
#     'OPP_FG3_PCT',
#     'OPP_FTM',
#     'OPP_PTS',
#     'OPP_FT_PCT'],
#    'score': 0.375}},
#  'Ausar Thompson': {'PTS': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_STL',
#     'Avg_Points_Prev_5',
#     'OPP_STLvsPos',
#     'OPP_DREB',
#     'OPP_PF',
#     'OPP_FTA',
#     'OPP_TOV',
#     'OPP_FG3A',
#     'OPP_OREB',
#     'OPP_PTSvsPos',
#     'PT_PWR',
#     'OPP_PFD',
#     'OPP_FGA',
#     'OPP_TOVvsPos'],
#    'score': 0.5},
#   'REB': {'model': Ridge(),
#    'top_10_features': ['OPP_PFD',
#     'PT_PWR',
#     'OPP_PTSvsPos',
#     'MIN',
#     'OPP_TOV',
#     'OPP_BLKvsPos',
#     'OPP_AST',
#     'OPP_FTM',
#     'OPP_ASTvsPos',
#     'OPP_TOVvsPos',
#     'OPP_OREB',
#     'OPP_REBvsPos',
#     'OPP_FTA',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FGA'],
#    'score': 0.75},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.25}},
#  'Chet Holmgren': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['OPP_STL',
#     'OPP_REBvsPos',
#     'OPP_FG3_PCT',
#     'OPP_AST',
#     'OPP_FGA',
#     'OPP_ASTvsPos',
#     'OPP_PTSvsPos',
#     'OPP_STLvsPos',
#     'OPP_OREB',
#     'PT_PWR',
#     'OPP_PF',
#     'OPP_FGM',
#     'OPP_DREB',
#     'OPP_FTA',
#     'OPP_PFD'],
#    'score': 0.375},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'PT_PWR'],
#    'score': 0.25},
#   'AST': {'model': RandomForestRegressor(),
#    'top_10_features': ['OPP_BLK',
#     'OPP_ASTvsPos',
#     'Avg_Rebounds_Prev_5',
#     'MIN',
#     'OPP_BLKvsPos',
#     'OPP_REB',
#     'OPP_DREB',
#     'OPP_STLvsPos',
#     'OPP_STL',
#     'OPP_REBvsPos',
#     'OPP_FTA',
#     'OPP_FT_PCT',
#     'OPP_FG3A',
#     'OPP_TOVvsPos',
#     'OPP_BLKA'],
#    'score': 0.375}},
#  'Jeremy Sochan': {'PTS': {'model': Lasso(),
#    'top_10_features': ['OPP_PF',
#     'OPP_STLvsPos',
#     'OPP_TOV',
#     'OPP_STL',
#     'PT_PWR',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M'],
#    'score': 0.25},
#   'REB': {'model': RandomForestRegressor(),
#    'top_10_features': ['OPP_BLKA',
#     'MIN',
#     'OPP_DREB',
#     'PT_PWR',
#     'Avg_Rebounds_Prev_5',
#     'OPP_REBvsPos',
#     'OPP_FG_PCT',
#     'OPP_FGM',
#     'OPP_PTSvsPos',
#     'OPP_TOVvsPos',
#     'OPP_AST',
#     'OPP_FG3M',
#     'OPP_FGA',
#     'OPP_ASTvsPos',
#     'OPP_PF'],
#    'score': 0.75},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.25}},
#  'Nikola Vucevic': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['MIN',
#     'OPP_PFD',
#     'OPP_REBvsPos',
#     'OPP_FGA',
#     'OPP_TOV',
#     'OPP_AST',
#     'OPP_TOVvsPos',
#     'OPP_PTSvsPos',
#     'OPP_FGM',
#     'OPP_BLK',
#     'OPP_FG3A',
#     'OPP_DREB',
#     'PT_PWR',
#     'OPP_FTA',
#     'OPP_OREB'],
#    'score': 0.42857142857142855},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_ASTvsPos',
#     'OPP_OREB',
#     'OPP_AST',
#     'MIN',
#     'OPP_TOVvsPos',
#     'OPP_BLKvsPos',
#     'OPP_REBvsPos',
#     'OPP_DREB',
#     'OPP_STLvsPos',
#     'OPP_PF',
#     'OPP_PFD',
#     'OPP_FG_PCT',
#     'OPP_FTM',
#     'PT_PWR',
#     'OPP_FT_PCT'],
#    'score': 0.14285714285714285},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_PF',
#     'OPP_STL',
#     'OPP_TOVvsPos',
#     'OPP_ASTvsPos',
#     'OPP_REBvsPos',
#     'OPP_TOV',
#     'OPP_BLKA',
#     'OPP_AST',
#     'PT_PWR',
#     'OPP_PTSvsPos',
#     'Avg_Rebounds_Prev_5',
#     'OPP_BLK',
#     'OPP_OREB',
#     'OPP_FGM',
#     'OPP_FGA'],
#    'score': 0.0}},
#  'Anthony Davis': {'PTS': {'model': Ridge(),
#    'top_10_features': ['OPP_REBvsPos',
#     'MIN',
#     'PT_PWR',
#     'OPP_PFD',
#     'OPP_OREB',
#     'OPP_BLKvsPos',
#     'OPP_ASTvsPos',
#     'Avg_Points_Prev_5',
#     'OPP_AST',
#     'OPP_FG_PCT',
#     'OPP_PF',
#     'OPP_REB',
#     'OPP_FTM',
#     'OPP_FTA',
#     'OPP_TOVvsPos'],
#    'score': 0.25},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_OREB',
#     'OPP_DREB',
#     'OPP_PTSvsPos',
#     'OPP_STL',
#     'OPP_PF',
#     'OPP_AST',
#     'OPP_TOVvsPos',
#     'OPP_BLK',
#     'OPP_BLKvsPos',
#     'OPP_REB',
#     'OPP_FTA',
#     'OPP_FT_PCT',
#     'OPP_FG_PCT',
#     'OPP_STLvsPos',
#     'OPP_FG3_PCT'],
#    'score': 0.375},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.0}},
#  'Jabari Smith Jr.': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['OPP_FGA',
#     'OPP_BLK',
#     'OPP_PF',
#     'OPP_AST',
#     'OPP_DREB',
#     'OPP_PFD',
#     'OPP_FG_PCT',
#     'OPP_TOV',
#     'OPP_PTSvsPos',
#     'OPP_FT_PCT',
#     'OPP_OREB',
#     'OPP_BLKA',
#     'OPP_REB',
#     'OPP_FTM',
#     'OPP_ASTvsPos'],
#    'score': 0.14285714285714285},
# ...
#     'OPP_BLKvsPos',
#     'OPP_PTSvsPos',
#     'OPP_FG3A',
#     'OPP_FT_PCT',
#     'OPP_FGA'],
#    'score': 1.0},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_BLK',
#     'OPP_REBvsPos',
#     'OPP_OREB',
#     'Avg_Rebounds_Prev_5',
#     'OPP_STL',
#     'MIN',
#     'OPP_BLKA',
#     'OPP_FG_PCT',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'OPP_BLKvsPos',
#     'OPP_FG3A',
#     'OPP_ASTvsPos'],
#    'score': 1.0}},
#  'Buddy Hield': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_FG3_PCT',
#     'OPP_FTA',
#     'OPP_BLKvsPos',
#     'OPP_FT_PCT',
#     'OPP_PF',
#     'OPP_OREB',
#     'OPP_PFD',
#     'OPP_FG3M',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM'],
#    'score': 0.25},
#   'REB': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_PF',
#     'MIN',
#     'OPP_FG_PCT',
#     'PT_PWR',
#     'OPP_DREB',
#     'OPP_STL',
#     'Avg_Rebounds_Prev_5',
#     'OPP_OREB',
#     'OPP_REBvsPos',
#     'OPP_BLKA',
#     'OPP_AST',
#     'OPP_PFD',
#     'OPP_FGA',
#     'OPP_PTSvsPos',
#     'OPP_ASTvsPos'],
#    'score': 1.0},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_PTSvsPos',
#     'Avg_Rebounds_Prev_5',
#     'OPP_ASTvsPos',
#     'OPP_PF',
#     'OPP_PTS',
#     'MIN',
#     'OPP_FG_PCT',
#     'OPP_OREB',
#     'OPP_BLK',
#     'OPP_PFD',
#     'OPP_REBvsPos',
#     'OPP_FG3M',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos'],
#    'score': 1.0}},
#  'Kyle Kuzma': {'PTS': {'model': RandomForestRegressor(),
#    'top_10_features': ['Avg_Points_Prev_5',
#     'MIN',
#     'OPP_PF',
#     'OPP_PFD',
#     'OPP_REB',
#     'OPP_DREB',
#     'OPP_STL',
#     'OPP_TOV',
#     'OPP_STLvsPos',
#     'OPP_FT_PCT',
#     'OPP_BLKA',
#     'OPP_FG_PCT',
#     'OPP_BLK',
#     'OPP_FG3A',
#     'PT_PWR'],
#    'score': 0.625},
#   'REB': {'model': Ridge(),
#    'top_10_features': ['OPP_TOV',
#     'OPP_PTSvsPos',
#     'OPP_FTM',
#     'OPP_PTS',
#     'OPP_BLK',
#     'MIN',
#     'OPP_OREB',
#     'OPP_FG3M',
#     'OPP_FTA',
#     'OPP_FG_PCT',
#     'OPP_FG3A',
#     'OPP_FT_PCT',
#     'OPP_FG3_PCT',
#     'OPP_PFD',
#     'OPP_DREB'],
#    'score': 0.375},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['OPP_FGA',
#     'PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.125}},
#  'Bennedict Mathurin': {'PTS': {'model': Ridge(),
#    'top_10_features': ['MIN',
#     'OPP_FT_PCT',
#     'OPP_STLvsPos',
#     'OPP_PTSvsPos',
#     'OPP_STL',
#     'OPP_PFD',
#     'OPP_BLKA',
#     'OPP_FG_PCT',
#     'OPP_BLK',
#     'OPP_FTA',
#     'OPP_TOVvsPos',
#     'OPP_FGA',
#     'OPP_AST',
#     'OPP_REBvsPos',
#     'OPP_FG3A'],
#    'score': 0.125},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_OREB',
#     'MIN',
#     'OPP_TOV',
#     'OPP_STL',
#     'OPP_BLKA',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'OPP_PTSvsPos',
#     'OPP_REB',
#     'OPP_BLK',
#     'OPP_PFD',
#     'OPP_FG3A',
#     'OPP_AST',
#     'OPP_ASTvsPos',
#     'OPP_FTM'],
#    'score': 0.125},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_TOV',
#     'OPP_STL',
#     'OPP_OREB',
#     'OPP_FG3_PCT',
#     'OPP_AST',
#     'OPP_PFD',
#     'OPP_PF',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_BLKA',
#     'OPP_FG3A',
#     'OPP_BLK',
#     'OPP_TOVvsPos',
#     'MIN',
#     'OPP_FG3M'],
#    'score': 0.375}},
#  'OG Anunoby': {'PTS': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=None, ...),
#    'top_10_features': ['OPP_DREB',
#     'OPP_FG3A',
#     'OPP_TOVvsPos',
#     'OPP_STL',
#     'OPP_FG3M',
#     'Avg_Points_Prev_5',
#     'MIN',
#     'OPP_FT_PCT',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_PF',
#     'OPP_FG_PCT',
#     'OPP_FTA',
#     'OPP_FGA',
#     'OPP_STLvsPos'],
#    'score': 1.0},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_PTSvsPos',
#     'OPP_BLK',
#     'OPP_OREB',
#     'PT_PWR',
#     'OPP_PF',
#     'OPP_FG_PCT',
#     'OPP_STL',
#     'OPP_TOVvsPos',
#     'OPP_BLKvsPos',
#     'OPP_PFD',
#     'OPP_FTA',
#     'OPP_FTM',
#     'OPP_FGA',
#     'OPP_TOV',
#     'OPP_REBvsPos'],
#    'score': 0.5714285714285714},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_ASTvsPos',
#     'OPP_OREB',
#     'OPP_BLKvsPos',
#     'OPP_PFD',
#     'OPP_REBvsPos',
#     'OPP_FTA',
#     'OPP_FTM',
#     'OPP_TOV',
#     'OPP_PF',
#     'OPP_STL',
#     'OPP_DREB',
#     'OPP_STLvsPos',
#     'OPP_TOVvsPos',
#     'OPP_BLK',
#     'OPP_FT_PCT'],
#    'score': 0.2857142857142857}},
#  'Franz Wagner': {'PTS': {'model': Lasso(),
#    'top_10_features': ['OPP_FG3A',
#     'OPP_STLvsPos',
#     'OPP_AST',
#     'OPP_BLK',
#     'OPP_FTA',
#     'OPP_OREB',
#     'OPP_PTSvsPos',
#     'PT_PWR',
#     'OPP_TOV',
#     'OPP_FG_PCT',
#     'OPP_PTS',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_PFD',
#     'OPP_BLKvsPos'],
#    'score': 0.2857142857142857},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_REBvsPos',
#     'OPP_AST',
#     'OPP_FG_PCT',
#     'OPP_ASTvsPos',
#     'OPP_STL',
#     'OPP_FTM',
#     'OPP_FT_PCT',
#     'OPP_FGM',
#     'OPP_BLKvsPos',
#     'OPP_BLKA',
#     'OPP_FG3A',
#     'OPP_TOVvsPos',
#     'MIN',
#     'OPP_FG3M',
#     'OPP_FGA'],
#    'score': 0.2857142857142857},
#   'AST': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_BLK',
#     'Avg_Rebounds_Prev_5',
#     'OPP_ASTvsPos',
#     'OPP_FG3A',
#     'OPP_OREB',
#     'OPP_PFD',
#     'OPP_PF',
#     'OPP_STL',
#     'OPP_PTSvsPos',
#     'OPP_TOVvsPos',
#     'OPP_REBvsPos',
#     'OPP_DREB',
#     'OPP_BLKA',
#     'PT_PWR'],
#    'score': 0.42857142857142855}},
#  'John Collins': {'PTS': {'model': RandomForestRegressor(),
#    'top_10_features': ['OPP_FTA',
#     'MIN',
#     'Avg_Points_Prev_5',
#     'OPP_PF',
#     'OPP_FTM',
#     'OPP_FG3A',
#     'OPP_BLK',
#     'OPP_DREB',
#     'OPP_BLKA',
#     'OPP_PFD',
#     'OPP_REB',
#     'OPP_STLvsPos',
#     'PT_PWR',
#     'OPP_TOVvsPos',
#     'OPP_FG3_PCT'],
#    'score': 0.8571428571428571},
#   'REB': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'OPP_DREB',
#     'Avg_Rebounds_Prev_5',
#     'OPP_PTSvsPos',
#     'OPP_BLK',
#     'OPP_TOV',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FGA',
#     'OPP_FGM',
#     'OPP_REB',
#     'OPP_OREB',
#     'OPP_AST',
#     'OPP_FT_PCT',
#     'OPP_STLvsPos'],
#    'score': 0.7142857142857143},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_TOV',
#     'OPP_STLvsPos',
#     'OPP_STL',
#     'OPP_PFD',
#     'PT_PWR',
#     'OPP_ASTvsPos',
#     'OPP_FG3M',
#     'OPP_TOVvsPos',
#     'OPP_OREB',
#     'OPP_FGA',
#     'OPP_BLK',
#     'OPP_FTA',
#     'OPP_PTS',
#     'MIN',
#     'OPP_BLKvsPos'],
#    'score': 0.0}},
#  'Paolo Banchero': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_BLK',
#     'OPP_DREB',
#     'PT_PWR',
#     'OPP_STLvsPos',
#     'OPP_ASTvsPos',
#     'OPP_PF',
#     'OPP_FG3A',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT'],
#    'score': 0.5},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_REBvsPos',
#     'OPP_OREB',
#     'OPP_PFD',
#     'OPP_FT_PCT',
#     'OPP_FGA',
#     'OPP_FTM',
#     'OPP_TOV',
#     'OPP_AST',
#     'OPP_DREB',
#     'OPP_TOVvsPos',
#     'OPP_PTSvsPos',
#     'OPP_BLKvsPos',
#     'OPP_STLvsPos',
#     'PT_PWR',
#     'OPP_FG3_PCT'],
#    'score': 0.375},
#   'AST': {'model': Ridge(),
#    'top_10_features': ['OPP_PFD',
#     'OPP_FG_PCT',
#     'OPP_AST',
#     'OPP_FT_PCT',
#     'OPP_BLKvsPos',
#     'OPP_STLvsPos',
#     'OPP_PTSvsPos',
#     'MIN',
#     'OPP_FGA',
#     'OPP_FG3M',
#     'OPP_FTA',
#     'OPP_FG3_PCT',
#     'OPP_PF',
#     'PT_PWR',
#     'OPP_FGM'],
#    'score': 0.25}},
#  'Jamal Murray': {'PTS': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_FGM',
#     'OPP_PTS',
#     'OPP_STL',
#     'OPP_FG_PCT',
#     'MIN',
#     'OPP_PTSvsPos',
#     'OPP_OREB',
#     'Avg_Points_Prev_5',
#     'OPP_BLK',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGA',
#     'OPP_STLvsPos',
#     'OPP_FG3A',
#     'OPP_ASTvsPos'],
#    'score': 1.0},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_DREB',
#     'OPP_REB',
#     'OPP_PF',
#     'OPP_STLvsPos',
#     'OPP_FG_PCT',
#     'PT_PWR',
#     'OPP_FT_PCT',
#     'OPP_FGM',
#     'OPP_PFD',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_FGA',
#     'OPP_BLK',
#     'OPP_FG3M'],
#    'score': 0.2},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'PT_PWR'],
#    'score': 0.4}},
#  'Jaren Jackson Jr.': {'PTS': {'model': Ridge(),
#    'top_10_features': ['MIN',
#     'OPP_PF',
#     'OPP_ASTvsPos',
#     'OPP_TOV',
#     'OPP_BLKvsPos',
#     'OPP_FGA',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'OPP_FT_PCT',
#     'OPP_STL',
#     'OPP_PFD',
#     'OPP_AST',
#     'OPP_FG3A',
#     'OPP_FG3M',
#     'OPP_FGM'],
#    'score': 0.625},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['Avg_Rebounds_Prev_5',
#     'OPP_FGA',
#     'OPP_AST',
#     'MIN',
#     'OPP_BLKA',
#     'OPP_BLK',
#     'OPP_STLvsPos',
#     'OPP_FG3_PCT',
#     'OPP_REBvsPos',
#     'OPP_BLKvsPos',
#     'OPP_FT_PCT',
#     'OPP_FG_PCT',
#     'OPP_TOV',
#     'OPP_PF',
#     'OPP_STL'],
#    'score': 0.375},
#   'AST': {'model': LinearRegression(),
#    'top_10_features': ['OPP_FGA',
#     'OPP_TOVvsPos',
#     'OPP_FG_PCT',
#     'OPP_FT_PCT',
#     'OPP_REB',
#     'OPP_DREB',
#     'OPP_FG3A',
#     'Avg_Rebounds_Prev_5',
#     'OPP_PTSvsPos',
#     'OPP_OREB',
#     'OPP_FG3_PCT',
#     'OPP_ASTvsPos',
#     'OPP_AST',
#     'OPP_BLKvsPos',
#     'OPP_BLK'],
#    'score': 0.25}},
#  'Spencer Dinwiddie': {'PTS': {'model': LinearRegression(),
#    'top_10_features': ['OPP_TOV',
#     'OPP_BLK',
#     'OPP_FGA',
#     'OPP_PFD',
#     'OPP_FGM',
#     'OPP_REB',
#     'OPP_FTA',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_PTS',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_TOVvsPos',
#     'OPP_DREB',
#     'OPP_STLvsPos'],
#    'score': 0.0},
#   'REB': {'model': LinearRegression(),
#    'top_10_features': ['OPP_TOV',
#     'OPP_REB',
#     'OPP_OREB',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_PTS',
#     'OPP_ASTvsPos',
#     'OPP_BLK',
#     'OPP_PFD',
#     'OPP_FG3M',
#     'OPP_PF',
#     'OPP_AST',
#     'OPP_TOVvsPos',
#     'OPP_FG3A',
#     'OPP_FT_PCT'],
#    'score': 0.2857142857142857},
#   'AST': {'model': RandomForestRegressor(),
#    'top_10_features': ['MIN',
#     'Avg_Rebounds_Prev_5',
#     'OPP_STLvsPos',
#     'OPP_FTA',
#     'OPP_PFD',
#     'OPP_FG3M',
#     'OPP_OREB',
#     'OPP_FG3A',
#     'OPP_STL',
#     'OPP_PF',
#     'OPP_ASTvsPos',
#     'OPP_AST',
#     'OPP_TOVvsPos',
#     'OPP_FG3_PCT',
#     'OPP_BLK'],
#    'score': 0.42857142857142855}},
#  'Jalen Johnson': {'PTS': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=None, ...),
#    'top_10_features': ['OPP_TOV',
#     'Avg_Points_Prev_5',
#     'OPP_ASTvsPos',
#     'OPP_PTSvsPos',
#     'MIN',
#     'OPP_FTA',
#     'OPP_FGA',
#     'OPP_DREB',
#     'OPP_BLKvsPos',
#     'OPP_REBvsPos',
#     'OPP_FG3M',
#     'OPP_FTM',
#     'OPP_BLK',
#     'OPP_FG_PCT',
#     'OPP_PTS'],
#    'score': 1.0},
#   'REB': {'model': Ridge(),
#    'top_10_features': ['MIN',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FGA',
#     'OPP_OREB',
#     'OPP_REBvsPos',
#     'OPP_BLK',
#     'OPP_FG3_PCT',
#     'OPP_FG3M',
#     'OPP_FG_PCT',
#     'OPP_PFD',
#     'OPP_PF',
#     'OPP_AST',
#     'OPP_TOVvsPos',
#     'OPP_TOV',
#     'OPP_REB'],
#    'score': 0.4},
#   'AST': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['MIN',
#     'Avg_Rebounds_Prev_5',
#     'OPP_FGA',
#     'OPP_DREB',
#     'OPP_BLKA',
#     'OPP_PFD',
#     'OPP_FG3A',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FG_PCT'],
#    'score': 1.0}},
#  'Khris Middleton': {'PTS': {'model': Lasso(),
#    'top_10_features': ['MIN',
#     'OPP_TOVvsPos',
#     'OPP_FTA',
#     'OPP_FG3_PCT',
#     'OPP_PTSvsPos',
#     'Avg_Points_Prev_5',
#     'OPP_FG3A',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_PTS',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT'],
#    'score': 0.2857142857142857},
#   'REB': {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=None, ...),
#    'top_10_features': ['OPP_FG3A',
#     'OPP_TOVvsPos',
#     'OPP_DREB',
#     'OPP_FG3M',
#     'OPP_FGM',
#     'OPP_FTM',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'MIN',
#     'Avg_Rebounds_Prev_5',
#     'OPP_STL',
#     'OPP_PTSvsPos',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_REBvsPos'],
#    'score': 1.0},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.2857142857142857}},
#  'Josh Giddey': {'PTS': {'model': DecisionTreeRegressor(),
#    'top_10_features': ['OPP_PTSvsPos',
#     'MIN',
#     'Avg_Points_Prev_5',
#     'OPP_TOV',
#     'OPP_BLK',
#     'OPP_FT_PCT',
#     'OPP_FG3A',
#     'PT_PWR',
#     'OPP_REBvsPos',
#     'OPP_PFD',
#     'OPP_ASTvsPos',
#     'OPP_FG3M',
#     'OPP_FG_PCT',
#     'OPP_FTM',
#     'OPP_STLvsPos'],
#    'score': 1.0},
#   'REB': {'model': Lasso(),
#    'top_10_features': ['OPP_BLK',
#     'PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT'],
#    'score': 0.42857142857142855},
#   'AST': {'model': Lasso(),
#    'top_10_features': ['PT_PWR',
#     'OPP_FTM',
#     'OPP_PTSvsPos',
#     'OPP_REBvsPos',
#     'OPP_ASTvsPos',
#     'OPP_STLvsPos',
#     'OPP_BLKvsPos',
#     'OPP_TOVvsPos',
#     'OPP_FGM',
#     'OPP_FGA',
#     'OPP_FG_PCT',
#     'OPP_FG3M',
#     'OPP_FG3A',
#     'OPP_FG3_PCT',
#     'OPP_FTA'],
#    'score': 0.0}}}

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Create separate dictionaries for points, rebounds, assists, blocks, steals, and turnovers predictions
points_predictions = {'Player': [], 'Points': [], 'R2_Score': []}
rebounds_predictions = {'Player': [], 'Rebounds': [], 'R2_Score': []}
assists_predictions = {'Player': [], 'Assists': [], 'R2_Score': []}


# Iterate through each player in 'today_data'
for player, player_data in today_data.groupby('Player'):
    # Check if the player has a fitted model in player_best_models
    if player in player_best_models:
        # Get the selected models and their scores for the player
        selected_models = player_best_models[player]
        if selected_models:
            # Prepare predictions for each target variable
            for target_variable, model_info in selected_models.items():
                # Get the model for the target variable
                model = model_info['model']
                r_squared = model_info.get('score', 0)  # Default to 0 if R-squared is missing

                # Check if the model exists and R-squared is above 0.5 for the target variable
                if model and r_squared > 0.0:
                    # Features for the current player from 'today_data' based on the top features
                    top_features = model_info.get('top_10_features', [])
                    X_player_today = player_data[top_features]

                    # Check if X_player_today is not empty
                    if not X_player_today.empty:
                        scaler = StandardScaler()
                        X_player_today_normalized = scaler.fit_transform(X_player_today)  # Normalize features

                        # Make predictions using the selected model
                        prediction = model.predict(X_player_today_normalized)

                        # Round predictions to two decimal places and convert to float
                        rounded_prediction = round(prediction[0], 2)

                        # Append predictions and R-squared scores to the respective prediction dictionary based on the target variable
                        if target_variable == 'PTS':
                            points_predictions['Player'].append(player)
                            points_predictions['Points'].append(float(rounded_prediction))
                            points_predictions['R2_Score'].append(r_squared)
                        elif target_variable == 'REB':
                            rebounds_predictions['Player'].append(player)
                            rebounds_predictions['Rebounds'].append(float(rounded_prediction))
                            rebounds_predictions['R2_Score'].append(r_squared)
                        elif target_variable == 'AST':
                            assists_predictions['Player'].append(player)
                            assists_predictions['Assists'].append(float(rounded_prediction))
                            assists_predictions['R2_Score'].append(r_squared)

# Convert the lists of predictions to DataFrames
df_points_predictions = pd.DataFrame(points_predictions)
df_rebounds_predictions = pd.DataFrame(rebounds_predictions)
df_assists_predictions = pd.DataFrame(assists_predictions)

# Sort DataFrames by R2 Score in descending order
df_points_predictions = df_points_predictions.sort_values(by='R2_Score', ascending=False)
df_rebounds_predictions = df_rebounds_predictions.sort_values(by='R2_Score', ascending=False)
df_assists_predictions = df_assists_predictions.sort_values(by='R2_Score', ascending=False)

# Display predictions for points, rebounds, assists, blocks, steals, and turnovers
print("Points Predictions:")
print(df_points_predictions)

print("\nRebounds Predictions:")
print(df_rebounds_predictions)

print("\nAssists Predictions:")
print(df_assists_predictions)
# Out:
# Points Predictions:
#                      Player     Points  R2_Score
# 0                Al Horford   6.600000  1.000000
# 14            Grayson Allen   9.000000  1.000000
# 35            Rui Hachimura  18.000000  1.000000
# 34               OG Anunoby  14.070000  1.000000
# 33         Matisse Thybulle   6.000000  1.000000
# 30            Luguentz Dort  12.000000  1.000000
# 29             LeBron James  18.090000  1.000000
# 26             Jusuf Nurkic  18.410000  1.000000
# 25            Julius Randle  19.959999  1.000000
# 21              Josh Giddey   7.000000  1.000000
# 41           Toumani Camara   4.000000  1.000000
# 32          Malcolm Brogdon  15.570000  0.833333
# 38  Shai Gilgeous-Alexander  31.400000  0.714286
# 37           Shaedon Sharpe  16.230000  0.714286
# 7            Damian Lillard  25.150000  0.714286
# 28       Kristaps Porzingis  19.190000  0.666667
# 12    Giannis Antetokounmpo  30.230000  0.625000
# 17           Jalen Williams  18.180000  0.571429
# 31              Luka Doncic  35.240000  0.571429
# 20             Jerami Grant  20.650000  0.571429
# 5               Cam Reddish   7.660000  0.571429
# 23                Josh Hart   5.970000  0.500000
# 16            Jalen Brunson  25.650000  0.500000
# 10             Devin Booker  26.140000  0.500000
# 24             Jrue Holiday  13.030000  0.428571
# 13           Grant Williams   8.350000  0.428571
# 19             Jayson Tatum  25.090000  0.428571
# 6             Chet Holmgren  17.940000  0.375000
# 8         Derrick Jones Jr.  15.150000  0.375000
# 2             Austin Reaves  15.110000  0.375000
# 22               Josh Green   6.620000  0.333333
# 11              Eric Gordon  13.520000  0.285714
# 27          Khris Middleton  14.690000  0.285714
# 9             Derrick White  16.180000  0.285714
# 18             Jaylen Brown  23.510000  0.285714
# 39           Taurean Prince   9.890000  0.250000
# 4               Brook Lopez  10.370000  0.250000
# 3              Bobby Portis  12.000000  0.250000
# 1             Anthony Davis  25.670000  0.250000
# 36          Scoot Henderson  11.540000  0.166667
# 40         Tim Hardaway Jr.  17.060000  0.142857
# 15       Isaiah Hartenstein   6.570000  0.125000
#
# Rebounds Predictions:
#                      Player  Rebounds  R2_Score
# 21                Josh Hart      5.12  1.000000
# 38           Taurean Prince      1.00  1.000000
# 5               Cam Reddish      3.00  1.000000
# 9              Devin Booker      4.41  1.000000
# 10              Eric Gordon      0.62  1.000000
# 25          Khris Middleton      5.83  1.000000
# 23            Julius Randle      8.00  1.000000
# 0                Al Horford      7.97  0.714286
# 24             Jusuf Nurkic      9.92  0.714286
# 11    Giannis Antetokounmpo     11.50  0.625000
# 33               OG Anunoby      4.09  0.571429
# 30              Luka Doncic      7.96  0.571429
# 28             LeBron James      7.47  0.571429
# 12            Grayson Allen      4.19  0.571429
# 35          Scoot Henderson      2.93  0.500000
# 26       Kristaps Porzingis      7.57  0.500000
# 20               Josh Green      2.85  0.500000
# 3              Bobby Portis      6.59  0.500000
# 4               Brook Lopez      5.04  0.500000
# 7            Damian Lillard      5.26  0.428571
# 19              Josh Giddey      6.03  0.428571
# 16             Jaylen Brown      5.20  0.428571
# 22             Jrue Holiday      6.44  0.428571
# 32         Matisse Thybulle      2.14  0.428571
# 1             Anthony Davis     12.19  0.375000
# 31          Malcolm Brogdon      3.38  0.333333
# 17             Jayson Tatum      8.53  0.285714
# 40           Toumani Camara      4.97  0.285714
# 8             Derrick White      4.12  0.285714
# 6             Chet Holmgren      7.39  0.250000
# 27             Kyrie Irving      5.00  0.200000
# 34            Rui Hachimura      3.60  0.200000
# 18             Jerami Grant      3.59  0.142857
# 15           Jalen Williams      4.06  0.142857
# 36           Shaedon Sharpe      4.97  0.142857
# 37  Shai Gilgeous-Alexander      5.89  0.142857
# 39         Tim Hardaway Jr.      3.60  0.142857
# 29            Luguentz Dort      3.74  0.142857
# 13       Isaiah Hartenstein      7.73  0.125000
# 14            Jalen Brunson      3.86  0.125000
# 2             Austin Reaves      4.37  0.125000
#
# Assists Predictions:
#                      Player  Assists  R2_Score
# 38           Toumani Camara     1.00  1.000000
# 2              Bobby Portis     2.00  1.000000
# 3               Brook Lopez     0.00  1.000000
# 4               Cam Reddish     2.00  1.000000
# 36           Taurean Prince     1.00  1.000000
# 7         Derrick Jones Jr.     1.00  1.000000
# 32            Rui Hachimura     2.00  1.000000
# 30         Matisse Thybulle     1.00  1.000000
# 24       Kristaps Porzingis     0.00  1.000000
# 12           Grant Williams     2.00  1.000000
# 16             Jaylen Brown     3.92  0.857143
# 25             Kyrie Irving     5.12  0.800000
# 21            Julius Randle     3.94  0.750000
# 15           Jalen Williams     2.00  0.714286
# 35  Shai Gilgeous-Alexander     6.40  0.571429
# 0                Al Horford     3.03  0.571429
# 8             Derrick White     5.18  0.571429
# 13            Grayson Allen     2.84  0.571429
# 33          Scoot Henderson     5.00  0.500000
# 6            Damian Lillard     6.85  0.428571
# 28              Luka Doncic     9.15  0.428571
# 20             Jrue Holiday     4.71  0.428571
# 14            Jalen Brunson     6.38  0.375000
# 5             Chet Holmgren     1.77  0.375000
# 18               Josh Green     2.27  0.333333
# 29          Malcolm Brogdon     5.17  0.333333
# 9              Devin Booker     7.82  0.333333
# 23          Khris Middleton     4.94  0.285714
# 10              Eric Gordon     1.03  0.285714
# 26             LeBron James     7.54  0.285714
# 17             Jayson Tatum     4.47  0.285714
# 31               OG Anunoby     2.41  0.285714
# 34           Shaedon Sharpe     3.00  0.285714
# 19                Josh Hart     2.55  0.250000
# 22             Jusuf Nurkic     3.51  0.142857
# 37         Tim Hardaway Jr.     1.69  0.142857
# 27            Luguentz Dort     1.87  0.142857
# 11    Giannis Antetokounmpo     5.86  0.125000
# 1             Austin Reaves     5.18  0.125000

# %%
props_read = pd.read_csv('/content/nba-player-props-rotowire.csv',skiprows=1)
print(props_read.head())
props_read[props_read['Player'] == 'Derrick Jones']
# Out:
#                     Player Team   Opp   PTS   REB  AST  3PT  BLK  STL  PTS.1  \
# 0    Giannis Antetokounmpo  MIL   BOS  33.5  12.5  6.5  0.5  NaN  NaN   33.5
# 1  Shai Gilgeous-Alexander  OKC   POR  31.5   6.5  5.5  1.5  NaN  NaN   31.5
# 2             Kyrie Irving  DAL   NYK  30.5   6.5  6.5  2.5  NaN  NaN   30.5
# 3            Anthony Davis  LAL   PHX  28.5  12.5  3.5  0.5  NaN  NaN   28.5
# 4            Julius Randle  NYK  @DAL  27.5   8.5  4.5  1.5  NaN  NaN   27.5
#
#    ...  AST.2  3PT.2  BLK.2  STL.2  PTS.3  REB.3  AST.3  3PT.3  BLK.3  STL.3
# 0  ...    6.5    0.5    0.5    1.5   33.5   13.5    6.5    NaN    NaN    NaN
# 1  ...    5.5    1.5    0.5    2.5   32.5    6.5    5.5    NaN    NaN    NaN
# 2  ...    6.5    2.5    0.5    1.5   30.5    6.5    6.5    NaN    NaN    NaN
# 3  ...    3.5    0.5    2.5    1.5   29.5   12.5    3.5    NaN    NaN    NaN
# 4  ...    4.5    1.5    0.5    0.5   28.5    9.5    4.5    NaN    NaN    NaN
#
# [5 rows x 27 columns]
#            Player Team  Opp   PTS  REB  AST  3PT  BLK  STL  PTS.1  ...  AST.2  \
# 32  Derrick Jones  DAL  NYK  12.5  5.5  NaN  1.5  NaN  NaN   12.5  ...    1.5
#
#     3PT.2  BLK.2  STL.2  PTS.3  REB.3  AST.3  3PT.3  BLK.3  STL.3
# 32    1.5    0.5    0.5   12.5    4.5    NaN    NaN    NaN    NaN
#
# [1 rows x 27 columns]

# %%
# Finding all columns related to PTS, REB, and AST
cols_PTS = [col for col in props_read.columns if 'PTS' in col]
cols_REB = [col for col in props_read.columns if 'REB' in col]
cols_AST = [col for col in props_read.columns if 'AST' in col]

# Extracting columns related to PTS, REB, and AST
PTS_columns = props_read[cols_PTS]
REB_columns = props_read[cols_REB]
AST_columns = props_read[cols_AST]

# Calculating averages for PTS, REB, AST
props_read['Points'] = PTS_columns.mean(axis=1, skipna=True)
props_read['Rebounds'] = REB_columns.mean(axis=1, skipna=True)
props_read['Assists'] = AST_columns.mean(axis=1, skipna=True)

# Creating a new DataFrame with selected columns
player_props = props_read[['Player', 'Points', 'Rebounds', 'Assists']]


player_props
# Out:
#                      Player     Points  Rebounds  Assists
# 0     Giannis Antetokounmpo  33.500000     12.75     6.25
# 1   Shai Gilgeous-Alexander  31.750000      6.25     5.50
# 2              Kyrie Irving  30.500000      6.25     6.50
# 3             Anthony Davis  28.750000     12.50     3.50
# 4             Julius Randle  27.750000      9.00     4.50
# 5             Jalen Brunson  27.000000      3.50     7.50
# 6              Kevin Durant  27.166667      6.50     5.00
# 7          Donovan Mitchell  27.000000      5.50     6.50
# 8              Jayson Tatum  27.500000      8.50     4.50
# 9              LeBron James  26.500000      6.50     7.75
# 10             Devin Booker  24.500000      4.50     7.50
# 11             Jaylen Brown  24.500000      5.50     3.50
# 12           Damian Lillard  24.500000      4.50     6.50
# 13            Mikal Bridges  22.500000      5.50     3.50
# 14          Anfernee Simons  22.500000      3.50     4.50
# 15       Kristaps Porzingis  20.500000      7.50      NaN
# 16             Bradley Beal  17.750000      3.75     4.50
# 17             Jerami Grant  18.500000      4.25     2.50
# 18            Jarrett Allen  16.750000     11.50     3.50
# 19            Chet Holmgren  17.500000      7.50     2.50
# 20           Jalen Williams  17.500000      4.50     4.50
# 21          Cameron Johnson  16.000000      4.50     2.50
# 22          Khris Middleton  15.750000      4.50     5.50
# 23            Austin Reaves  15.833333      3.50     5.50
# 24               OG Anunoby  13.500000      4.50     1.50
# 25              Nic Claxton  13.500000     10.50     1.50
# 26        Spencer Dinwiddie  13.500000      3.50     6.50
# 27              Brook Lopez  12.750000      5.50     0.50
# 28                Max Strus  13.500000      4.50     3.50
# 29            Grayson Allen  12.500000      3.50     2.50
# 30              Josh Giddey  12.000000      6.50     4.50
# 31          Scoot Henderson  12.500000      3.50     5.50
# 32            Derrick Jones  12.500000      5.25     1.50
# 33             Jusuf Nurkic  11.750000      9.50     2.50
# 34               Duop Reath  12.166667      6.50      NaN
# 35         Donte DiVincenzo  11.500000      3.50     2.50
# 36            Luguentz Dort  10.500000      4.50     1.50
# 37           Taurean Prince  10.500000      2.75     1.50
# 38              Isaac Okoro   9.500000      3.50     2.50
# 39            Malik Beasley   8.500000      3.50     0.50
# 40      Dorian Finney-Smith   8.500000      4.50     1.50
# 41       Isaiah Hartenstein   8.500000     11.00     2.50
# 42            Dwight Powell   7.500000      6.50     2.50
# 43              Cam Reddish   6.500000      2.50     1.50
# 44           Toumani Camara   5.500000      5.50     0.50
# 45                Dean Wade   4.500000      4.50     0.50

# %%
df_points_predictions['Player'] = df_points_predictions['Player'].str.replace(' Jr.', '')
df_rebounds_predictions['Player'] = df_rebounds_predictions['Player'].str.replace(' Jr.', '')
df_assists_predictions['Player'] = df_assists_predictions['Player'].str.replace(' Jr.', '')
player_props['Player'] = player_props['Player'].str.replace(' Jr.', '')
# Out:
# <ipython-input-54-62157ca758bb>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_points_predictions['Player'] = df_points_predictions['Player'].str.replace(' Jr.', '')
# <ipython-input-54-62157ca758bb>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_rebounds_predictions['Player'] = df_rebounds_predictions['Player'].str.replace(' Jr.', '')
# <ipython-input-54-62157ca758bb>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_assists_predictions['Player'] = df_assists_predictions['Player'].str.replace(' Jr.', '')
# <ipython-input-54-62157ca758bb>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   player_props['Player'] = player_props['Player'].str.replace(' Jr.', '')
# <ipython-input-54-62157ca758bb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_props['Player'] = player_props['Player'].str.replace(' Jr.', '')

# %%
df_points_predictions['Player'].unique()
# Out:
# array(['Al Horford', 'Grayson Allen', 'Rui Hachimura', 'OG Anunoby',
#        'Matisse Thybulle', 'Luguentz Dort', 'LeBron James',
#        'Jusuf Nurkic', 'Julius Randle', 'Josh Giddey', 'Toumani Camara',
#        'Malcolm Brogdon', 'Shai Gilgeous-Alexander', 'Shaedon Sharpe',
#        'Damian Lillard', 'Kristaps Porzingis', 'Giannis Antetokounmpo',
#        'Jalen Williams', 'Luka Doncic', 'Jerami Grant', 'Cam Reddish',
#        'Josh Hart', 'Jalen Brunson', 'Devin Booker', 'Jrue Holiday',
#        'Grant Williams', 'Jayson Tatum', 'Chet Holmgren', 'Derrick Jones',
#        'Austin Reaves', 'Josh Green', 'Eric Gordon', 'Khris Middleton',
#        'Derrick White', 'Jaylen Brown', 'Taurean Prince', 'Brook Lopez',
#        'Bobby Portis', 'Anthony Davis', 'Scoot Henderson', 'Tim Hardaway',
#        'Isaiah Hartenstein'], dtype=object)

# %%
prediction_dfs = [df_points_predictions, df_rebounds_predictions, df_assists_predictions]
prediction_columns = ['Points', 'Rebounds', 'Assists']
stat_names = ['PTS', 'REB', 'AST']
result_pts = pd.DataFrame(columns=['Player', 'Prediction', 'Prop', 'Difference', 'R2_Score'])
result_reb = pd.DataFrame(columns=['Player', 'Prediction', 'Prop', 'Difference', 'R2_Score'])
result_ast = pd.DataFrame(columns=['Player', 'Prediction', 'Prop', 'Difference', 'R2_Score'])

# ... (Previous code remains the same)

# Loop through each prediction DataFrame and compare with player_props
for pred_df, column, stat_name in zip(prediction_dfs, prediction_columns, stat_names):
    for index, row in pred_df.iterrows():
        player = row['Player']
        pred = row[column]
        r2_score = row['R2_Score']

        # Check if the player exists in both DataFrames
        if (player_props['Player'] == player).any() and (player in player_props['Player'].values):
            if stat_name == 'PTS' and 'Points' in player_props.columns:
                difference = pred - player_props[player_props['Player'] == player]['Points'].iloc[0]
                result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
            elif stat_name == 'REB' and 'Rebounds' in player_props.columns:
                difference = pred - player_props[player_props['Player'] == player]['Rebounds'].iloc[0]
                result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
            elif stat_name == 'AST' and 'Assists' in player_props.columns:
                difference = pred - player_props[player_props['Player'] == player]['Assists'].iloc[0]
                result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# Out:
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_pts = result_pts.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Points'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_reb = result_reb.append({'Player': player, 'Prediction': pred, 'Prop':player_props[player_props['Player'] == player]['Rebounds'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)
# <ipython-input-56-36e4df32cfaa>:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_ast = result_ast.append({'Player': player, 'Prediction': pred, 'Prop': player_props[player_props['Player'] == player]['Assists'].iloc[0], 'Difference': difference, 'R2_Score': r2_score}, ignore_index=True)

# %%
# Round numerical columns including 'Prediction', 'Prop', 'Difference', 'R2_Score' to 2 decimal points
columns_to_round = ['Prediction', 'Prop', 'Difference', 'R2_Score']
result_pts[columns_to_round] = result_pts[columns_to_round].round(2)
result_reb[columns_to_round] = result_reb[columns_to_round].round(2)
result_ast[columns_to_round] = result_ast[columns_to_round].round(2)

# Sort the DataFrames by the 'Difference' column
result_pts_sorted = result_pts.sort_values(by='R2_Score', ascending=False)
result_reb_sorted = result_reb.sort_values(by='R2_Score', ascending=False)
result_ast_sorted = result_ast.sort_values(by='R2_Score', ascending=False)


result_pts_sorted = result_pts_sorted.rename(columns={'R2_Score': 'Model Score'})
result_reb_sorted = result_reb_sorted.rename(columns={'R2_Score': 'Model Score'})
result_ast_sorted = result_ast_sorted.rename(columns={'R2_Score': 'Model Score'})

# Display the sorted and rounded DataFrames for each stat with modified column names
print("\033[1mResults for Points (Sorted by Difference):\033[0m")  # \033[1m and \033[0m for bold and reset
print(result_pts_sorted.to_string(index=False))

print("\n\033[1mResults for Rebounds (Sorted by Difference):\033[0m")
print(result_reb_sorted.to_string(index=False))

print("\n\033[1mResults for Assists (Sorted by Difference):\033[0m")
print(result_ast_sorted.to_string(index=False))
# Out:
# Results for Points (Sorted by Difference):
#                  Player  Prediction  Prop  Difference  Model Score
#           Grayson Allen        9.00 12.50       -3.50         1.00
#           Luguentz Dort       12.00 10.50        1.50         1.00
#            LeBron James       18.09 26.50       -8.41         1.00
#            Jusuf Nurkic       18.41 11.75        6.66         1.00
#           Julius Randle       19.96 27.75       -7.79         1.00
#             Josh Giddey        7.00 12.00       -5.00         1.00
#          Toumani Camara        4.00  5.50       -1.50         1.00
#              OG Anunoby       14.07 13.50        0.57         1.00
# Shai Gilgeous-Alexander       31.40 31.75       -0.35         0.71
#          Damian Lillard       25.15 24.50        0.65         0.71
#      Kristaps Porzingis       19.19 20.50       -1.31         0.67
#   Giannis Antetokounmpo       30.23 33.50       -3.27         0.62
#            Jerami Grant       20.65 18.50        2.15         0.57
#             Cam Reddish        7.66  6.50        1.16         0.57
#          Jalen Williams       18.18 17.50        0.68         0.57
#           Jalen Brunson       25.65 27.00       -1.35         0.50
#            Devin Booker       26.14 24.50        1.64         0.50
#            Jayson Tatum       25.09 27.50       -2.41         0.43
#           Chet Holmgren       17.94 17.50        0.44         0.38
#           Derrick Jones       15.15 12.50        2.65         0.38
#           Austin Reaves       15.11 15.83       -0.72         0.38
#         Khris Middleton       14.69 15.75       -1.06         0.29
#            Jaylen Brown       23.51 24.50       -0.99         0.29
#          Taurean Prince        9.89 10.50       -0.61         0.25
#             Brook Lopez       10.37 12.75       -2.38         0.25
#           Anthony Davis       25.67 28.75       -3.08         0.25
#         Scoot Henderson       11.54 12.50       -0.96         0.17
#      Isaiah Hartenstein        6.57  8.50       -1.93         0.12
#
# Results for Rebounds (Sorted by Difference):
#                  Player  Prediction  Prop  Difference  Model Score
#          Taurean Prince        1.00  2.75       -1.75         1.00
#             Cam Reddish        3.00  2.50        0.50         1.00
#            Devin Booker        4.41  4.50       -0.09         1.00
#         Khris Middleton        5.83  4.50        1.33         1.00
#           Julius Randle        8.00  9.00       -1.00         1.00
#            Jusuf Nurkic        9.92  9.50        0.42         0.71
#   Giannis Antetokounmpo       11.50 12.75       -1.25         0.62
#              OG Anunoby        4.09  4.50       -0.41         0.57
#            LeBron James        7.47  6.50        0.97         0.57
#           Grayson Allen        4.19  3.50        0.69         0.57
#         Scoot Henderson        2.93  3.50       -0.57         0.50
#      Kristaps Porzingis        7.57  7.50        0.07         0.50
#             Brook Lopez        5.04  5.50       -0.46         0.50
#            Jaylen Brown        5.20  5.50       -0.30         0.43
#             Josh Giddey        6.03  6.50       -0.47         0.43
#          Damian Lillard        5.26  4.50        0.76         0.43
#           Anthony Davis       12.19 12.50       -0.31         0.38
#            Jayson Tatum        8.53  8.50        0.03         0.29
#          Toumani Camara        4.97  5.50       -0.53         0.29
#           Chet Holmgren        7.39  7.50       -0.11         0.25
#            Kyrie Irving        5.00  6.25       -1.25         0.20
#            Jerami Grant        3.59  4.25       -0.66         0.14
#          Jalen Williams        4.06  4.50       -0.44         0.14
# Shai Gilgeous-Alexander        5.89  6.25       -0.36         0.14
#           Luguentz Dort        3.74  4.50       -0.76         0.14
#      Isaiah Hartenstein        7.73 11.00       -3.27         0.12
#           Jalen Brunson        3.86  3.50        0.36         0.12
#           Austin Reaves        4.37  3.50        0.87         0.12
#
# Results for Assists (Sorted by Difference):
#                  Player  Prediction  Prop  Difference  Model Score
#          Toumani Camara        1.00  0.50        0.50         1.00
#             Brook Lopez        0.00  0.50       -0.50         1.00
#             Cam Reddish        2.00  1.50        0.50         1.00
#          Taurean Prince        1.00  1.50       -0.50         1.00
#           Derrick Jones        1.00  1.50       -0.50         1.00
#      Kristaps Porzingis        0.00   NaN         NaN         1.00
#            Jaylen Brown        3.92  3.50        0.42         0.86
#            Kyrie Irving        5.12  6.50       -1.38         0.80
#           Julius Randle        3.94  4.50       -0.56         0.75
#          Jalen Williams        2.00  4.50       -2.50         0.71
# Shai Gilgeous-Alexander        6.40  5.50        0.90         0.57
#           Grayson Allen        2.84  2.50        0.34         0.57
#         Scoot Henderson        5.00  5.50       -0.50         0.50
#          Damian Lillard        6.85  6.50        0.35         0.43
#           Jalen Brunson        6.38  7.50       -1.12         0.38
#           Chet Holmgren        1.77  2.50       -0.73         0.38
#            Devin Booker        7.82  7.50        0.32         0.33
#         Khris Middleton        4.94  5.50       -0.56         0.29
#            LeBron James        7.54  7.75       -0.21         0.29
#            Jayson Tatum        4.47  4.50       -0.03         0.29
#              OG Anunoby        2.41  1.50        0.91         0.29
#            Jusuf Nurkic        3.51  2.50        1.01         0.14
#           Luguentz Dort        1.87  1.50        0.37         0.14
#   Giannis Antetokounmpo        5.86  6.25       -0.39         0.12
#           Austin Reaves        5.18  5.50       -0.32         0.12
